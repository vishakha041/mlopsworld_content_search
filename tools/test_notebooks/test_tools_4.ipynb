# %%
# Import required libraries and tools
import os
import sys
import json
from pprint import pprint

# Load environment variables
from dotenv import load_dotenv
load_dotenv()

# Add tools directory to path
sys.path.append('.')

# Import all our tools
from search_talks_by_filters import search_talks_by_filters
from search_talks_semantically import search_talks_semantically
from analyze_speaker_activity import analyze_speaker_activity
from get_talk_details import get_talk_details
from find_similar_content import find_similar_content
from analyze_topics_and_trends import analyze_topics_and_trends

print("✅ All tools imported successfully!")
print(f"🔑 ApertureDB Key configured: {'Yes' if os.getenv('APERTUREDB_KEY') else 'No'}")

# Helper function for pretty printing results
def print_results(result, max_results=5):
    """Pretty print tool results with truncation"""
    if isinstance(result, dict) and 'results' in result:
        print(f"Total found: {result.get('total_found', 'Unknown')}")
        if result.get('query_summary'):
            print(f"Query: {result['query_summary']}")
        if result.get('sort_info'):
            print(f"Sorting: {result['sort_info']}")
        
        results = result['results'][:max_results]
        for i, talk in enumerate(results, 1):
            print(f"\n{i}. {talk.get('title', 'No Title')}")
            print(f"   Speaker: {talk.get('speaker', 'Unknown')}")
            print(f"   Company: {talk.get('company', 'Unknown')}")
            print(f"   Views: {talk.get('views', 0):,}")
            if talk.get('published_date'):
                print(f"   Date: {talk['published_date']}")
    else:
        pprint(result)
# Out:
# ✅ All tools imported successfully!
# 🔑 ApertureDB Key configured: Yes

# %% [markdown]
# ## Tool 4: `get_talk_details` - Comprehensive Talk Deep Dive Testing
#
# This tool provides comprehensive details about specific MLOps talks including metadata, transcript chunks, speaker information, and optionally related talks. It handles both title-based and ID-based lookups with flexible transcript filtering by time ranges.
#
# ### Test 1: Basic Talk Information Retrieval
# **Query**: "Get complete details about the talk 'LLMs, from Playgrounds to Production-ready Pipelines'"
#
# This performs a basic lookup by exact title to retrieve all metadata including speaker info, abstract, view counts, and technical details. No transcript or related talks included for focused metadata analysis.

# %%
# Test 1: Basic Talk Information Retrieval
result1 = get_talk_details.invoke({
    "talk_title": "LLMs, from Playgrounds to Production-ready Pipelines"
})

print("=== BASIC TALK DETAILS ===")
pprint(result1)
# Out:
# === BASIC TALK DETAILS ===
# {'related_talks': [],
#  'success': True,
#  'summary': "Retrieved details for talk 'LLMs, from Playgrounds to "
#             "Production-ready Pipelines'",
#  'talk_info': {'abstract': 'Despite the onset of commercially viable '
#                            'open-source Large Langauge Models, companies are '
#                            'struggling to leverage cutting-edge models like '
#                            'Llama2 and Mistral 7B for production-ready '
#                            'applications. Creating a simple demo page on a '
#                            'personal laptop and training, fine-tuning, and '
#                            'serving multi-billion parameter LLMs on HPC-scale '
#                            'infrastructure - with proprietary enterprise data '
#                            '- involves an entirely different engineering '
#                            'challenge. In this session, Intae, who co-founded '
#                            'and now leads product development at VESSL AI, '
#                            'will explore how companies can leverage MLOps '
#                            'infrastructure to go from a simple model '
#                            'playground to deploying enterprise-scale pipelines '
#                            'for LLMs.',
#                'category': 'Deployment and integration',
#                'company': 'VESSL AI',
#                'duration': 'Unknown',
#                'event': 'MLOps & GenAI World 2023',
#                'industries': None,
#                'keywords': None,
#                'published_date': '2023-11-02',
#                'speaker': 'Intae Rhyoo',
#                'speaker_details': {'bio': '',
#                                    'company': None,
#                                    'name': 'Intae Rhyoo'},
#                'talk_id': 'cade4e0c-5922-57c4-9dba-98ea942da9de',
#                'tech_level': 5,
#                'title': 'LLMs, from Playgrounds to Production-ready Pipelines',
#                'track': 'Workshop',
#                'views': 58,
#                'youtube_url': 'https://www.youtube.com/watch?v=HWXPBJAhNlY'},
#  'transcript_chunks': [],
#  'transcript_stats': {}}

# %% [markdown]
# ### Test 2: Talk with Full Transcript Access
# **Query**: "Get the multimodal agents talk with complete transcript for content analysis"
#
# This retrieves a talk with full transcript chunks included, useful for analyzing the actual spoken content, finding specific discussions, and understanding the flow of the presentation.

# %%
# Test 2: Talk with Full Transcript Access
result2 = get_talk_details.invoke({
    "talk_title": "Making ChatGPT funny with Prompt Optimization",
    "include_transcript": True,
    "max_chunks": 15
})

print("=== TALK WITH TRANSCRIPT ===")
pprint(result2)
# Out:
# === TALK WITH TRANSCRIPT ===
# {'related_talks': [],
#  'success': True,
#  'summary': "Retrieved details for talk 'Making ChatGPT funny with Prompt "
#             "Optimization' | 15 transcript chunks",
#  'talk_info': {'abstract': 'A recent study found ChatGPT repeated the same 25 '
#                            'jokes 90% of the time. As is often the case with '
#                            'popular narratives about the limits of AI, ChatGPT '
#                            'is capable of so much more... you just have to '
#                            'know how to ask! Using principles of prompt '
#                            'engineering, I try to get ChatGPT to make you '
#                            'laugh, while arming you with techniques for '
#                            'overcoming similar supposed limitations, when '
#                            'working with AI.',
#                'category': 'Introduction to MLOps and GenAI',
#                'company': 'Saxifrage',
#                'duration': 'Unknown',
#                'event': 'MLOps & GenAI World 2023',
#                'industries': 'Banking & Financial Services, Hospital & Health '
#                              'Care, Information Technology & Service, '
#                              'Marketing & Advertising, Telecommunications',
#                'keywords': None,
#                'published_date': '2024-05-15',
#                'speaker': 'Mike  Taylor',
#                'speaker_details': {'bio': '',
#                                    'company': None,
#                                    'name': 'Mike  Taylor'},
#                'talk_id': 'a33cda43-3b87-566f-b94d-5658b37f32a0',
#                'tech_level': 2,
#                'title': 'Making ChatGPT funny with Prompt Optimization',
#                'track': None,
#                'views': 2279,
#                'youtube_url': 'https://www.youtube.com/watch?v=lo6OOTlSS6A'},
#  'transcript_chunks': [{'duration': 65,
#                         'end_time': 70,
#                         'sequence': 1,
#                         'start_time': 5,
#                         'text': 'uh so presentation today is making chat gbt '
#                                 'funny with prompt optimization and you might '
#                                 'be wondering what that has to do with mlops '
#                                 'and uh the business strategy track but uh '
#                                 "trust me I'll get to that I'll tie it all "
#                                 "together for you guys uh so I'm I'm Mike "
#                                 'Taylor I was the co-founder of ladder which '
#                                 'was a 50 person marketing agency we also did '
#                                 'a bunch of our own technology including '
#                                 'machine learning uh to automate a lot of our '
#                                 "work uh since I left I've uh attracted about "
#                                 '300,000 students on my courses on LinkedIn '
#                                 'learning uh as well as Vex power which is a '
#                                 'platform I built um and udemy where I have a '
#                                 'prompt engineering course uh which has done '
#                                 "pretty well recently um and I'm writing a "
#                                 'book on prompt engineering for generative AI '
#                                 'uh for Riley media so that that should be out '
#                                 "early 2024 once I've done all the editing so "
#                                 "uh that's me I'm pretty deep in the AI space "
#                                 'and in particular I like to take on '
#                                 "challenges that a lot of people say can't be "
#                                 'done',
#                         'timestamp_formatted': '0:05'},
#                        {'duration': 63,
#                         'end_time': 119,
#                         'sequence': 2,
#                         'start_time': 56,
#                         'text': "that should be out early 2024 once I've done "
#                                 "all the editing so uh that's me I'm pretty "
#                                 'deep in the AI space and in particular I like '
#                                 'to take on challenges that a lot of people '
#                                 "say can't be done yet uh so uh one of the "
#                                 'challenges I took on as kind of side project '
#                                 "was making chat GPT funny um and we're going "
#                                 'to talk about how I did that uh and you can '
#                                 'be the you can uh you can be the judge as to '
#                                 'whether I actually made it tell funny jokes '
#                                 'uh but um along the way most importantly '
#                                 "we're going to learn the five principles of "
#                                 "prompting uh so this is what I've really been "
#                                 'writing the book around because I tried to '
#                                 'extra extrapolate and kind of think about '
#                                 'where this is heading in the future what um '
#                                 'types of principles are still going to be '
#                                 'useful when GPT 5 comes out when GPT 6 comes '
#                                 "out um and they're are Universal across "
#                                 'models and not just open AI models as well uh '
#                                 'and so these principles are you know what I '
#                                 'found in my work you know working with '
#                                 'clients as well as just working my own '
#                                 'projects uh',
#                         'timestamp_formatted': '0:56'},
#                        {'duration': 62,
#                         'end_time': 167,
#                         'sequence': 3,
#                         'start_time': 105,
#                         'text': "GPT 6 comes out um and they're are Universal "
#                                 'across models and not just open AI models as '
#                                 'well uh and so these principles are you know '
#                                 'what I found in my work you know working with '
#                                 'clients as well as just working my own '
#                                 'projects uh that that universally are helpful '
#                                 "and um actually you'll find as we go through "
#                                 "that they're also pretty helpful when you're "
#                                 'working with human intelligence as well as '
#                                 "artificial intelligence so I think there's no "
#                                 "um there's no coincidence as to why they work "
#                                 "uh so we're going to dive into this now um "
#                                 "I'm not going to look at the chat I'm just "
#                                 'going to kind of talk through um you know '
#                                 'through the slides and get to the end uh but '
#                                 "then at the end I'm going to go through and "
#                                 "save some time and I'll go back through any "
#                                 'questions you guys have so feel free to ask '
#                                 "any questions you have um and then I'll cover "
#                                 'them as best I can at the end cool telling '
#                                 "jokes with chat gbt um if I don't know if "
#                                 "you've ever tried this um if you've ever "
#                                 'asked chat gbt to tell you a joke like if you '
#                                 'have it open',
#                         'timestamp_formatted': '1:45'},
#                        {'duration': 62,
#                         'end_time': 218,
#                         'sequence': 4,
#                         'start_time': 156,
#                         'text': 'best I can at the end cool telling jokes with '
#                                 "chat gbt um if I don't know if you've ever "
#                                 "tried this um if you've ever asked chat gbt "
#                                 'to tell you a joke like if you have it open '
#                                 'uh maybe try now and see what you get uh you '
#                                 'get pretty poor results uh so the chances are '
#                                 "you'll get one of these five uh 57% of the "
#                                 'time it told one of these five jokes and you '
#                                 "know I'm a dad so I tell Dad jokes and this "
#                                 "feels funny to me uh in some way they're not "
#                                 "terrible jokes but they're also kind of you "
#                                 "know politically correct they're not um "
#                                 "particularly interesting um they're not the "
#                                 'sort of jokes that you would hear in a '
#                                 'standup comedy club um and uh and and you '
#                                 "know there's a reason for that right the chat "
#                                 'gbt by default is trying to kind of give you '
#                                 'or guess what you want and that guess is '
#                                 'always you know the average of the internet '
#                                 "um because that's what it was trained on if "
#                                 "you don't give it any direction um so it "
#                                 'makes sense that it would kind of stay pretty '
#                                 "neutral it's also been optimized",
#                         'timestamp_formatted': '2:36'},
#                        {'duration': 61,
#                         'end_time': 266,
#                         'sequence': 5,
#                         'start_time': 205,
#                         'text': 'and that guess is always you know the average '
#                                 "of the internet um because that's what it was "
#                                 "trained on if you don't give it any direction "
#                                 'um so it makes sense that it would kind of '
#                                 "stay pretty neutral it's also been optimized "
#                                 'and um you know incentivized uh to um you '
#                                 'know be middle of the road right and not not '
#                                 'to cause too much controversy with the '
#                                 'responses so we have to really push it a '
#                                 'little bit um these uh these jokes by the way '
#                                 'if you want to look a bit further into this '
#                                 'this is from a study um called chat GPT is '
#                                 'fun but it is not funny um and they actually '
#                                 'you know tested over a thousand uh responses '
#                                 'and found that um just 25 jokes uh on repeat '
#                                 "are used 90% of the time so let's see if we "
#                                 'can do a little bit better uh the reason why '
#                                 'I dug into this is because I thought it was a '
#                                 "good opportunity um like I can't share a lot "
#                                 "of the client work I'm doing most of my "
#                                 'clients see their prompts as proprietary code '
#                                 "and you know it's hard to you know hard to "
#                                 'argue with that I guess um if if',
#                         'timestamp_formatted': '3:25'},
#                        {'duration': 62,
#                         'end_time': 316,
#                         'sequence': 6,
#                         'start_time': 254,
#                         'text': "opportunity um like I can't share a lot of "
#                                 "the client work I'm doing most of my clients "
#                                 'see their prompts as proprietary code and you '
#                                 "know it's hard to you know hard to argue with "
#                                 "that I guess um if if they've got something "
#                                 "working that most people can't so I thought "
#                                 'this would be good project to demonstrate um '
#                                 "the type of work that I'm doing and and give "
#                                 'you an idea of like what AI can actually do '
#                                 'when you know how to ask because quite often '
#                                 "when I see someone say that chat GPT can't do "
#                                 'x uh and I look at the study or I look at '
#                                 "what they've done um either you know it's "
#                                 "something that most humans can't do either "
#                                 'right like can robot tell a funny joke can '
#                                 'you um you know this is uh I mean this is '
#                                 'kind of hits home like you know most of us '
#                                 "are not funny uh so it's weird for us I think "
#                                 "to expect an AI to be funny um you know it's "
#                                 "it's uh especially when when it's trying to "
#                                 'just kind of give you the average default '
#                                 'answer um most of the time these studies '
#                                 "aren't tested on gp4 so that's the first "
#                                 'thing to check if you ever see someone make a '
#                                 'claim that',
#                         'timestamp_formatted': '4:14'},
#                        {'duration': 61,
#                         'end_time': 365,
#                         'sequence': 7,
#                         'start_time': 304,
#                         'text': "know it's it's uh especially when when it's "
#                                 'trying to just kind of give you the average '
#                                 'default answer um most of the time these '
#                                 "studies aren't tested on gp4 so that's the "
#                                 'first thing to check if you ever see someone '
#                                 "make a claim that AI can't do X or that chat "
#                                 'gbt is getting bad results uh the chances are '
#                                 "they're actually just using the free version "
#                                 'of chat gbt um or the or the paper is old and '
#                                 "I say old in AI it's like could be 6 months "
#                                 'old um and they use GPT 3.5 um you know or it '
#                                 "could be like 12 months old and uh that's "
#                                 "already ancient right like they're probably "
#                                 'using gpt3 um and and and you know gp4 is '
#                                 'capable of a lot more than the previous '
#                                 'models um you know gp4 for example can pass '
#                                 "the bar exam uh whereas GPT 3.5 can't uh so "
#                                 'the other thing that you want to look out for '
#                                 'when someone makes this claim is did they use '
#                                 'any prompt engineering when I looked into the '
#                                 'paper the only thing they really asked was '
#                                 "can you tell me a joke they didn't do any "
#                                 'prompt engineering they',
#                         'timestamp_formatted': '5:04'},
#                        {'duration': 58,
#                         'end_time': 412,
#                         'sequence': 8,
#                         'start_time': 354,
#                         'text': 'you want to look out for when someone makes '
#                                 'this claim is did they use any prompt '
#                                 'engineering when I looked into the paper the '
#                                 'only thing they really asked was can you tell '
#                                 "me a joke they didn't do any prompt "
#                                 "engineering they didn't change the way they "
#                                 "asked they didn't test different ways of "
#                                 'asking in order to get funnier jokes so '
#                                 "that's what I'm going to be doing the way "
#                                 'that you ask the AI for something makes a big '
#                                 'difference just like you know the way that '
#                                 'you ask your employees to do something makes '
#                                 'a big difference too um you know there are '
#                                 'different ways to ask that get you great like '
#                                 'much better results um and there are ways to '
#                                 'ask that you know tend to get you really unel '
#                                 'reliable results as well um so prompt '
#                                 'engineering is really just the you know the '
#                                 'act of finding those prompts that work what '
#                                 'we always start with in prompt engineering is '
#                                 'a naive prompt um even I do this like you '
#                                 'know I know how to write really sophisticated '
#                                 'stuff but um but most of the time prompt '
#                                 "engineering isn't needed and um and if it's "
#                                 "not needed you don't want to waste time on",
#                         'timestamp_formatted': '5:54'},
#                        {'duration': 62,
#                         'end_time': 462,
#                         'sequence': 9,
#                         'start_time': 400,
#                         'text': 'engineering is a naive prompt um even I do '
#                                 'this like you know I know how to write really '
#                                 'sophisticated stuff but um but most of the '
#                                 "time prompt engineering isn't needed and um "
#                                 "and if it's not needed you don't want to "
#                                 "waste time on it it's a similar you know "
#                                 "thing to when you're writing software uh "
#                                 'quite often they say the best software is no '
#                                 'software like if you can solve the problem '
#                                 'without having to write code um you know if '
#                                 'you can reframe the problem so that you can '
#                                 "write less code that's a good thing um and I "
#                                 'would say like even though I work full-time '
#                                 'as a prompt engineer um I try to actively '
#                                 'avoid doing any prompt engineering at first '
#                                 'because you know 80 90% of the time when '
#                                 "you're talking to jat gbt um or you're "
#                                 'prompting midgy um or or you know doing '
#                                 'anything with AI um the models like pretty '
#                                 'good and they can do most tasks um zero shot '
#                                 "uh zero shot meaning you're not providing it "
#                                 "any examples you're just kind of asking for "
#                                 'the thing that you want they do a pretty '
#                                 'reasonable job and um I only really dive into '
#                                 'prompt',
#                         'timestamp_formatted': '6:40'},
#                        {'duration': 61,
#                         'end_time': 511,
#                         'sequence': 10,
#                         'start_time': 450,
#                         'text': "um zero shot uh zero shot meaning you're not "
#                                 "providing it any examples you're just kind of "
#                                 'asking for the thing that you want they do a '
#                                 'pretty reasonable job and um I only really '
#                                 'dive into prompt engineering if this if the '
#                                 "first naive prompt that I try doesn't work um "
#                                 "so uh in this case you know it it doesn't "
#                                 'work right like we we ask can you tell me a '
#                                 "joke uh and it says sure here's a classic one "
#                                 "for you why don't scientists trust atoms "
#                                 'because they make up everything um and if you '
#                                 "recognize that one it's actually one of those "
#                                 'top five um this is the one that I got back '
#                                 "um and there's a bunch of things wrong this "
#                                 "like one is that they're cycling through the "
#                                 'same jokes is not particularly funny um and '
#                                 'um and also that you know the response is '
#                                 "kind of unreliable uh here it's got this "
#                                 "extra text that we don't need in our response "
#                                 "sure here's a classic one for you right like "
#                                 "that's different every time and sometimes "
#                                 "it's there sometimes it's not and that's "
#                                 "that's um a nightmare when you're a prompt "
#                                 "engineer because you don't want as "
#                                 'unreliability in the response like',
#                         'timestamp_formatted': '7:30'},
#                        {'duration': 64,
#                         'end_time': 562,
#                         'sequence': 11,
#                         'start_time': 498,
#                         'text': "classic one for you right like that's "
#                                 "different every time and sometimes it's there "
#                                 "sometimes it's not and that's that's um a "
#                                 "nightmare when you're a prompt engineer "
#                                 "because you don't want as unreliability in "
#                                 "the response like quite often when you're "
#                                 "using prompt engineering it's because you're "
#                                 "building a system whether it's you know uh "
#                                 "just a prompt that you're going to be using "
#                                 "again and again in chat GPT or it's a you "
#                                 'know Google sheet where you have um you know '
#                                 'chat GPT added as a custom function and '
#                                 "you're going to run this prompt like 30 times "
#                                 '100 times a thousand times um and uh you know '
#                                 'it could be an actual product or or like an '
#                                 'internal product or an external product where '
#                                 "you're using this prompt and if some of the "
#                                 'times it comes back with this prepending text '
#                                 "sure here's a classic one for you that's "
#                                 "really bad because um that's extra text you "
#                                 "didn't need in your response um and you have "
#                                 'to pass that out you have to get rid of it '
#                                 'before you display the end result to the user '
#                                 'so um a lot of prompt engineering is really '
#                                 'just kind of making the the response format '
#                                 "reliable as well and we're going to cover "
#                                 'that in the',
#                         'timestamp_formatted': '8:18'},
#                        {'duration': 63,
#                         'end_time': 612,
#                         'sequence': 12,
#                         'start_time': 549,
#                         'text': 'pass that out you have to get rid of it '
#                                 'before you display the end result to the user '
#                                 'so um a lot of prompt engineering is really '
#                                 'just kind of making the the response format '
#                                 "reliable as well and we're going to cover "
#                                 'that in the principles all right so uh a lot '
#                                 'of the people who call themselves prompt '
#                                 'Engineers right now um I realize this kind of '
#                                 'like a loaded term a lot of people ask like '
#                                 'is that even a job um and and know to be '
#                                 "honest it's not really a job yet um it's kind "
#                                 'of like the equivalent of calling yourself an '
#                                 'Excel engineer um you know when when Excel '
#                                 'came out um you know but uh but the reason '
#                                 "why I focus on it is uh just because uh I I'm "
#                                 'like very specifically focus on testing the '
#                                 'prompts making sure they work and kind of '
#                                 'building the ecosystem around the prompts and '
#                                 'that is something that actually machine '
#                                 'learning Engineers are particularly bad at um '
#                                 "to be honest um uh don't don't kill me for "
#                                 'saying that the reason is because machine '
#                                 'learning Engineers are a lot smarter than I '
#                                 'am um you know how to',
#                         'timestamp_formatted': '9:09'},
#                        {'duration': 63,
#                         'end_time': 663,
#                         'sequence': 13,
#                         'start_time': 600,
#                         'text': 'something that actually machine learning '
#                                 'Engineers are particularly bad at um to be '
#                                 "honest um uh don't don't kill me for saying "
#                                 'that the reason is because machine learning '
#                                 'Engineers are a lot smarter than I am um you '
#                                 'know how to fine-tune models uh you know how '
#                                 "to build your own models and that's what you "
#                                 'reach for typically um and and I think that '
#                                 'that can actually be a little bit of a '
#                                 'hindrance like uh a little bit of um a bad '
#                                 'point um when it comes to prompt engineering '
#                                 'because quite often um prompt engineer ing '
#                                 'can get you much bigger increases in accuracy '
#                                 'uh for a lot less time and effort and '
#                                 'resource uh then you can get deploying a '
#                                 'machine learning engineer on it and machine '
#                                 'learning Engineers are very expensive as you '
#                                 'guys will well know um so if you can get '
#                                 'someone like me a prompt engineer to do it '
#                                 "you know they don't necessarily even need to "
#                                 'know how to code my background is marketing I '
#                                 'did learn how to code um but um but you know '
#                                 "you don't necessarily need to you can do a "
#                                 'lot of this stuff testing in Google sheets '
#                                 'right um so um anyway I I I would say',
#                         'timestamp_formatted': '10:00'},
#                        {'duration': 65,
#                         'end_time': 714,
#                         'sequence': 14,
#                         'start_time': 649,
#                         'text': 'even need to know how to code my background '
#                                 'is marketing I did learn how to code um but '
#                                 "um but you know you don't necessarily need to "
#                                 'you can do a lot of this stuff testing in '
#                                 'Google sheets right um so um anyway I I I '
#                                 'would say that um you know there is like a '
#                                 'bit of a weird um cluster of these like gurus '
#                                 "that you see on Twitter or x.com um or you'll "
#                                 'see them in various tools or uh various '
#                                 "communities where they'll share like here are "
#                                 'my 1,000 prompts for doing X um and uh this '
#                                 "is the type of prompt you'll get from them so "
#                                 "this is from AI PRM it's like a prompt live "
#                                 'Library built into a Chrome extension and not '
#                                 'to pick on these guys in particular because '
#                                 "um you know I think you know everyone's just "
#                                 'kind of doing their best with a brand new '
#                                 'technology um but you get these really weird '
#                                 'prompts that like you know use all these uh '
#                                 'you know these tricks and and um you know '
#                                 'this is uh what I call like a blind prompt '
#                                 "it's kind of when when it sounds like a "
#                                 "wizard casting a spell that's when um I would "
#                                 'my red flags',
#                         'timestamp_formatted': '10:49'},
#                        {'duration': 62,
#                         'end_time': 765,
#                         'sequence': 15,
#                         'start_time': 703,
#                         'text': 'these uh you know these tricks and and um you '
#                                 'know this is uh what I call like a blind '
#                                 "prompt it's kind of when when it sounds like "
#                                 "a wizard casting a spell that's when um I "
#                                 "would my red flags raise um there's there's "
#                                 'really probably no testing being done on this '
#                                 'this type of prompt um you know this is done '
#                                 'through trial and error um in this case uh '
#                                 "you know it's saying let's play a game you're "
#                                 "going to act as dark humor GPT there's "
#                                 'actually a spelling mistake here um you know '
#                                 'in the in the actual prompt um although that '
#                                 "doesn't make that much of a difference "
#                                 "surprisingly um and uh you know you'll find "
#                                 "all these weird words like there's no social "
#                                 'piety within the Cabaret right who knows what '
#                                 "that means that's going to take some you chat "
#                                 'gbt into some weird places um in Laten space '
#                                 'so um you know I would definitely test '
#                                 'dropping that or or at least changing that '
#                                 'right um and then uh one of the other things '
#                                 'that I found and you might have found if '
#                                 "you've been testing this sort of stuff is "
#                                 "that um it doesn't respect word limits really "
#                                 'at all um you can say Max 10 words but it '
#                                 "doesn't know how to count surprisingly",
#                         'timestamp_formatted': '11:43'}],
#  'transcript_stats': {'chunks_returned': 15,
#                       'time_filter_applied': False,
#                       'time_range': '0:05 - 12:45',
#                       'total_text_length': 15636}}

# %% [markdown]
# ### Test 3: Time-Specific Transcript Analysis
# **Query**: "Show me what was discussed in the first 5 minutes (0-300 seconds) of the RAG deployment talk"
#
# This demonstrates time-filtered transcript access to analyze specific sections of a talk, useful for understanding introductions, key concepts, or specific time ranges mentioned by users.

# %%
# Test 3: Time-Specific Transcript Analysis
result3 = get_talk_details.invoke({
    "talk_title": "Deploying and Evaluating RAG pipelines with Lightning Studios",
    "include_transcript": True,
    "time_start": 0,
    "time_end": 300,
    "max_chunks": 10
})

print("=== FIRST 5 MINUTES ANALYSIS ===")
pprint(result3)
# Out:
# === FIRST 5 MINUTES ANALYSIS ===
# {'related_talks': [],
#  'success': True,
#  'summary': "Retrieved details for talk 'Deploying and Evaluating RAG "
#             "pipelines with Lightning Studios' | 10 transcript chunks | with "
#             'time filtering',
#  'talk_info': {'abstract': 'Learn how to use Lightning Studios to quickly '
#                            'deploy AI agents and accelerate your evaluation of '
#                            'RAG pipelines.',
#                'category': 'Deployment and integration',
#                'company': 'Lightning AI',
#                'duration': 'Unknown',
#                'event': 'TMLS 2024',
#                'industries': 'Automotive, Banking & Financial Services, '
#                              'Computer Software, Environmental Services, Food '
#                              '& Beverages, Hospital & Health Care, Information '
#                              'Technology & Service, Insurance',
#                'keywords': None,
#                'published_date': '2024-10-31',
#                'speaker': 'Rob Levy',
#                'speaker_details': {'bio': '',
#                                    'company': None,
#                                    'name': 'Rob Levy'},
#                'talk_id': '0c7e727c-214e-5fc1-954e-3aa19bd8a513',
#                'tech_level': 5,
#                'title': 'Deploying and Evaluating RAG pipelines with Lightning '
#                         'Studios',
#                'track': 'Applied Case Studies',
#                'views': 93,
#                'youtube_url': 'https://www.youtube.com/watch?v=JO2mJ00rCkU'},
#  'transcript_chunks': [{'duration': 34,
#                         'end_time': 36,
#                         'sequence': 1,
#                         'start_time': 2,
#                         'text': "[Music] I'm very happy to introduce you to "
#                                 "Rob Levy he's a staff engineer at lighten AI "
#                                 'a New York City based startup at lighten in '
#                                 'the eye the team is focused on defining the '
#                                 'Next Generation development and deployment '
#                                 'pipeline for other Ai and machine learning '
#                                 'operators specifically work focus on data '
#                                 'Ingress and agress needs of apply models and '
#                                 'the',
#                         'timestamp_formatted': '0:02'},
#                        {'duration': 26,
#                         'end_time': 56,
#                         'sequence': 2,
#                         'start_time': 30,
#                         'text': 'work focus on data Ingress and agress needs '
#                                 'of apply models and the optimization of model '
#                                 "deployments let's welcome Rob for the "
#                                 'presentation perfect this seems on thanks so '
#                                 "much for coming out my name is Rob I'm a "
#                                 "Staff engineer at liting AI I'm going to talk "
#                                 'to you all today about llm evaluation and '
#                                 'deployment on the cloud I know people might '
#                                 'be at',
#                         'timestamp_formatted': '0:30'},
#                        {'duration': 21,
#                         'end_time': 73,
#                         'sequence': 3,
#                         'start_time': 52,
#                         'text': 'llm evaluation and deployment on the cloud I '
#                                 'know people might be at different various '
#                                 'levels some of us are PhD researchers some of '
#                                 'us more towards the mlop side or the '
#                                 'management side so going to really try to '
#                                 'cover two things in the next 30 minutes first '
#                                 'what is Lady ni what do we do how can you get '
#                                 "started with this today even if you're just a "
#                                 'hobbyist and how can we help you',
#                         'timestamp_formatted': '0:52'},
#                        {'duration': 24,
#                         'end_time': 93,
#                         'sequence': 4,
#                         'start_time': 69,
#                         'text': "started with this today even if you're just a "
#                                 'hobbyist and how can we help you accelerate '
#                                 'deploying LMS and then second how can we save '
#                                 'your Enterprise real time and money at the '
#                                 'scale of hundreds of thousands of dollars if '
#                                 'you are bringing us some of the harder '
#                                 "problems that we've seen other Enterprises "
#                                 'approach us with over the past few months so '
#                                 'as we all know being in this',
#                         'timestamp_formatted': '1:09'},
#                        {'duration': 29,
#                         'end_time': 115,
#                         'sequence': 5,
#                         'start_time': 86,
#                         'text': 'approach us with over the past few months so '
#                                 'as we all know being in this wonderful '
#                                 'industry iteration speed is King uh all of '
#                                 'the tools that we use on a daily basis they '
#                                 'are just fantastic and they always work '
#                                 'without any hiccups or bumps the road I wish '
#                                 "this were true unfortunately it's not um "
#                                 "there's a dichotomy that has emerged in our "
#                                 'industry',
#                         'timestamp_formatted': '1:26'},
#                        {'duration': 26,
#                         'end_time': 135,
#                         'sequence': 6,
#                         'start_time': 109,
#                         'text': 'dichotomy that has emerged in our industry '
#                                 'where the statisticians mathematicians '
#                                 'scientists who are typically designing models '
#                                 'or fine-tuning experiments and running those '
#                                 'experiments they need to learn a lot about '
#                                 'the orchestration and the infrastructure in '
#                                 'order to get those experiments to scale to a '
#                                 'production use case but those are two very '
#                                 'different',
#                         'timestamp_formatted': '1:49'},
#                        {'duration': 25,
#                         'end_time': 155,
#                         'sequence': 7,
#                         'start_time': 130,
#                         'text': 'experiments to scale to a production use case '
#                                 'but those are two very different types of '
#                                 'people that have uh that knowledge on one '
#                                 'side you have you know PhD level researchers '
#                                 'who you want running these experiments on the '
#                                 'other you have orchestration Specialists '
#                                 'Engineers platform people so this was '
#                                 'realized by our founder about 5 years ago and '
#                                 'uh we created P torch lightning',
#                         'timestamp_formatted': '2:10'},
#                        {'duration': 30,
#                         'end_time': 180,
#                         'sequence': 8,
#                         'start_time': 150,
#                         'text': 'realized by our founder about 5 years ago and '
#                                 'uh we created P torch lightning as a response '
#                                 "if you've ever done a fine tuning or a "
#                                 'training using pytorch you may have run into '
#                                 'the issue that it does not scale uh very well '
#                                 'when you go from single GPU to multi-gpu in '
#                                 'order to go from one to multi you need to do '
#                                 'a lot of configuration that ultimately is is '
#                                 'again a waste of your talent if you are',
#                         'timestamp_formatted': '2:30'},
#                        {'duration': 25,
#                         'end_time': 200,
#                         'sequence': 9,
#                         'start_time': 175,
#                         'text': 'of configuration that ultimately is is again '
#                                 'a waste of your talent if you are one of '
#                                 'those people who is designing experiments and '
#                                 'models uh so pytorch lightning abstracts away '
#                                 'the scalability so that if it runs on one GPU '
#                                 'it will run on tens of thousands and the '
#                                 'community gave it a great response but we got '
#                                 'a response back from a number of researchers '
#                                 'and academics who said hey',
#                         'timestamp_formatted': '2:55'},
#                        {'duration': 24,
#                         'end_time': 218,
#                         'sequence': 10,
#                         'start_time': 194,
#                         'text': 'we got a response back from a number of '
#                                 "researchers and academics who said hey I've "
#                                 'been using pytorch for years I spent years '
#                                 'mastering these configurations I want that '
#                                 'low level uh that low level of control so we '
#                                 'had to develop a second Library lightning '
#                                 'fabric to give it back to those people it '
#                                 'comes packaged with pytorch lightning and so '
#                                 'with pytorch lightning you know',
#                         'timestamp_formatted': '3:14'}],
#  'transcript_stats': {'chunks_returned': 10,
#                       'time_filter_applied': True,
#                       'time_range': '0:02 - 3:38',
#                       'total_text_length': 3699}}

# %% [markdown]
# ### Test 4: Talk Details with Related Content Discovery
# **Query**: "Get details about the Memory Optimizations for Machine Learning talk and find similar presentations for comprehensive research"
#
# This combines talk details with semantic similarity search to find related talks, useful for comprehensive topic research and discovering related content from different speakers.

# %%
# Test 4: Talk Details with Related Content Discovery
result4 = get_talk_details.invoke({
    "talk_title": "Memory Optimizations for Machine Learning",
    "include_related": True,
    "related_count": 6
})

print("=== TALK WITH RELATED CONTENT ===")
pprint(result4)
# Out:
# === TALK WITH RELATED CONTENT ===
# {'related_talks': [{'category': 'Performance optimization and efficiency',
#                     'similarity_score': 0.303,
#                     'speaker': 'Sri  Raghu Malireddi',
#                     'title': 'On-Device ML for LLMs: Post-training '
#                              'Optimization Techniques with T5 and Beyond',
#                     'views': 252,
#                     'youtube_url': 'https://www.youtube.com/watch?v=QRPvr1td4s0'},
#                    {'category': 'Deployment and integration',
#                     'similarity_score': 0.329,
#                     'speaker': 'Jaeman An',
#                     'title': 'Mastering Enterprise-Grade LLM Deployment: '
#                              'Overcoming Production Challenges',
#                     'views': 11,
#                     'youtube_url': 'https://www.youtube.com/watch?v=dRgwzUk1s-g'},
#                    {'category': 'Deployment and integration',
#                     'similarity_score': 0.335,
#                     'speaker': 'Anish  Shah',
#                     'title': 'Investigating the Evolution of Evaluation from '
#                              'Model Training to GenAI inference',
#                     'views': 27,
#                     'youtube_url': 'https://www.youtube.com/watch?v=0pznirh2Ko4'},
#                    {'category': 'Performance optimization and efficiency',
#                     'similarity_score': 0.353,
#                     'speaker': 'Nathan Beach',
#                     'title': 'Leverage Kubernetes To Optimize the Utilization '
#                              'of Your AI Accelerators',
#                     'views': 12,
#                     'youtube_url': 'https://www.youtube.com/watch?v=5jdZksHaJ_Q'},
#                    {'category': 'Model dev, training, arch.',
#                     'similarity_score': 0.357,
#                     'speaker': 'Anish Shah',
#                     'title': 'Hemm: Holistic Evaluation of Multi-modal '
#                              'Generative Models',
#                     'views': 16,
#                     'youtube_url': 'https://www.youtube.com/watch?v=wHC6pnfWsWI'},
#                    {'category': 'Deployment and integration',
#                     'similarity_score': 0.364,
#                     'speaker': 'Anu Reddy',
#                     'title': 'Optimizing AI/ML Workflows on Kubernetes: '
#                              'Advanced Techniques and Integration',
#                     'views': 26,
#                     'youtube_url': 'https://www.youtube.com/watch?v=grCvM9tkS7Q'}],
#  'success': True,
#  'summary': "Retrieved details for talk 'Memory Optimizations for Machine "
#             "Learning' | 6 related talks",
#  'talk_info': {'abstract': 'As Machine Learning continues to forge its way '
#                            'into diverse industries and applications, '
#                            'optimizing computational resources, particularly '
#                            'memory, has become a critical aspect of effective '
#                            'model deployment. This session, "Memory '
#                            'Optimizations for Machine Learning," aims to offer '
#                            'an exhaustive look into the specific memory '
#                            'requirements in Machine Learning tasks, including '
#                            'Large Language Models (LLMs), and the cutting-edge '
#                            'strategies to minimize memory consumption '
#                            'efficiently.\n'
#                            '\n'
#                            "We'll begin by demystifying the memory footprint "
#                            'of typical Machine Learning data structures and '
#                            'algorithms, elucidating the nuances of memory '
#                            'allocation and deallocation during model training '
#                            'phases. The talk will then focus on memory-saving '
#                            'techniques such as data quantization, model '
#                            'pruning, and efficient mini-batch selection. These '
#                            'techniques offer the advantage of conserving '
#                            'memory resources without significant degradation '
#                            'in model performance.\n'
#                            'A special emphasis will be placed on the memory '
#                            'footprint of LLMs during inferencing. LLMs, known '
#                            'for their immense size and complexity, pose unique '
#                            'challenges in terms of memory consumption during '
#                            'deployment. We will explore the factors '
#                            'contributing to the memory footprint of LLMs, such '
#                            'as model architecture, input sequence length, and '
#                            'vocabulary size. Additionally, we will discuss '
#                            'practical strategies to optimize memory usage '
#                            'during LLM inferencing, including techniques like '
#                            'model distillation, dynamic memory allocation, and '
#                            'efficient caching mechanisms.\n'
#                            'By the end of this session, attendees will have a '
#                            'comprehensive understanding of memory optimization '
#                            'techniques for Machine Learning, with a particular '
#                            'focus on the challenges and solutions related to '
#                            'LLM inferencing.',
#                'category': 'Performance optimization and efficiency',
#                'company': 'Netflix',
#                'duration': 'Unknown',
#                'event': 'MLOps & GenAI World 2024',
#                'industries': 'Information Technology Services, Computer '
#                              'Software',
#                'keywords': None,
#                'published_date': '2024-12-05',
#                'speaker': 'Tejas Chopra',
#                'speaker_details': {'bio': '',
#                                    'company': None,
#                                    'name': 'Tejas Chopra'},
#                'talk_id': '87a10c81-06f3-5ba6-85b5-ae807a93e099',
#                'tech_level': 5,
#                'title': 'Memory Optimizations for Machine Learning',
#                'track': 'Research or Advanced Technical',
#                'views': 12,
#                'youtube_url': 'https://www.youtube.com/watch?v=ILR0F6Hjqq4'},
#  'transcript_chunks': [],
#  'transcript_stats': {}}

# %% [markdown]
# ### Test 5: Middle Section Transcript Analysis
# **Query**: "Analyze the middle section (10-20 minutes) of the ML production pipeline talk to understand the core technical content"
#
# This demonstrates advanced time filtering to focus on the main technical content of a talk, skipping introductions and conclusions to analyze the core material.

# %%
# Test 5: Middle Section Transcript Analysis
result5 = get_talk_details.invoke({
    "talk_title": "From ML Repository to ML Production Pipeline",
    "include_transcript": True,
    "time_start": 600,  # 10 minutes
    "time_end": 1200,   # 20 minutes
    "max_chunks": 12
})

print("=== MIDDLE SECTION ANALYSIS (10-20 mins) ===")
pprint(result5)
# Out:
# === MIDDLE SECTION ANALYSIS (10-20 mins) ===
# {'related_talks': [],
#  'success': True,
#  'summary': "Retrieved details for talk 'From ML Repository to ML Production "
#             "Pipeline' | 10 transcript chunks | with time filtering",
#  'talk_info': {'abstract': 'In the pRED MLOps team, we collaborate closely '
#                            'with research scientists to transition their '
#                            'machine learning models into a production '
#                            'environment seamlessly. Through our efforts, we '
#                            'have developed a robust framework that '
#                            'standardises and scales this process effectively. '
#                            'In this talk, we will provide an in-depth look at '
#                            'our framework, the tools we leverage, and the '
#                            'challenges we overcome in this journey.',
#                'category': 'Deployment and integration',
#                'company': 'Roche',
#                'duration': 'Unknown',
#                'event': 'MLOps & GenAI World 2024',
#                'industries': None,
#                'keywords': None,
#                'published_date': '2024-12-05',
#                'speaker': 'Jakub Witkowski, Dariusz Adamczyk',
#                'speaker_details': {'bio': '',
#                                    'company': None,
#                                    'name': 'Jakub Witkowski'},
#                'talk_id': 'aa56daa2-2e78-5292-9fa9-bfa8cb22ce66',
#                'tech_level': 4,
#                'title': 'From ML Repository to ML Production Pipeline',
#                'track': 'Virtual Talk',
#                'views': 23,
#                'youtube_url': 'https://www.youtube.com/watch?v=fqzqDK-ZXcQ'},
#  'transcript_chunks': [{'duration': 69,
#                         'end_time': 697,
#                         'sequence': 13,
#                         'start_time': 628,
#                         'text': 'regarding each of of the repositories uh so '
#                                 "let's drive through them so first of all we "
#                                 'have uh code quality tools uh those help us '
#                                 'keep code in a top shape and catch issues uh '
#                                 'early on um secondly we have Dev containers '
#                                 'uh to make sure everyone has the same Dev '
#                                 'environment which is super handy um and uh '
#                                 'code quality and Dev containers are not '
#                                 'mandatory for for our model owners for our '
#                                 'clients but they are usually interested in '
#                                 'implementing them on their s if they are not '
#                                 'present uh already because sometimes they are '
#                                 'uh they have enough knowledge to implement '
#                                 'those things for for themselves um we have '
#                                 'done cicd pipelines um to automate our '
#                                 'integration uh and deployment so this makes '
#                                 'things uh you know way more efficient um as '
#                                 'yakob said earlier this is kind of mandatory '
#                                 "and it's and it's necessary um",
#                         'timestamp_formatted': '10:28'},
#                        {'duration': 71,
#                         'end_time': 753,
#                         'sequence': 14,
#                         'start_time': 682,
#                         'text': 'uh and deployment so this makes things uh you '
#                                 'know way more efficient um as yakob said '
#                                 "earlier this is kind of mandatory and it's "
#                                 "and it's necessary um our team implements the "
#                                 'ICD and conization for for our model owners '
#                                 "uh if they don't have capacity to to do that "
#                                 'um additionally for um on mlops side we have '
#                                 'C flow reusable components uh this speeds up '
#                                 'development by reusing pre-build components '
#                                 'and eliminate code duplication uh we have '
#                                 'also ke flow SDK uh it helps us manage and '
#                                 'interact with platform more easily um now I '
#                                 'want to talk about three technologies that '
#                                 'really help helped us with uh integration and '
#                                 'building production um pipelines um so first '
#                                 'one is code quality um and to ensure code '
#                                 'quality we implemented a promit hooks to '
#                                 'enforce',
#                         'timestamp_formatted': '11:22'},
#                        {'duration': 68,
#                         'end_time': 807,
#                         'sequence': 15,
#                         'start_time': 739,
#                         'text': 'production um pipelines um so first one is '
#                                 'code quality um and to ensure code quality we '
#                                 'implemented a promit hooks to enforce checks '
#                                 'through our cicd pipeline uh promit hooks are '
#                                 'G scripts designed to catch straightforward '
#                                 'issues before the code is submitted for for '
#                                 'review process right um and that gives us '
#                                 'following benefits um first is to ensure '
#                                 'consistency coding standards uh second '
#                                 'identifying and fix bugs before code review '
#                                 'and uh and third delivering code to '
#                                 'production faster um so what impact did the '
#                                 'promit hook uh in our case um so besides '
#                                 'obvious benefits like preventing accidential '
#                                 'uh leakage of sensitive s sensitive data um '
#                                 'and checking for common security issues uh '
#                                 'what B bothered me personally the most',
#                         'timestamp_formatted': '12:19'},
#                        {'duration': 67,
#                         'end_time': 862,
#                         'sequence': 16,
#                         'start_time': 795,
#                         'text': 'preventing accidential uh leakage of '
#                                 'sensitive s sensitive data um and checking '
#                                 'for common security issues uh what B bothered '
#                                 'me personally the most was the number of '
#                                 'unnecessary uh difference in the code during '
#                                 'the reviews because uh everyone on the team '
#                                 'had different linter settings and different '
#                                 'version of them uh some had called breaking '
#                                 'uh line at 80 characters While others had it '
#                                 'at 120 um and this made the review process '
#                                 'longer as we had to focus on review the '
#                                 'unnecessary uh unnecessary changes um so we '
#                                 'decide to um to align our configuration and '
#                                 'linters and uh things around around the code '
#                                 'quality so once the code quality is good um '
#                                 'the next step is to develop and test code in '
#                                 'uh reproducible way and for that uh I',
#                         'timestamp_formatted': '13:15'},
#                        {'duration': 63,
#                         'end_time': 913,
#                         'sequence': 17,
#                         'start_time': 850,
#                         'text': 'um the next step is to develop and test code '
#                                 'in uh reproducible way and for that uh I '
#                                 'would uh I will tell you about Dev containers '
#                                 'uh and what about def containers uh for those '
#                                 'who are not familiar with this technology uh '
#                                 'Dev containers just lets you use a container '
#                                 'as a complete setup for develop uh '
#                                 'development work um and there is also uh PS '
#                                 'code extension for the containers and it has '
#                                 'made our development process much smoother uh '
#                                 'it provides us with a consistent setup making '
#                                 'it easy to get started and work um uh '
#                                 'together without any issues um each project '
#                                 "has its own isolated environment so it's "
#                                 'eliminating conflicts um over overall it just '
#                                 'make you know everything easier and and '
#                                 'faster uh when it comes to to',
#                         'timestamp_formatted': '14:10'},
#                        {'duration': 64,
#                         'end_time': 964,
#                         'sequence': 18,
#                         'start_time': 900,
#                         'text': 'um each project has its own isolated '
#                                 "environment so it's eliminating conflicts um "
#                                 'over overall it just make you know everything '
#                                 'easier and and faster uh when it comes to to '
#                                 "development and testing um and there's a "
#                                 'small story uh for instance we had a very '
#                                 'Advanced use case to on board that uh already '
#                                 'run somewhere in in our organization um there '
#                                 'was uh already preped Docker fi with '
#                                 'multi-stage build uh they had cicd and so on '
#                                 'um however it quickly turned out that um you '
#                                 'know to get this image run uh for some reason '
#                                 'it was necessary to M additional volume uh to '
#                                 'that image with a third party Library so it '
#                                 'turned out that the test and development are '
#                                 'being done on system that contain such '
#                                 "Library um that's why we think that you know "
#                                 'the unified development environment um is so',
#                         'timestamp_formatted': '15:00'},
#                        {'duration': 68,
#                         'end_time': 1019,
#                         'sequence': 19,
#                         'start_time': 951,
#                         'text': 'test and development are being done on system '
#                                 "that contain such Library um that's why we "
#                                 'think that you know the unified development '
#                                 'environment um is so important uh and by '
#                                 'standardizing the development process we can '
#                                 'diagnose and fix problem uh faster and more '
#                                 'accurately um so then as a ml team we have '
#                                 'also noticed some problems on our end as well '
#                                 'um and I will give you small introduction '
#                                 'introduction um as yob said earlier uh we use '
#                                 'CU flow and C flow pipeline components are '
#                                 'piece of code um that that perform specific '
#                                 'tasks in machine learning workflow such as '
#                                 'preparing data or training model um and after '
#                                 'some time we realize that realized that '
#                                 'certain steps in our machine learning '
#                                 'pipeline could be simplified',
#                         'timestamp_formatted': '15:51'},
#                        {'duration': 65,
#                         'end_time': 1072,
#                         'sequence': 20,
#                         'start_time': 1007,
#                         'text': 'or training model um and after some time we '
#                                 'realize that realized that certain steps in '
#                                 'our machine learning pipeline could be '
#                                 'simplified um steps that were repeated across '
#                                 'various use cases such as connecting to '
#                                 'external system and fetching or uploading '
#                                 'data from them uh were simplified and '
#                                 'implemented as as we called it uh reusable '
#                                 "components um as a result it's easier to "
#                                 'manage and update these steps uh we also '
#                                 'avoid the problem of code duplication um we '
#                                 'have more consistent steps in our pipelines '
#                                 'and there is less CS uh within a specific '
#                                 'pipeline um we are some somewhat moving '
#                                 'towards building pipelines uh as uh '
#                                 'assembling something from building blocks of '
#                                 "course as much as we can um and uh that's all "
#                                 'uh and to wrap',
#                         'timestamp_formatted': '16:47'},
#                        {'duration': 66,
#                         'end_time': 1124,
#                         'sequence': 21,
#                         'start_time': 1058,
#                         'text': 'building pipelines uh as uh assembling '
#                                 'something from building blocks of course as '
#                                 "much as we can um and uh that's all uh and to "
#                                 "wrap things up let's highlight the key points "
#                                 'of our approach when it comes to framework '
#                                 'but by naturally separating repositories we '
#                                 'gain flexibility in adopting the specific use '
#                                 'case regardless of the level of advancement '
#                                 'um at the same time we can fairly easy '
#                                 'implement the appropriate standards in them '
#                                 'and have great control over access to '
#                                 'individual repositories which signific '
#                                 'significantly um improves security um so then '
#                                 'we for standards on our side as Kuba as Jakob '
#                                 'said said earlier um when it comes to code '
#                                 'quality uh and development and testing we '
#                                 'also want to shift left and allow our '
#                                 'internal customers to benefit from these',
#                         'timestamp_formatted': '17:38'},
#                        {'duration': 66,
#                         'end_time': 1179,
#                         'sequence': 22,
#                         'start_time': 1113,
#                         'text': 'earlier um when it comes to code quality uh '
#                                 'and development and testing we also want to '
#                                 'shift left and allow our internal customers '
#                                 'to benefit from these standards making our '
#                                 'and their lives easier um having standards '
#                                 'implemented is a great entry point for '
#                                 'templating which ensures uh consistency is '
#                                 'less error prone and safe time um having '
#                                 "standards uh implemented um it's a great "
#                                 "opportunity to adopt um it's great uh yeah "
#                                 "it's great uh great opportunity to adopt um "
#                                 'templating which also saves time and ensures '
#                                 'consistency and uh the last one with '
#                                 "standards and templating in place it's a "
#                                 'great opportunity to adopt automation at '
#                                 'scale which reduce manual effort and speeds '
#                                 'up the uh for machine learning code to '
#                                 'machine learning',
#                         'timestamp_formatted': '18:33'}],
#  'transcript_stats': {'chunks_returned': 10,
#                       'time_filter_applied': True,
#                       'time_range': '10:28 - 19:39',
#                       'total_text_length': 7475}}

# %% [markdown]
# ### Test 6: Comprehensive Analysis with All Features
# **Query**: "Get everything about the optimization deployment talk - metadata, transcript, and related talks for complete analysis"
#
# This demonstrates the tool's full capabilities by retrieving complete talk information, transcript chunks, and related content in a single comprehensive query.

# %%
# Test 6: Comprehensive Analysis with All Features
result6 = get_talk_details.invoke({
    "talk_title": "Evaluation Techniques for Large Language Models",
    "include_transcript": True,
    "include_related": True,
    "max_chunks": 8,
    "related_count": 4
})

print("=== COMPREHENSIVE ANALYSIS ===")
pprint(result6)
# Out:
# === COMPREHENSIVE ANALYSIS ===
# {'related_talks': [{'category': 'Model dev, training, arch.',
#                     'similarity_score': 0.37,
#                     'speaker': 'Aniket Maurya',
#                     'title': 'Finetuning a large language model on a custom '
#                              'dataset',
#                     'views': 1110,
#                     'youtube_url': 'https://www.youtube.com/watch?v=OsD0KkyYXoY'},
#                    {'category': 'Model dev, training, arch.',
#                     'similarity_score': 0.372,
#                     'speaker': 'Rohit Saha, Kyryl Truskovskyi, Angeline '
#                                'Yasodhara, Benjamin Ye',
#                     'title': 'Leveraging Large Language Models to build '
#                              'Enterprise AI',
#                     'views': 145,
#                     'youtube_url': 'https://www.youtube.com/watch?v=BTYL-kLmhFE'},
#                    {'category': 'Model dev, training, arch.',
#                     'similarity_score': 0.391,
#                     'speaker': 'Niv Hertz',
#                     'title': "Monitoring LLMs: Where to Begin? What's "
#                              'Important?',
#                     'views': 52,
#                     'youtube_url': 'https://www.youtube.com/watch?v=Qje3tWudbMQ'},
#                    {'category': 'Security and Privacy',
#                     'similarity_score': 0.393,
#                     'speaker': 'Shashank Shekhar',
#                     'title': "A Practitioner's Guide To Safeguarding Your LLM "
#                              'Applications',
#                     'views': 151,
#                     'youtube_url': 'https://www.youtube.com/watch?v=NMYIj1U8DRM'}],
#  'success': True,
#  'summary': "Retrieved details for talk 'Evaluation Techniques for Large "
#             "Language Models' | 8 transcript chunks | 4 related talks",
#  'talk_info': {'abstract': 'Large language models (LLMs) represent an exciting '
#                            'trend in AI, with many new commercial and '
#                            'open-source models released recently. However, '
#                            'selecting the right LLM for your needs has become '
#                            'increasingly complex. This tutorial provides data '
#                            'scientists and machine learning engineers with '
#                            'practical tools and best practices for evaluating '
#                            'and choosing LLMs.\n'
#                            '\n'
#                            'The tutorial will cover the existing research on '
#                            'the capabilities of LLMs versus small traditional '
#                            'ML models. If an LLM is the best solution, the '
#                            'tutorial covers several techniques, including '
#                            'evaluation suites like the EleutherAI Harness, '
#                            'head-to-head competition approaches, and using '
#                            'LLMs for evaluating other LLMs. The tutorial will '
#                            'also touch on subtle factors that affect '
#                            'evaluation, including role of prompts, '
#                            'tokenization, and requirements for factual '
#                            'accuracy. Finally, a discussion of model bias and '
#                            'ethics will be integrated into the working '
#                            'examples.\n'
#                            '\n'
#                            'Attendees will gain an in-depth understanding of '
#                            'LLM evaluation tradeoffs and methods. Jupyter '
#                            'Notebooks will provide reusable code for each '
#                            'technique discussed.',
#                'category': 'Model dev, training, arch.',
#                'company': 'Hugging Face',
#                'duration': 'Unknown',
#                'event': 'MLOps & GenAI World 2023',
#                'industries': 'Banking & Financial Services, Insurance',
#                'keywords': None,
#                'published_date': '2024-05-15',
#                'speaker': 'Rajiv  Shah',
#                'speaker_details': {'bio': '',
#                                    'company': None,
#                                    'name': 'Rajiv  Shah'},
#                'talk_id': '11e00af4-e7a6-5406-9025-79af0439f1ee',
#                'tech_level': 5,
#                'title': 'Evaluation Techniques for Large Language Models',
#                'track': 'Advanced Technical/Research',
#                'views': 575,
#                'youtube_url': 'https://www.youtube.com/watch?v=vqO7ks7DFZw'},
#  'transcript_chunks': [{'duration': 61,
#                         'end_time': 66,
#                         'sequence': 1,
#                         'start_time': 5,
#                         'text': "thank you all for coming it's going to be a "
#                                 "lot of fun it's going to be intense we're "
#                                 'going to throw a lot of stuff at you here so '
#                                 'feel free kind of sit in the back sit in the '
#                                 'front wherever if you need to get up and '
#                                 "stretch your legs I'm not going to be "
#                                 "offended through this now I've got a couple "
#                                 "pieces of key information that you're going "
#                                 'to want for this presentation one is I have '
#                                 'the GitHub repo here the GitHub repo has two '
#                                 'things that are important one is it has a '
#                                 'copy of the slide as I go through this I got '
#                                 'like 150 slides I got references on the '
#                                 "slides inevitably you'll care more about one "
#                                 'or two of the slides than others so if you '
#                                 'can if you have the slides pulled up you want '
#                                 'to click on a reference look at a paper feel '
#                                 'free to do that the other thing is I have a '
#                                 'couple of notebooks the idea here is I want '
#                                 'to give you working examples of how all this '
#                                 "stuff works now I'm not going to force us to "
#                                 'sit and work through the notebook cell byell '
#                                 "here I find that that's an ineffective time "
#                                 "of this I'll walk through on my computer and "
#                                 'show you some of the notebooks and show you '
#                                 "the important places for the code but you're",
#                         'timestamp_formatted': '0:05'},
#                        {'duration': 64,
#                         'end_time': 118,
#                         'sequence': 2,
#                         'start_time': 54,
#                         'text': 'sit and work through the notebook cell byell '
#                                 "here I find that that's an ineffective time "
#                                 "of this I'll walk through on my computer and "
#                                 'show you some of the notebooks and show you '
#                                 "the important places for the code but you're "
#                                 'not expected to kind of run the notebooks '
#                                 'yourselves I just know how complicated that '
#                                 "gets inside this all right I'll take breaks "
#                                 'during this to be to ask for questions as '
#                                 'well if you have a burning question you want '
#                                 "to ask feel free to spit it out as well I'll "
#                                 'try to kind of manage the time and if we get '
#                                 'short on time or something I might run '
#                                 "through it but we'll have some fun and get "
#                                 'through this two other things I want to '
#                                 "mention um on here that's important is one is "
#                                 'my contact information and you might want to '
#                                 'get a hold of me on LinkedIn if you care '
#                                 'about the business stuff if you want more '
#                                 'resources around evaluation you want to hear '
#                                 "me talk about that that's cool the other "
#                                 'thing is if you get a little bored you need a '
#                                 'little bit of entertainment I make Tik toks '
#                                 'and other short videos as well so if you like '
#                                 'that Vibe I got you',
#                         'timestamp_formatted': '0:54'},
#                        {'duration': 63,
#                         'end_time': 166,
#                         'sequence': 3,
#                         'start_time': 103,
#                         'text': 'resources around evaluation you want to hear '
#                                 "me talk about that that's cool the other "
#                                 'thing is if you get a little bored you need a '
#                                 'little bit of entertainment I make Tik toks '
#                                 'and other short videos as well so if you like '
#                                 'that Vibe I got you covered as well so feel '
#                                 'free to kind of follow along with that as '
#                                 'well all right so I work at hugging face and '
#                                 'I work with a lot of our Enterprise customers '
#                                 "and what I see every day now that we've had "
#                                 'this generative AI explosion is I go to all '
#                                 'these companies I see probably hundreds of '
#                                 'companies in a given year and everywhere you '
#                                 'have these machine learning Engineers the '
#                                 "developers the data scientists they're all "
#                                 'out there trying out these El M trying out '
#                                 'these generative AIS and what I see a lot of '
#                                 "it from my perspective is they're just doing "
#                                 "a lot of experimenting they're trying new "
#                                 "things which is good but what they're really "
#                                 'doing is just running lots of science '
#                                 'experiments and the problem is and especially '
#                                 'for a lot of',
#                         'timestamp_formatted': '1:43'},
#                        {'duration': 59,
#                         'end_time': 215,
#                         'sequence': 4,
#                         'start_time': 156,
#                         'text': "doing a lot of experimenting they're trying "
#                                 "new things which is good but what they're "
#                                 'really doing is just running lots of science '
#                                 'experiments and the problem is and especially '
#                                 'for a lot of the crowd here that cares about '
#                                 'getting things into production is what '
#                                 "they're building things it's like Homer "
#                                 "Simpson's car like they're just full of "
#                                 'features totally unrealistic without '
#                                 'consideration of actually how we would '
#                                 "productionize this and so that's some of the "
#                                 'discipline I want to bring today is to talk '
#                                 'about how we can take these gener of AI '
#                                 "projects and have impact and here when I'm "
#                                 "talking about impact we're going to of course "
#                                 'focus on the technical the majority of this '
#                                 'is going to talk about technical ways we can '
#                                 "evaluate models but we're also going to talk "
#                                 'about the business um the earlier talk by '
#                                 'datab bricks also mentioned this as well '
#                                 'thinking about the business side of it as '
#                                 'well as the operational total cost of '
#                                 'ownership of these things as well um now '
#                                 "along the way I'm going to focus",
#                         'timestamp_formatted': '2:36'},
#                        {'duration': 60,
#                         'end_time': 263,
#                         'sequence': 5,
#                         'start_time': 203,
#                         'text': 'by datab bricks also mentioned this as well '
#                                 'thinking about the business side of it as '
#                                 'well as the operational total cost of '
#                                 'ownership of these things as well um now '
#                                 "along the way I'm going to focus largely on "
#                                 "technical evaluation we're going to work our "
#                                 'way through a lot of the different ways to '
#                                 "think about evaluating these models I've got "
#                                 'some ways to kind of hopefully summarize it '
#                                 'make our head get our heads around it a '
#                                 "little bit easier like that but that's the "
#                                 'thrust of it at the end I want to apply this '
#                                 "to a use case so we're going to just do rag "
#                                 'and I just explaining and the idea here is '
#                                 'just applying these Concepts to a widely used '
#                                 "use case all right so that's the plan one "
#                                 'other thing I forgot to mention but some of '
#                                 'you especially the ones in the back if you '
#                                 'want to get a little bit of social cred feel '
#                                 'free to take a couple of pictures tag hugging '
#                                 'face because all we care about is social '
#                                 'media to peers and tag me and tag social '
#                                 'media and put',
#                         'timestamp_formatted': '3:23'},
#                        {'duration': 65,
#                         'end_time': 315,
#                         'sequence': 6,
#                         'start_time': 250,
#                         'text': 'of you especially the ones in the back if you '
#                                 'want to get a little bit of social cred feel '
#                                 'free to take a couple of pictures tag hugging '
#                                 'face because all we care about is social '
#                                 'media to peers and tag me and tag social '
#                                 'media and put it on Linkin or Twitter '
#                                 'whatever um like that will be that all right '
#                                 'so hopefully you all the repo share it '
#                                 "amongst yourselves if you don't again you get "
#                                 'the slides and notebooks like that any '
#                                 'burning questions before I kind of jump into '
#                                 'this everyone with me so far good good all '
#                                 'right so when we talk about gender of AI '
#                                 'large language models we can use these in a '
#                                 'lot of different ways we can do things like '
#                                 'summarization ask questions even do code '
#                                 'generation with these things and so what this '
#                                 "means is there's just so many ways ways to "
#                                 'think about how to evaluate these models it '
#                                 'gets very difficult to do that and if we go '
#                                 'and look at how people are doing it one of '
#                                 "the most popular benchmarks that's out there "
#                                 "is comes out of Stanford it's the holistic "
#                                 'evaluation of language models the helm',
#                         'timestamp_formatted': '4:10'},
#                        {'duration': 64,
#                         'end_time': 366,
#                         'sequence': 7,
#                         'start_time': 302,
#                         'text': 'these models it gets very difficult to do '
#                                 'that and if we go and look at how people are '
#                                 'doing it one of the most popular benchmarks '
#                                 "that's out there is comes out of Stanford "
#                                 "it's the holistic evaluation of language "
#                                 "models the helm benchmarks and what they've "
#                                 "done is they've looked at these large "
#                                 'language models and looked at many models '
#                                 'across lots of different data sets using lots '
#                                 "of different metrics they've published that "
#                                 "all out there it's an enormous amount of "
#                                 'information if you just look at the paper '
#                                 "alone that they have it's 160 some odd pages "
#                                 'and I have too much time on my hand I did the '
#                                 "word count of this and you would it's the "
#                                 'same amount of reading as if you read a Harry '
#                                 "Potter book like that's how much information "
#                                 "right and you don't want to spend your time "
#                                 'right reading a reading a paper that long but '
#                                 "that's how much detailed information there is "
#                                 "it's just overwhelming if you're just trying "
#                                 "to like I'm trying to solve a problem now "
#                                 "there's other people have tried other things "
#                                 'so hugging face where',
#                         'timestamp_formatted': '5:02'},
#                        {'duration': 61,
#                         'end_time': 414,
#                         'sequence': 8,
#                         'start_time': 353,
#                         'text': "that long but that's how much detailed "
#                                 "information there is it's just overwhelming "
#                                 "if you're just trying to like I'm trying to "
#                                 "solve a problem now there's other people have "
#                                 'tried other things so hugging face where I '
#                                 'work at has built a leaderboard right the '
#                                 "idea is let's rank the bottles to make it "
#                                 'easier for people to do it the leaderboard at '
#                                 'this point embarrassingly has over 2,000 '
#                                 "different large language models and it's just "
#                                 'a little bit too overwhelming if you go to go '
#                                 "and look at it now and I'm sure many of you "
#                                 "who've worked in large language models know "
#                                 'about this leaderboard like that so it had '
#                                 "good intentions but I'm not sure exactly how "
#                                 'useful it is for most people and you know '
#                                 'this is the kind of the vibe you get is if '
#                                 "you're in the space and trying to figure it "
#                                 'out if you peel one layer beneath like I '
#                                 "really want to use this stuff you'll see that "
#                                 "for example with Helm they've looked at data "
#                                 'sets in particular categories but if you just',
#                         'timestamp_formatted': '5:53'}],
#  'transcript_stats': {'chunks_returned': 8,
#                       'time_filter_applied': False,
#                       'time_range': '0:05 - 6:54',
#                       'total_text_length': 8163}}

# %% [markdown]
# ### Test 9: Late-Stage Content Analysis
# **Query**: "Analyze the final 10 minutes of a talk to understand conclusions, Q&A, and key takeaways"
#
# This focuses on the end of a presentation to capture conclusions, final insights, and Q&A sessions which often contain valuable practical insights and audience interactions.

# %%
# Test 9: Late-Stage Content Analysis  
result9 = get_talk_details.invoke({
    "talk_title": "LLMs, Big Data, and Audio: Breaching an Untapped Gold Mine",
    "include_transcript": True,
    "time_start": 1800,  # Last 10 minutes (assuming ~30 min talk)
    "max_chunks": 8
})

print("=== FINAL 10 MINUTES ANALYSIS ===")
pprint(result9)
# Out:
# === FINAL 10 MINUTES ANALYSIS ===
# {'related_talks': [],
#  'success': True,
#  'summary': "Retrieved details for talk 'LLMs, Big Data, and Audio: Breaching "
#             "an Untapped Gold Mine' | 0 transcript chunks | with time "
#             'filtering',
#  'talk_info': {'abstract': 'Large language models like those in the GPT and '
#                            'Llama series are primarily trained on massive '
#                            'amounts of *text* data. However, the vast majority '
#                            "of language and communication doesn't take place "
#                            'over text, but rather through voice. Cues in vocal '
#                            'tone carry information that the plaintext cannot '
#                            "convey—think about the last time you've witnessed "
#                            'or experienced a miscommunication over '
#                            'text/email/Slack. Thus, in this talk, I argue that '
#                            'training language models on audio data is the next '
#                            "step to improving them. Then, I'll propose a way "
#                            'of integrating audio data with text data in a '
#                            'larger dataset that can then be used for training '
#                            'various LLMs.',
#                'category': 'Model dev, training, arch.',
#                'company': 'Deepgram',
#                'duration': 'Unknown',
#                'event': 'MLOps & GenAI World 2023',
#                'industries': None,
#                'keywords': None,
#                'published_date': '2023-11-02',
#                'speaker': 'Jose Nicholas Francisco',
#                'speaker_details': {'bio': '',
#                                    'company': None,
#                                    'name': 'Jose Nicholas Francisco'},
#                'talk_id': '95c82848-d9f9-54c3-a7eb-2f3fed38adac',
#                'tech_level': None,
#                'title': 'LLMs, Big Data, and Audio: Breaching an Untapped Gold '
#                         'Mine',
#                'track': 'Ignite Lightning Talk',
#                'views': 59,
#                'youtube_url': 'https://www.youtube.com/watch?v=5Uju4DP7XLY'},
#  'transcript_chunks': [],
#  'transcript_stats': {'chunks_returned': 0,
#                       'time_filter_applied': True,
#                       'time_range': '0:00 - 0:00',
#                       'total_text_length': 0}}

# %% [markdown]
# ### Test 10: Brief Transcript Sample for Quick Overview
# **Query**: "Get just a few transcript chunks from the Kubernetes talk for a quick content preview"
#
# This demonstrates using minimal transcript chunks for quick content sampling, useful when you want a brief overview without extensive transcript analysis.

# %%
# Test 10: Brief Transcript Sample for Quick Overview
result10 = get_talk_details.invoke({
    "talk_title": "Evaluation Techniques for Large Language Models",
    "include_transcript": True,
    "max_chunks": 3
})

print("=== BRIEF TRANSCRIPT SAMPLE ===")
pprint(result10)
# Out:
# === BRIEF TRANSCRIPT SAMPLE ===
# {'related_talks': [],
#  'success': True,
#  'summary': "Retrieved details for talk 'Evaluation Techniques for Large "
#             "Language Models' | 3 transcript chunks",
#  'talk_info': {'abstract': 'Large language models (LLMs) represent an exciting '
#                            'trend in AI, with many new commercial and '
#                            'open-source models released recently. However, '
#                            'selecting the right LLM for your needs has become '
#                            'increasingly complex. This tutorial provides data '
#                            'scientists and machine learning engineers with '
#                            'practical tools and best practices for evaluating '
#                            'and choosing LLMs.\n'
#                            '\n'
#                            'The tutorial will cover the existing research on '
#                            'the capabilities of LLMs versus small traditional '
#                            'ML models. If an LLM is the best solution, the '
#                            'tutorial covers several techniques, including '
#                            'evaluation suites like the EleutherAI Harness, '
#                            'head-to-head competition approaches, and using '
#                            'LLMs for evaluating other LLMs. The tutorial will '
#                            'also touch on subtle factors that affect '
#                            'evaluation, including role of prompts, '
#                            'tokenization, and requirements for factual '
#                            'accuracy. Finally, a discussion of model bias and '
#                            'ethics will be integrated into the working '
#                            'examples.\n'
#                            '\n'
#                            'Attendees will gain an in-depth understanding of '
#                            'LLM evaluation tradeoffs and methods. Jupyter '
#                            'Notebooks will provide reusable code for each '
#                            'technique discussed.',
#                'category': 'Model dev, training, arch.',
#                'company': 'Hugging Face',
#                'duration': 'Unknown',
#                'event': 'MLOps & GenAI World 2023',
#                'industries': 'Banking & Financial Services, Insurance',
#                'keywords': None,
#                'published_date': '2024-05-15',
#                'speaker': 'Rajiv  Shah',
#                'speaker_details': {'bio': '',
#                                    'company': None,
#                                    'name': 'Rajiv  Shah'},
#                'talk_id': '11e00af4-e7a6-5406-9025-79af0439f1ee',
#                'tech_level': 5,
#                'title': 'Evaluation Techniques for Large Language Models',
#                'track': 'Advanced Technical/Research',
#                'views': 575,
#                'youtube_url': 'https://www.youtube.com/watch?v=vqO7ks7DFZw'},
#  'transcript_chunks': [{'duration': 61,
#                         'end_time': 66,
#                         'sequence': 1,
#                         'start_time': 5,
#                         'text': "thank you all for coming it's going to be a "
#                                 "lot of fun it's going to be intense we're "
#                                 'going to throw a lot of stuff at you here so '
#                                 'feel free kind of sit in the back sit in the '
#                                 'front wherever if you need to get up and '
#                                 "stretch your legs I'm not going to be "
#                                 "offended through this now I've got a couple "
#                                 "pieces of key information that you're going "
#                                 'to want for this presentation one is I have '
#                                 'the GitHub repo here the GitHub repo has two '
#                                 'things that are important one is it has a '
#                                 'copy of the slide as I go through this I got '
#                                 'like 150 slides I got references on the '
#                                 "slides inevitably you'll care more about one "
#                                 'or two of the slides than others so if you '
#                                 'can if you have the slides pulled up you want '
#                                 'to click on a reference look at a paper feel '
#                                 'free to do that the other thing is I have a '
#                                 'couple of notebooks the idea here is I want '
#                                 'to give you working examples of how all this '
#                                 "stuff works now I'm not going to force us to "
#                                 'sit and work through the notebook cell byell '
#                                 "here I find that that's an ineffective time "
#                                 "of this I'll walk through on my computer and "
#                                 'show you some of the notebooks and show you '
#                                 "the important places for the code but you're",
#                         'timestamp_formatted': '0:05'},
#                        {'duration': 64,
#                         'end_time': 118,
#                         'sequence': 2,
#                         'start_time': 54,
#                         'text': 'sit and work through the notebook cell byell '
#                                 "here I find that that's an ineffective time "
#                                 "of this I'll walk through on my computer and "
#                                 'show you some of the notebooks and show you '
#                                 "the important places for the code but you're "
#                                 'not expected to kind of run the notebooks '
#                                 'yourselves I just know how complicated that '
#                                 "gets inside this all right I'll take breaks "
#                                 'during this to be to ask for questions as '
#                                 'well if you have a burning question you want '
#                                 "to ask feel free to spit it out as well I'll "
#                                 'try to kind of manage the time and if we get '
#                                 'short on time or something I might run '
#                                 "through it but we'll have some fun and get "
#                                 'through this two other things I want to '
#                                 "mention um on here that's important is one is "
#                                 'my contact information and you might want to '
#                                 'get a hold of me on LinkedIn if you care '
#                                 'about the business stuff if you want more '
#                                 'resources around evaluation you want to hear '
#                                 "me talk about that that's cool the other "
#                                 'thing is if you get a little bored you need a '
#                                 'little bit of entertainment I make Tik toks '
#                                 'and other short videos as well so if you like '
#                                 'that Vibe I got you',
#                         'timestamp_formatted': '0:54'},
#                        {'duration': 63,
#                         'end_time': 166,
#                         'sequence': 3,
#                         'start_time': 103,
#                         'text': 'resources around evaluation you want to hear '
#                                 "me talk about that that's cool the other "
#                                 'thing is if you get a little bored you need a '
#                                 'little bit of entertainment I make Tik toks '
#                                 'and other short videos as well so if you like '
#                                 'that Vibe I got you covered as well so feel '
#                                 'free to kind of follow along with that as '
#                                 'well all right so I work at hugging face and '
#                                 'I work with a lot of our Enterprise customers '
#                                 "and what I see every day now that we've had "
#                                 'this generative AI explosion is I go to all '
#                                 'these companies I see probably hundreds of '
#                                 'companies in a given year and everywhere you '
#                                 'have these machine learning Engineers the '
#                                 "developers the data scientists they're all "
#                                 'out there trying out these El M trying out '
#                                 'these generative AIS and what I see a lot of '
#                                 "it from my perspective is they're just doing "
#                                 "a lot of experimenting they're trying new "
#                                 "things which is good but what they're really "
#                                 'doing is just running lots of science '
#                                 'experiments and the problem is and especially '
#                                 'for a lot of',
#                         'timestamp_formatted': '1:43'}],
#  'transcript_stats': {'chunks_returned': 3,
#                       'time_filter_applied': False,
#                       'time_range': '0:05 - 2:46',
#                       'total_text_length': 3181}}

# %% [markdown]
# ### Test 11: Error Handling - Non-Existent Talk
# **Query**: "Test error handling by requesting details for a talk that doesn't exist"
#
# This tests the tool's error handling capabilities when a talk title is not found, ensuring graceful failure modes and informative error messages.

# %%
# Test 11: Error Handling - Non-Existent Talk
result11 = get_talk_details.invoke({
    "talk_title": "This Talk Does Not Exist In The Database"
})

print("=== ERROR HANDLING TEST ===")
pprint(result11)
# Out:
# === ERROR HANDLING TEST ===
# {'error': '0',
#  'related_talks': [],
#  'success': False,
#  'summary': 'Failed to retrieve talk details',
#  'talk_info': {},
#  'transcript_chunks': [],
#  'transcript_stats': {}}

# %% [markdown]
# ### Test 12: Input Validation - Missing Parameters
# **Query**: "Test input validation by calling the tool without required parameters"
#
# This tests the tool's input validation to ensure proper error messages when neither talk_title nor talk_id is provided, validating the parameter requirements.

# %%
# Test 12: Input Validation - Missing Parameters
print("\n=== Test 12: Input Validation - Missing Parameters ===")
try:
    result = get_talk_details.invoke({})
    print(f"Result: {result}")
except Exception as e:
    print(f"Expected error: {e}")
    print("✅ Tool properly validated required parameters")
# Out:
# === Test 12: Input Validation - Missing Parameters ===
# Result: {'talk_info': {}, 'transcript_chunks': [], 'related_talks': [], 'summary': 'Error: Either talk_title or talk_id must be provided', 'transcript_stats': {}, 'success': False, 'error': "Missing required parameter: either 'talk_title' or 'talk_id' must be specified"}
