# %%
# Import required libraries and tools
import os
import sys
import json
from pprint import pprint

# Load environment variables
from dotenv import load_dotenv
load_dotenv()

# Add tools directory to path
sys.path.append('.')

# Import all our tools
from search_talks_by_filters import search_talks_by_filters
from search_talks_semantically import search_talks_semantically
from analyze_speaker_activity import analyze_speaker_activity
from get_talk_details import get_talk_details
from find_similar_content import find_similar_content
from analyze_topics_and_trends import analyze_topics_and_trends

print("✅ All tools imported successfully!")
print(f"🔑 ApertureDB Key configured: {'Yes' if os.getenv('APERTUREDB_KEY') else 'No'}")

# Helper function for pretty printing results
def print_results(result, max_results=5):
    """Pretty print tool results with truncation"""
    if isinstance(result, dict) and 'results' in result:
        print(f"Total found: {result.get('total_found', 'Unknown')}")
        if result.get('query_summary'):
            print(f"Query: {result['query_summary']}")
        if result.get('sort_info'):
            print(f"Sorting: {result['sort_info']}")
        
        results = result['results'][:max_results]
        for i, talk in enumerate(results, 1):
            print(f"\n{i}. {talk.get('title', 'No Title')}")
            print(f"   Speaker: {talk.get('speaker', 'Unknown')}")
            print(f"   Company: {talk.get('company', 'Unknown')}")
            print(f"   Views: {talk.get('views', 0):,}")
            if talk.get('published_date'):
                print(f"   Date: {talk['published_date']}")
    else:
        pprint(result)
# Out:
# ✅ All tools imported successfully!
# 🔑 ApertureDB Key configured: Yes

# %% [markdown]
# ## Tool 3: `analyze_speaker_activity` - Comprehensive Speaker Analytics Testing
#
# This tool analyzes speaker activity patterns, frequency, topics, and company representation across the MLOps events dataset. It provides comprehensive speaker-centric analytics including talk counts, topic diversity, company breakdown, and repeat speaker identification.
#
# ### Test 1: Individual Speaker Deep Dive Analysis
# **Query**: "Analyze all activity and talks by Chip Huyen - how many talks, topics covered, engagement metrics"
#
# This performs a detailed analysis of a specific speaker, showing their complete talk history, view statistics, topic diversity, and presentation timeline.

# %%
# Test 1: Individual Speaker Deep Dive Analysis
result1 = analyze_speaker_activity.invoke({
    "speaker_name": "Chip Huyen", 
    "analysis_type": "all"
})

print("=== INDIVIDUAL SPEAKER ANALYSIS ===")
pprint(result1)
# Out:
# === INDIVIDUAL SPEAKER ANALYSIS ===
# {'analysis_summary': "Detailed analysis for speaker 'Chip Huyen'",
#  'company_breakdown': {},
#  'repeat_speakers': [],
#  'speaker_stats': [{'avg_views': 844,
#                     'categories_covered': ['Model dev, training, arch.'],
#                     'companies': ['Claypot AI'],
#                     'events_participated': ['TMLS 2022'],
#                     'speaker_name': 'Chip Huyen',
#                     'talk_list': [{'abstract': 'Fresh data beats stale data '
#                                                'for machine learning '
#                                                'applications. This talk '
#                                                'discusses the value of fresh '
#                                                'data as well as different '
#                                                'types of architecture ...',
#                                    'category': 'Model dev, training, arch.',
#                                    'date': '2023-08-17',
#                                    'event': 'TMLS 2022',
#                                    'title': 'Real-time Machine Learning: '
#                                             'Architecture and Challenges',
#                                    'views': 844,
#                                    'youtube_url': 'https://www.youtube.com/watch?v=S4A8QWN1G7s'}],
#                     'total_talks': 1,
#                     'total_views': 844}],
#  'success': True,
#  'topic_analysis': {},
#  'total_speakers': 1}

# %% [markdown]
# ### Test 2: Repeat Speaker Discovery
# **Query**: "Find all speakers who presented multiple times (2+ talks) and rank by frequency"
#
# This identifies repeat speakers in the dataset, showing who are the most active presenters. The min_talk_count=2 filter ensures we only get speakers with multiple presentations.

# %%
# Test 2: Repeat Speaker Discovery
result2 = analyze_speaker_activity.invoke({
    "min_talk_count": 2,
    "analysis_type": "all",
    "limit": 15
})

print("=== REPEAT SPEAKERS ANALYSIS ===")
pprint(result2)
# Out:
# === REPEAT SPEAKERS ANALYSIS ===
# {'analysis_summary': 'Speaker activity analysis: speaker talk counts, company '
#                      'representation',
#  'company_breakdown': [{'company': 'Aporia', 'speaker_count': 7},
#                        {'company': 'Outerbounds', 'speaker_count': 5},
#                        {'company': 'Lightning AI', 'speaker_count': 4},
#                        {'company': 'Loblaw Digital', 'speaker_count': 4},
#                        {'company': 'Scotiabank', 'speaker_count': 4},
#                        {'company': 'Google', 'speaker_count': 3},
#                        {'company': 'Wealthsimple', 'speaker_count': 3},
#                        {'company': 'RBC', 'speaker_count': 3},
#                        {'company': 'Armilla AI', 'speaker_count': 3},
#                        {'company': 'Hugging Face', 'speaker_count': 3},
#                        {'company': 'Vector Institute', 'speaker_count': 3},
#                        {'company': 'Seldon', 'speaker_count': 3},
#                        {'company': 'DVC', 'speaker_count': 3},
#                        {'company': 'Union.ai', 'speaker_count': 3},
#                        {'company': 'AI Makerspace', 'speaker_count': 3},
#                        {'company': 'VESSL AI', 'speaker_count': 2},
#                        {'company': 'Instacart', 'speaker_count': 2},
#                        {'company': 'LakeFS', 'speaker_count': 2},
#                        {'company': 'University of Toronto', 'speaker_count': 2},
#                        {'company': 'Grammarly', 'speaker_count': 2}],
#  'repeat_speakers': [{'avg_views': 510,
#                       'categories': ['Deployment and integration',
#                                      'Model dev, training, arch.'],
#                       'companies': ['Lightning AI'],
#                       'events': ['MLOps & GenAI World 2024',
#                                  'MLOps & GenAI World 2023',
#                                  'TMLS 2024'],
#                       'speaker_name': 'Aniket Maurya',
#                       'total_talks': 3,
#                       'total_views': 1529},
#                      {'avg_views': 28,
#                       'categories': ['Ethics, governance compliance'],
#                       'companies': ['Armilla AI', 'AutoAlign AI'],
#                       'events': ['TMLS 2022',
#                                  'MLOps & GenAI World 2024',
#                                  'TMLS 2023'],
#                       'speaker_name': 'Dan Adamson',
#                       'total_talks': 3,
#                       'total_views': 83},
#                      {'avg_views': 292,
#                       'categories': ['Model dev, training, arch.'],
#                       'companies': ['AI Makerspace'],
#                       'events': ['MLOps & GenAI World 2024', 'TMLS 2024'],
#                       'speaker_name': 'Greg Loughnane, Chris Alexiuk',
#                       'total_talks': 3,
#                       'total_views': 876},
#                      {'avg_views': 65,
#                       'categories': ['Deployment and integration',
#                                      'Introduction to MLOps and GenAI'],
#                       'companies': ['Outerbounds'],
#                       'events': ['MLOps & GenAI World 2024',
#                                  'MLOps & GenAI World 2023'],
#                       'speaker_name': 'Eddie Mattia',
#                       'total_talks': 2,
#                       'total_views': 130},
#                      {'avg_views': 13,
#                       'categories': ['Ethics, governance compliance'],
#                       'companies': ['Arya.ai'],
#                       'events': ['MLOps & GenAI World 2024'],
#                       'speaker_name': 'Vinay Kumar Sankarapu',
#                       'total_talks': 2,
#                       'total_views': 26},
#                      {'avg_views': 2227,
#                       'categories': ['Ethics, governance compliance',
#                                      'Performance optimization and efficiency'],
#                       'companies': ['Layer 6 AI', 'Layer 6 AI @ TD'],
#                       'events': ['TMLS 2022', 'TMLS 2023'],
#                       'speaker_name': 'Jesse Cresswell',
#                       'total_talks': 2,
#                       'total_views': 4454},
#                      {'avg_views': 143,
#                       'categories': ['Deployment and integration'],
#                       'companies': ['THE FULL STACK', 'Modal Labs'],
#                       'events': ['MLOps & GenAI World 2024',
#                                  'MLOps & GenAI World 2023'],
#                       'speaker_name': 'Charles Frye',
#                       'total_talks': 2,
#                       'total_views': 286},
#                      {'avg_views': 140,
#                       'categories': ['Deployment and integration',
#                                      'Model dev, training, arch.'],
#                       'companies': ['Featureform'],
#                       'events': ['MLOps & GenAI World 2024',
#                                  'MLOps & GenAI World 2023'],
#                       'speaker_name': 'Simba Khadder',
#                       'total_talks': 2,
#                       'total_views': 281},
#                      {'avg_views': 80,
#                       'categories': ['Introduction to MLOps and GenAI',
#                                      'Performance optimization and efficiency'],
#                       'companies': ['Aporia'],
#                       'events': ['TMLS 2022', 'MLOps & GenAI World 2023'],
#                       'speaker_name': 'Marcelo Litovsky',
#                       'total_talks': 2,
#                       'total_views': 160},
#                      {'avg_views': 58,
#                       'categories': ['Introduction to MLOps and GenAI'],
#                       'companies': ['Anaconda', 'Mistral AI'],
#                       'events': ['MLOps & GenAI World 2024'],
#                       'speaker_name': 'Sophia  Yang',
#                       'total_talks': 2,
#                       'total_views': 116},
#                      {'avg_views': 462,
#                       'categories': ['Introduction to MLOps and GenAI',
#                                      'Model dev, training, arch.'],
#                       'companies': ['Outerbounds'],
#                       'events': ['MLOps & GenAI World 2023', 'TMLS 2024'],
#                       'speaker_name': 'Ville Tuulos, Eddie Mattia',
#                       'total_talks': 2,
#                       'total_views': 924},
#                      {'avg_views': 82,
#                       'categories': ['Model dev, training, arch.',
#                                      'Performance optimization and efficiency'],
#                       'companies': ['Aporia', 'Solutions Architect'],
#                       'events': ['TMLS 2023', 'MLOps & GenAI World 2023'],
#                       'speaker_name': 'Niv Hertz',
#                       'total_talks': 2,
#                       'total_views': 165},
#                      {'avg_views': 766,
#                       'categories': ['Model dev, training, arch.',
#                                      'Performance optimization and efficiency'],
#                       'companies': ['Union.ai'],
#                       'events': ['MLOps & GenAI World 2024',
#                                  'MLOps & GenAI World 2023'],
#                       'speaker_name': 'Niels Bantilan',
#                       'total_talks': 2,
#                       'total_views': 1531},
#                      {'avg_views': 216,
#                       'categories': ['Deployment and integration',
#                                      'Introduction to MLOps and GenAI'],
#                       'companies': ['ZenML'],
#                       'events': ['MLOps & GenAI World 2024',
#                                  'MLOps & GenAI World 2023'],
#                       'speaker_name': 'Adam Probst',
#                       'total_talks': 2,
#                       'total_views': 432}],
#  'speaker_stats': [{'avg_views': 510,
#                     'categories': ['Deployment and integration',
#                                    'Model dev, training, arch.'],
#                     'companies': ['Lightning AI'],
#                     'events': ['MLOps & GenAI World 2024',
#                                'MLOps & GenAI World 2023',
#                                'TMLS 2024'],
#                     'speaker_name': 'Aniket Maurya',
#                     'total_talks': 3,
#                     'total_views': 1529},
#                    {'avg_views': 28,
#                     'categories': ['Ethics, governance compliance'],
#                     'companies': ['Armilla AI', 'AutoAlign AI'],
#                     'events': ['TMLS 2022',
#                                'MLOps & GenAI World 2024',
#                                'TMLS 2023'],
#                     'speaker_name': 'Dan Adamson',
#                     'total_talks': 3,
#                     'total_views': 83},
#                    {'avg_views': 292,
#                     'categories': ['Model dev, training, arch.'],
#                     'companies': ['AI Makerspace'],
#                     'events': ['MLOps & GenAI World 2024', 'TMLS 2024'],
#                     'speaker_name': 'Greg Loughnane, Chris Alexiuk',
#                     'total_talks': 3,
#                     'total_views': 876},
#                    {'avg_views': 65,
#                     'categories': ['Deployment and integration',
#                                    'Introduction to MLOps and GenAI'],
#                     'companies': ['Outerbounds'],
#                     'events': ['MLOps & GenAI World 2024',
#                                'MLOps & GenAI World 2023'],
#                     'speaker_name': 'Eddie Mattia',
#                     'total_talks': 2,
#                     'total_views': 130},
#                    {'avg_views': 13,
#                     'categories': ['Ethics, governance compliance'],
#                     'companies': ['Arya.ai'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Vinay Kumar Sankarapu',
#                     'total_talks': 2,
#                     'total_views': 26},
#                    {'avg_views': 2227,
#                     'categories': ['Ethics, governance compliance',
#                                    'Performance optimization and efficiency'],
#                     'companies': ['Layer 6 AI', 'Layer 6 AI @ TD'],
#                     'events': ['TMLS 2022', 'TMLS 2023'],
#                     'speaker_name': 'Jesse Cresswell',
#                     'total_talks': 2,
#                     'total_views': 4454},
#                    {'avg_views': 143,
#                     'categories': ['Deployment and integration'],
#                     'companies': ['THE FULL STACK', 'Modal Labs'],
#                     'events': ['MLOps & GenAI World 2024',
#                                'MLOps & GenAI World 2023'],
#                     'speaker_name': 'Charles Frye',
#                     'total_talks': 2,
#                     'total_views': 286},
#                    {'avg_views': 140,
#                     'categories': ['Deployment and integration',
#                                    'Model dev, training, arch.'],
#                     'companies': ['Featureform'],
#                     'events': ['MLOps & GenAI World 2024',
#                                'MLOps & GenAI World 2023'],
#                     'speaker_name': 'Simba Khadder',
#                     'total_talks': 2,
#                     'total_views': 281},
#                    {'avg_views': 80,
#                     'categories': ['Introduction to MLOps and GenAI',
#                                    'Performance optimization and efficiency'],
#                     'companies': ['Aporia'],
#                     'events': ['TMLS 2022', 'MLOps & GenAI World 2023'],
#                     'speaker_name': 'Marcelo Litovsky',
#                     'total_talks': 2,
#                     'total_views': 160},
#                    {'avg_views': 58,
#                     'categories': ['Introduction to MLOps and GenAI'],
#                     'companies': ['Anaconda', 'Mistral AI'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Sophia  Yang',
#                     'total_talks': 2,
#                     'total_views': 116},
#                    {'avg_views': 462,
#                     'categories': ['Introduction to MLOps and GenAI',
#                                    'Model dev, training, arch.'],
#                     'companies': ['Outerbounds'],
#                     'events': ['MLOps & GenAI World 2023', 'TMLS 2024'],
#                     'speaker_name': 'Ville Tuulos, Eddie Mattia',
#                     'total_talks': 2,
#                     'total_views': 924},
#                    {'avg_views': 82,
#                     'categories': ['Model dev, training, arch.',
#                                    'Performance optimization and efficiency'],
#                     'companies': ['Aporia', 'Solutions Architect'],
#                     'events': ['TMLS 2023', 'MLOps & GenAI World 2023'],
#                     'speaker_name': 'Niv Hertz',
#                     'total_talks': 2,
#                     'total_views': 165},
#                    {'avg_views': 766,
#                     'categories': ['Model dev, training, arch.',
#                                    'Performance optimization and efficiency'],
#                     'companies': ['Union.ai'],
#                     'events': ['MLOps & GenAI World 2024',
#                                'MLOps & GenAI World 2023'],
#                     'speaker_name': 'Niels Bantilan',
#                     'total_talks': 2,
#                     'total_views': 1531},
#                    {'avg_views': 216,
#                     'categories': ['Deployment and integration',
#                                    'Introduction to MLOps and GenAI'],
#                     'companies': ['ZenML'],
#                     'events': ['MLOps & GenAI World 2024',
#                                'MLOps & GenAI World 2023'],
#                     'speaker_name': 'Adam Probst',
#                     'total_talks': 2,
#                     'total_views': 432}],
#  'success': True,
#  'topic_analysis': {},
#  'total_speakers': 14}

# %% [markdown]
# ### Test 3: Corporate Representation Analysis
# **Query**: "Analyze speaker representation from Google - how many speakers, their talk counts, and engagement"
#
# This focuses on speakers from a specific company to understand corporate representation in the conference. Useful for analyzing which companies are most active in the MLOps community.

# %%
# Test 3: Corporate Representation Analysis
result3 = analyze_speaker_activity.invoke({
    "company_name": "Google",
    "analysis_type": "all",
    "limit": 10
})

print("=== GOOGLE SPEAKERS ANALYSIS ===")
pprint(result3)
# Out:
# === GOOGLE SPEAKERS ANALYSIS ===
# {'analysis_summary': 'Speaker activity analysis: speaker talk counts, company '
#                      "representation, filtered by company 'Google'",
#  'company_breakdown': [{'company': 'Google', 'speaker_count': 3}],
#  'repeat_speakers': [],
#  'speaker_stats': [{'avg_views': 12,
#                     'categories': ['Performance optimization and efficiency'],
#                     'companies': ['Google'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Nathan Beach',
#                     'total_talks': 1,
#                     'total_views': 12},
#                    {'avg_views': 26,
#                     'categories': ['Deployment and integration'],
#                     'companies': ['Google'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Anu Reddy',
#                     'total_talks': 1,
#                     'total_views': 26},
#                    {'avg_views': 2372,
#                     'categories': ['Introduction to MLOps and GenAI'],
#                     'companies': ['Google'],
#                     'events': ['TMLS 2024'],
#                     'speaker_name': 'Patrick Marlow',
#                     'total_talks': 1,
#                     'total_views': 2372}],
#  'success': True,
#  'topic_analysis': {},
#  'total_speakers': 3}

# %% [markdown]
# ### Test 4: Overall Company Breakdown Analysis
# **Query**: "Show me the company representation breakdown - which companies have the most speakers"
#
# This provides a comprehensive view of company representation across all talks, showing which organizations are most represented in the MLOps community. Focuses on companies analysis type.

# %%
# Test 4: Overall Company Breakdown Analysis
result4 = analyze_speaker_activity.invoke({
    "analysis_type": "companies",
    "limit": 25
})

print("=== COMPANY BREAKDOWN ANALYSIS ===")
pprint(result4)
# Out:
# === COMPANY BREAKDOWN ANALYSIS ===
# {'analysis_summary': 'Speaker activity analysis: company representation',
#  'company_breakdown': [{'company': 'Aporia', 'speaker_count': 7},
#                        {'company': 'Outerbounds', 'speaker_count': 5},
#                        {'company': 'Lightning AI', 'speaker_count': 4},
#                        {'company': 'Loblaw Digital', 'speaker_count': 4},
#                        {'company': 'Scotiabank', 'speaker_count': 4},
#                        {'company': 'Google', 'speaker_count': 3},
#                        {'company': 'Wealthsimple', 'speaker_count': 3},
#                        {'company': 'RBC', 'speaker_count': 3},
#                        {'company': 'Armilla AI', 'speaker_count': 3},
#                        {'company': 'Hugging Face', 'speaker_count': 3},
#                        {'company': 'Vector Institute', 'speaker_count': 3},
#                        {'company': 'Seldon', 'speaker_count': 3},
#                        {'company': 'DVC', 'speaker_count': 3},
#                        {'company': 'Union.ai', 'speaker_count': 3},
#                        {'company': 'AI Makerspace', 'speaker_count': 3},
#                        {'company': 'VESSL AI', 'speaker_count': 2},
#                        {'company': 'Instacart', 'speaker_count': 2},
#                        {'company': 'LakeFS', 'speaker_count': 2},
#                        {'company': 'University of Toronto', 'speaker_count': 2},
#                        {'company': 'Grammarly', 'speaker_count': 2}],
#  'repeat_speakers': [{'avg_views': 510,
#                       'categories': ['Deployment and integration',
#                                      'Model dev, training, arch.'],
#                       'companies': ['Lightning AI'],
#                       'events': ['MLOps & GenAI World 2024',
#                                  'MLOps & GenAI World 2023',
#                                  'TMLS 2024'],
#                       'speaker_name': 'Aniket Maurya',
#                       'total_talks': 3,
#                       'total_views': 1529},
#                      {'avg_views': 28,
#                       'categories': ['Ethics, governance compliance'],
#                       'companies': ['Armilla AI', 'AutoAlign AI'],
#                       'events': ['TMLS 2022',
#                                  'MLOps & GenAI World 2024',
#                                  'TMLS 2023'],
#                       'speaker_name': 'Dan Adamson',
#                       'total_talks': 3,
#                       'total_views': 83},
#                      {'avg_views': 292,
#                       'categories': ['Model dev, training, arch.'],
#                       'companies': ['AI Makerspace'],
#                       'events': ['MLOps & GenAI World 2024', 'TMLS 2024'],
#                       'speaker_name': 'Greg Loughnane, Chris Alexiuk',
#                       'total_talks': 3,
#                       'total_views': 876},
#                      {'avg_views': 65,
#                       'categories': ['Deployment and integration',
#                                      'Introduction to MLOps and GenAI'],
#                       'companies': ['Outerbounds'],
#                       'events': ['MLOps & GenAI World 2024',
#                                  'MLOps & GenAI World 2023'],
#                       'speaker_name': 'Eddie Mattia',
#                       'total_talks': 2,
#                       'total_views': 130},
#                      {'avg_views': 13,
#                       'categories': ['Ethics, governance compliance'],
#                       'companies': ['Arya.ai'],
#                       'events': ['MLOps & GenAI World 2024'],
#                       'speaker_name': 'Vinay Kumar Sankarapu',
#                       'total_talks': 2,
#                       'total_views': 26},
#                      {'avg_views': 2227,
#                       'categories': ['Ethics, governance compliance',
#                                      'Performance optimization and efficiency'],
#                       'companies': ['Layer 6 AI', 'Layer 6 AI @ TD'],
#                       'events': ['TMLS 2022', 'TMLS 2023'],
#                       'speaker_name': 'Jesse Cresswell',
#                       'total_talks': 2,
#                       'total_views': 4454},
#                      {'avg_views': 143,
#                       'categories': ['Deployment and integration'],
#                       'companies': ['THE FULL STACK', 'Modal Labs'],
#                       'events': ['MLOps & GenAI World 2024',
#                                  'MLOps & GenAI World 2023'],
#                       'speaker_name': 'Charles Frye',
#                       'total_talks': 2,
#                       'total_views': 286},
#                      {'avg_views': 140,
#                       'categories': ['Deployment and integration',
#                                      'Model dev, training, arch.'],
#                       'companies': ['Featureform'],
#                       'events': ['MLOps & GenAI World 2024',
#                                  'MLOps & GenAI World 2023'],
#                       'speaker_name': 'Simba Khadder',
#                       'total_talks': 2,
#                       'total_views': 281},
#                      {'avg_views': 80,
#                       'categories': ['Introduction to MLOps and GenAI',
#                                      'Performance optimization and efficiency'],
#                       'companies': ['Aporia'],
#                       'events': ['TMLS 2022', 'MLOps & GenAI World 2023'],
#                       'speaker_name': 'Marcelo Litovsky',
#                       'total_talks': 2,
#                       'total_views': 160},
#                      {'avg_views': 58,
#                       'categories': ['Introduction to MLOps and GenAI'],
#                       'companies': ['Anaconda', 'Mistral AI'],
#                       'events': ['MLOps & GenAI World 2024'],
#                       'speaker_name': 'Sophia  Yang',
#                       'total_talks': 2,
#                       'total_views': 116},
#                      {'avg_views': 462,
#                       'categories': ['Introduction to MLOps and GenAI',
#                                      'Model dev, training, arch.'],
#                       'companies': ['Outerbounds'],
#                       'events': ['MLOps & GenAI World 2023', 'TMLS 2024'],
#                       'speaker_name': 'Ville Tuulos, Eddie Mattia',
#                       'total_talks': 2,
#                       'total_views': 924},
#                      {'avg_views': 82,
#                       'categories': ['Model dev, training, arch.',
#                                      'Performance optimization and efficiency'],
#                       'companies': ['Aporia', 'Solutions Architect'],
#                       'events': ['TMLS 2023', 'MLOps & GenAI World 2023'],
#                       'speaker_name': 'Niv Hertz',
#                       'total_talks': 2,
#                       'total_views': 165},
#                      {'avg_views': 766,
#                       'categories': ['Model dev, training, arch.',
#                                      'Performance optimization and efficiency'],
#                       'companies': ['Union.ai'],
#                       'events': ['MLOps & GenAI World 2024',
#                                  'MLOps & GenAI World 2023'],
#                       'speaker_name': 'Niels Bantilan',
#                       'total_talks': 2,
#                       'total_views': 1531},
#                      {'avg_views': 216,
#                       'categories': ['Deployment and integration',
#                                      'Introduction to MLOps and GenAI'],
#                       'companies': ['ZenML'],
#                       'events': ['MLOps & GenAI World 2024',
#                                  'MLOps & GenAI World 2023'],
#                       'speaker_name': 'Adam Probst',
#                       'total_talks': 2,
#                       'total_views': 432}],
#  'speaker_stats': [{'avg_views': 510,
#                     'categories': ['Deployment and integration',
#                                    'Model dev, training, arch.'],
#                     'companies': ['Lightning AI'],
#                     'events': ['MLOps & GenAI World 2024',
#                                'MLOps & GenAI World 2023',
#                                'TMLS 2024'],
#                     'speaker_name': 'Aniket Maurya',
#                     'total_talks': 3,
#                     'total_views': 1529},
#                    {'avg_views': 28,
#                     'categories': ['Ethics, governance compliance'],
#                     'companies': ['Armilla AI', 'AutoAlign AI'],
#                     'events': ['TMLS 2022',
#                                'MLOps & GenAI World 2024',
#                                'TMLS 2023'],
#                     'speaker_name': 'Dan Adamson',
#                     'total_talks': 3,
#                     'total_views': 83},
#                    {'avg_views': 292,
#                     'categories': ['Model dev, training, arch.'],
#                     'companies': ['AI Makerspace'],
#                     'events': ['MLOps & GenAI World 2024', 'TMLS 2024'],
#                     'speaker_name': 'Greg Loughnane, Chris Alexiuk',
#                     'total_talks': 3,
#                     'total_views': 876},
#                    {'avg_views': 65,
#                     'categories': ['Deployment and integration',
#                                    'Introduction to MLOps and GenAI'],
#                     'companies': ['Outerbounds'],
#                     'events': ['MLOps & GenAI World 2024',
#                                'MLOps & GenAI World 2023'],
#                     'speaker_name': 'Eddie Mattia',
#                     'total_talks': 2,
#                     'total_views': 130},
#                    {'avg_views': 13,
#                     'categories': ['Ethics, governance compliance'],
#                     'companies': ['Arya.ai'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Vinay Kumar Sankarapu',
#                     'total_talks': 2,
#                     'total_views': 26},
#                    {'avg_views': 2227,
#                     'categories': ['Ethics, governance compliance',
#                                    'Performance optimization and efficiency'],
#                     'companies': ['Layer 6 AI', 'Layer 6 AI @ TD'],
#                     'events': ['TMLS 2022', 'TMLS 2023'],
#                     'speaker_name': 'Jesse Cresswell',
#                     'total_talks': 2,
#                     'total_views': 4454},
#                    {'avg_views': 143,
#                     'categories': ['Deployment and integration'],
#                     'companies': ['THE FULL STACK', 'Modal Labs'],
#                     'events': ['MLOps & GenAI World 2024',
#                                'MLOps & GenAI World 2023'],
#                     'speaker_name': 'Charles Frye',
#                     'total_talks': 2,
#                     'total_views': 286},
#                    {'avg_views': 140,
#                     'categories': ['Deployment and integration',
#                                    'Model dev, training, arch.'],
#                     'companies': ['Featureform'],
#                     'events': ['MLOps & GenAI World 2024',
#                                'MLOps & GenAI World 2023'],
#                     'speaker_name': 'Simba Khadder',
#                     'total_talks': 2,
#                     'total_views': 281},
#                    {'avg_views': 80,
#                     'categories': ['Introduction to MLOps and GenAI',
#                                    'Performance optimization and efficiency'],
#                     'companies': ['Aporia'],
#                     'events': ['TMLS 2022', 'MLOps & GenAI World 2023'],
#                     'speaker_name': 'Marcelo Litovsky',
#                     'total_talks': 2,
#                     'total_views': 160},
#                    {'avg_views': 58,
#                     'categories': ['Introduction to MLOps and GenAI'],
#                     'companies': ['Anaconda', 'Mistral AI'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Sophia  Yang',
#                     'total_talks': 2,
#                     'total_views': 116},
#                    {'avg_views': 462,
#                     'categories': ['Introduction to MLOps and GenAI',
#                                    'Model dev, training, arch.'],
#                     'companies': ['Outerbounds'],
#                     'events': ['MLOps & GenAI World 2023', 'TMLS 2024'],
#                     'speaker_name': 'Ville Tuulos, Eddie Mattia',
#                     'total_talks': 2,
#                     'total_views': 924},
#                    {'avg_views': 82,
#                     'categories': ['Model dev, training, arch.',
#                                    'Performance optimization and efficiency'],
#                     'companies': ['Aporia', 'Solutions Architect'],
#                     'events': ['TMLS 2023', 'MLOps & GenAI World 2023'],
#                     'speaker_name': 'Niv Hertz',
#                     'total_talks': 2,
#                     'total_views': 165},
#                    {'avg_views': 766,
#                     'categories': ['Model dev, training, arch.',
#                                    'Performance optimization and efficiency'],
#                     'companies': ['Union.ai'],
#                     'events': ['MLOps & GenAI World 2024',
#                                'MLOps & GenAI World 2023'],
#                     'speaker_name': 'Niels Bantilan',
#                     'total_talks': 2,
#                     'total_views': 1531},
#                    {'avg_views': 216,
#                     'categories': ['Deployment and integration',
#                                    'Introduction to MLOps and GenAI'],
#                     'companies': ['ZenML'],
#                     'events': ['MLOps & GenAI World 2024',
#                                'MLOps & GenAI World 2023'],
#                     'speaker_name': 'Adam Probst',
#                     'total_talks': 2,
#                     'total_views': 432},
#                    {'avg_views': 23,
#                     'categories': ['Deployment and integration'],
#                     'companies': ['Roche'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Jakub Witkowski, Dariusz Adamczyk',
#                     'total_talks': 1,
#                     'total_views': 23},
#                    {'avg_views': 127705,
#                     'categories': [],
#                     'companies': ['Bloomberg'],
#                     'events': ['TMLS 2023'],
#                     'speaker_name': 'David Rosenberg',
#                     'total_talks': 1,
#                     'total_views': 127705},
#                    {'avg_views': 58,
#                     'categories': ['Deployment and integration'],
#                     'companies': ['VESSL AI'],
#                     'events': ['MLOps & GenAI World 2023'],
#                     'speaker_name': 'Intae Rhyoo',
#                     'total_talks': 1,
#                     'total_views': 58},
#                    {'avg_views': 12,
#                     'categories': ['Performance optimization and efficiency'],
#                     'companies': ['Google'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Nathan Beach',
#                     'total_talks': 1,
#                     'total_views': 12},
#                    {'avg_views': 28,
#                     'categories': ['Model dev, training, arch.'],
#                     'companies': ['Liquid AI'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Maxime Labonne',
#                     'total_talks': 1,
#                     'total_views': 28},
#                    {'avg_views': 155,
#                     'categories': ['Business and stakeholder alignment'],
#                     'companies': ['Anheuser-Busch'],
#                     'events': ['TMLS 2022'],
#                     'speaker_name': 'Eric Hart',
#                     'total_talks': 1,
#                     'total_views': 155},
#                    {'avg_views': 45,
#                     'categories': ['Performance optimization and efficiency'],
#                     'companies': ['Engineering Manager ML'],
#                     'events': ['TMLS 2024'],
#                     'speaker_name': 'Avin Regmi',
#                     'total_talks': 1,
#                     'total_views': 45},
#                    {'avg_views': 23,
#                     'categories': ['Performance optimization and efficiency'],
#                     'companies': ['Intuit'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Jineet Doshi',
#                     'total_talks': 1,
#                     'total_views': 23},
#                    {'avg_views': 119,
#                     'categories': ['Business and stakeholder alignment'],
#                     'companies': ['Wealthsimple'],
#                     'events': ['TMLS 2024'],
#                     'speaker_name': 'Mandy Gu',
#                     'total_talks': 1,
#                     'total_views': 119},
#                    {'avg_views': 34,
#                     'categories': ['Model dev, training, arch.'],
#                     'companies': ['Voiceflow'],
#                     'events': ['TMLS 2024'],
#                     'speaker_name': 'Bhuvana Adur Kannan, Yoyo Yang',
#                     'total_talks': 1,
#                     'total_views': 34},
#                    {'avg_views': 12,
#                     'categories': ['Model dev, training, arch.'],
#                     'companies': ['SambaNova Systems'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Urmish Thakker',
#                     'total_talks': 1,
#                     'total_views': 12}],
#  'success': True,
#  'topic_analysis': {},
#  'total_speakers': 261}

# %% [markdown]
# ### Test 5: Recent Speaker Activity Analysis (2024)
# **Query**: "Analyze speaker activity for 2024 - who were the most active recent presenters"
#
# This filters speaker activity to recent timeframes to understand current trends and identify speakers who have been active in 2024. Useful for finding current thought leaders.

# %%
# Test 5: Recent Speaker Activity Analysis (2024)
result5 = analyze_speaker_activity.invoke({
    "date_from": "2024-01-01",
    "analysis_type": "all",
    "limit": 12
})

print("=== 2024 SPEAKER ACTIVITY ===")
pprint(result5)
# Out:
# === 2024 SPEAKER ACTIVITY ===
# {'analysis_summary': 'Speaker activity analysis: speaker talk counts, company '
#                      'representation, filtered by from 2024-01-01',
#  'company_breakdown': [{'company': 'Google', 'speaker_count': 3},
#                        {'company': 'Lightning AI', 'speaker_count': 3},
#                        {'company': 'Outerbounds', 'speaker_count': 3},
#                        {'company': 'Aporia', 'speaker_count': 3},
#                        {'company': 'AI Makerspace', 'speaker_count': 3},
#                        {'company': 'Wealthsimple', 'speaker_count': 2},
#                        {'company': 'LakeFS', 'speaker_count': 2},
#                        {'company': 'Grammarly', 'speaker_count': 2},
#                        {'company': 'Google Cloud', 'speaker_count': 2},
#                        {'company': 'TitanML', 'speaker_count': 2},
#                        {'company': 'Weights & Biases', 'speaker_count': 2},
#                        {'company': 'Arya.ai', 'speaker_count': 2},
#                        {'company': 'Pinterest', 'speaker_count': 2},
#                        {'company': 'Hugging Face', 'speaker_count': 2},
#                        {'company': 'TELUS', 'speaker_count': 2},
#                        {'company': 'ZenML', 'speaker_count': 2},
#                        {'company': 'InfinyOn', 'speaker_count': 2},
#                        {'company': 'Neo4j', 'speaker_count': 2},
#                        {'company': 'Roche', 'speaker_count': 1},
#                        {'company': 'Liquid AI', 'speaker_count': 1}],
#  'repeat_speakers': [{'avg_views': 292,
#                       'categories': ['Model dev, training, arch.'],
#                       'companies': ['AI Makerspace'],
#                       'events': ['MLOps & GenAI World 2024', 'TMLS 2024'],
#                       'speaker_name': 'Greg Loughnane, Chris Alexiuk',
#                       'total_talks': 3,
#                       'total_views': 876},
#                      {'avg_views': 210,
#                       'categories': ['Deployment and integration',
#                                      'Model dev, training, arch.'],
#                       'companies': ['Lightning AI'],
#                       'events': ['MLOps & GenAI World 2024', 'TMLS 2024'],
#                       'speaker_name': 'Aniket Maurya',
#                       'total_talks': 2,
#                       'total_views': 419},
#                      {'avg_views': 13,
#                       'categories': ['Ethics, governance compliance'],
#                       'companies': ['Arya.ai'],
#                       'events': ['MLOps & GenAI World 2024'],
#                       'speaker_name': 'Vinay Kumar Sankarapu',
#                       'total_talks': 2,
#                       'total_views': 26},
#                      {'avg_views': 216,
#                       'categories': ['Deployment and integration',
#                                      'Introduction to MLOps and GenAI'],
#                       'companies': ['ZenML'],
#                       'events': ['MLOps & GenAI World 2024',
#                                  'MLOps & GenAI World 2023'],
#                       'speaker_name': 'Adam Probst',
#                       'total_talks': 2,
#                       'total_views': 432}],
#  'speaker_stats': [{'avg_views': 292,
#                     'categories': ['Model dev, training, arch.'],
#                     'companies': ['AI Makerspace'],
#                     'events': ['MLOps & GenAI World 2024', 'TMLS 2024'],
#                     'speaker_name': 'Greg Loughnane, Chris Alexiuk',
#                     'total_talks': 3,
#                     'total_views': 876},
#                    {'avg_views': 210,
#                     'categories': ['Deployment and integration',
#                                    'Model dev, training, arch.'],
#                     'companies': ['Lightning AI'],
#                     'events': ['MLOps & GenAI World 2024', 'TMLS 2024'],
#                     'speaker_name': 'Aniket Maurya',
#                     'total_talks': 2,
#                     'total_views': 419},
#                    {'avg_views': 13,
#                     'categories': ['Ethics, governance compliance'],
#                     'companies': ['Arya.ai'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Vinay Kumar Sankarapu',
#                     'total_talks': 2,
#                     'total_views': 26},
#                    {'avg_views': 216,
#                     'categories': ['Deployment and integration',
#                                    'Introduction to MLOps and GenAI'],
#                     'companies': ['ZenML'],
#                     'events': ['MLOps & GenAI World 2024',
#                                'MLOps & GenAI World 2023'],
#                     'speaker_name': 'Adam Probst',
#                     'total_talks': 2,
#                     'total_views': 432},
#                    {'avg_views': 23,
#                     'categories': ['Deployment and integration'],
#                     'companies': ['Roche'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Jakub Witkowski, Dariusz Adamczyk',
#                     'total_talks': 1,
#                     'total_views': 23},
#                    {'avg_views': 12,
#                     'categories': ['Performance optimization and efficiency'],
#                     'companies': ['Google'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Nathan Beach',
#                     'total_talks': 1,
#                     'total_views': 12},
#                    {'avg_views': 28,
#                     'categories': ['Model dev, training, arch.'],
#                     'companies': ['Liquid AI'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Maxime Labonne',
#                     'total_talks': 1,
#                     'total_views': 28},
#                    {'avg_views': 45,
#                     'categories': ['Performance optimization and efficiency'],
#                     'companies': ['Engineering Manager ML'],
#                     'events': ['TMLS 2024'],
#                     'speaker_name': 'Avin Regmi',
#                     'total_talks': 1,
#                     'total_views': 45},
#                    {'avg_views': 23,
#                     'categories': ['Performance optimization and efficiency'],
#                     'companies': ['Intuit'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Jineet Doshi',
#                     'total_talks': 1,
#                     'total_views': 23},
#                    {'avg_views': 119,
#                     'categories': ['Business and stakeholder alignment'],
#                     'companies': ['Wealthsimple'],
#                     'events': ['TMLS 2024'],
#                     'speaker_name': 'Mandy Gu',
#                     'total_talks': 1,
#                     'total_views': 119},
#                    {'avg_views': 34,
#                     'categories': ['Model dev, training, arch.'],
#                     'companies': ['Voiceflow'],
#                     'events': ['TMLS 2024'],
#                     'speaker_name': 'Bhuvana Adur Kannan, Yoyo Yang',
#                     'total_talks': 1,
#                     'total_views': 34},
#                    {'avg_views': 12,
#                     'categories': ['Model dev, training, arch.'],
#                     'companies': ['SambaNova Systems'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Urmish Thakker',
#                     'total_talks': 1,
#                     'total_views': 12}],
#  'success': True,
#  'topic_analysis': {},
#  'total_speakers': 146}

# %% [markdown]
# ### Test 6: Event-Specific Speaker Analysis
# **Query**: "Analyze speakers from MLOps & GenAI World 2024 event - who presented and how many talks"
#
# This focuses on speaker activity within a specific event, useful for understanding event participation patterns and identifying key contributors to particular conferences.

# %%
# Test 6: Event-Specific Speaker Analysis
result6 = analyze_speaker_activity.invoke({
    "event_name": "MLOps & GenAI World 2024",
    "analysis_type": "all",
    "limit": 15
})

print("=== EVENT-SPECIFIC SPEAKER ANALYSIS ===")
pprint(result6)
# Out:
# === EVENT-SPECIFIC SPEAKER ANALYSIS ===
# {'analysis_summary': 'Speaker activity analysis: speaker talk counts, company '
#                      "representation, filtered by event 'MLOps & GenAI World "
#                      "2024'",
#  'company_breakdown': [{'company': 'Google', 'speaker_count': 2},
#                        {'company': 'Google Cloud', 'speaker_count': 2},
#                        {'company': 'Weights & Biases', 'speaker_count': 2},
#                        {'company': 'Arya.ai', 'speaker_count': 2},
#                        {'company': 'Outerbounds', 'speaker_count': 2},
#                        {'company': 'AI Makerspace', 'speaker_count': 2},
#                        {'company': 'Aporia', 'speaker_count': 2},
#                        {'company': 'Roche', 'speaker_count': 1},
#                        {'company': 'Liquid AI', 'speaker_count': 1},
#                        {'company': 'Intuit', 'speaker_count': 1},
#                        {'company': 'SambaNova Systems', 'speaker_count': 1},
#                        {'company': 'University of British Columbia',
#                         'speaker_count': 1},
#                        {'company': 'Toyota', 'speaker_count': 1},
#                        {'company': 'CentML', 'speaker_count': 1},
#                        {'company': 'Lightning AI', 'speaker_count': 1},
#                        {'company': 'Grammarly', 'speaker_count': 1},
#                        {'company': 'lakeFS', 'speaker_count': 1},
#                        {'company': 'VESSL AI', 'speaker_count': 1},
#                        {'company': 'Faire Wholesale Inc', 'speaker_count': 1},
#                        {'company': 'JFrog', 'speaker_count': 1}],
#  'repeat_speakers': [{'avg_views': 13,
#                       'categories': ['Ethics, governance compliance'],
#                       'companies': ['Arya.ai'],
#                       'events': ['MLOps & GenAI World 2024'],
#                       'speaker_name': 'Vinay Kumar Sankarapu',
#                       'total_talks': 2,
#                       'total_views': 26},
#                      {'avg_views': 68,
#                       'categories': ['Model dev, training, arch.'],
#                       'companies': ['AI Makerspace'],
#                       'events': ['MLOps & GenAI World 2024'],
#                       'speaker_name': 'Greg Loughnane, Chris Alexiuk',
#                       'total_talks': 2,
#                       'total_views': 135}],
#  'speaker_stats': [{'avg_views': 13,
#                     'categories': ['Ethics, governance compliance'],
#                     'companies': ['Arya.ai'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Vinay Kumar Sankarapu',
#                     'total_talks': 2,
#                     'total_views': 26},
#                    {'avg_views': 68,
#                     'categories': ['Model dev, training, arch.'],
#                     'companies': ['AI Makerspace'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Greg Loughnane, Chris Alexiuk',
#                     'total_talks': 2,
#                     'total_views': 135},
#                    {'avg_views': 23,
#                     'categories': ['Deployment and integration'],
#                     'companies': ['Roche'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Jakub Witkowski, Dariusz Adamczyk',
#                     'total_talks': 1,
#                     'total_views': 23},
#                    {'avg_views': 12,
#                     'categories': ['Performance optimization and efficiency'],
#                     'companies': ['Google'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Nathan Beach',
#                     'total_talks': 1,
#                     'total_views': 12},
#                    {'avg_views': 28,
#                     'categories': ['Model dev, training, arch.'],
#                     'companies': ['Liquid AI'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Maxime Labonne',
#                     'total_talks': 1,
#                     'total_views': 28},
#                    {'avg_views': 23,
#                     'categories': ['Performance optimization and efficiency'],
#                     'companies': ['Intuit'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Jineet Doshi',
#                     'total_talks': 1,
#                     'total_views': 23},
#                    {'avg_views': 12,
#                     'categories': ['Model dev, training, arch.'],
#                     'companies': ['SambaNova Systems'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Urmish Thakker',
#                     'total_talks': 1,
#                     'total_views': 12},
#                    {'avg_views': 18,
#                     'categories': ['Future trends'],
#                     'companies': ['University of British Columbia'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Jeff Clune',
#                     'total_talks': 1,
#                     'total_views': 18},
#                    {'avg_views': 106,
#                     'categories': ['Model dev, training, arch.'],
#                     'companies': ['Toyota'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Ravi Chandu Ummadisetti, Stephen Ellis, '
#                                     'Kordel France, Eric Swei',
#                     'total_talks': 1,
#                     'total_views': 106},
#                    {'avg_views': 26,
#                     'categories': ['Deployment and integration'],
#                     'companies': ['CentML'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Vasilis Vagias',
#                     'total_talks': 1,
#                     'total_views': 26},
#                    {'avg_views': 33,
#                     'categories': ['Deployment and integration'],
#                     'companies': ['Lightning AI'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Aniket Maurya',
#                     'total_talks': 1,
#                     'total_views': 33},
#                    {'avg_views': 252,
#                     'categories': ['Performance optimization and efficiency'],
#                     'companies': ['Grammarly'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Sri  Raghu Malireddi',
#                     'total_talks': 1,
#                     'total_views': 252},
#                    {'avg_views': 27,
#                     'categories': ['Model dev, training, arch.'],
#                     'companies': ['Google Cloud'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Ivan Nardini, Holt Skinner',
#                     'total_talks': 1,
#                     'total_views': 27},
#                    {'avg_views': 35,
#                     'categories': ['Model dev, training, arch.'],
#                     'companies': ['lakeFS'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Amit  Kesarwani',
#                     'total_talks': 1,
#                     'total_views': 35},
#                    {'avg_views': 11,
#                     'categories': ['Deployment and integration'],
#                     'companies': ['VESSL AI'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Jaeman An',
#                     'total_talks': 1,
#                     'total_views': 11}],
#  'success': True,
#  'topic_analysis': {},
#  'total_speakers': 70}

# %% [markdown]
# ### Test 7: Category-Focused Speaker Analysis
# **Query**: "Who are the most active speakers in Model dev, training, arch. category - find domain experts"
#
# This analyzes speaker activity within a specific topic category to identify domain experts and thought leaders in particular areas like MLOps, deployment, or future trends.

# %%
# Test 7: Category-Focused Speaker Analysis
result7 = analyze_speaker_activity.invoke({
    "category": "Model dev, training, arch.",
    "analysis_type": "all",
    "limit": 10
})

print("=== MLOPS CATEGORY SPEAKER ANALYSIS ===")
pprint(result7)
# Out:
# === MLOPS CATEGORY SPEAKER ANALYSIS ===
# {'analysis_summary': 'Speaker activity analysis: speaker talk counts, company '
#                      "representation, filtered by category 'Model dev, "
#                      "training, arch.'",
#  'company_breakdown': [{'company': 'AI Makerspace', 'speaker_count': 3},
#                        {'company': 'Google Cloud', 'speaker_count': 2},
#                        {'company': 'Lightning AI', 'speaker_count': 2},
#                        {'company': 'Union.ai', 'speaker_count': 2},
#                        {'company': 'Liquid AI', 'speaker_count': 1},
#                        {'company': 'Voiceflow', 'speaker_count': 1},
#                        {'company': 'SambaNova Systems', 'speaker_count': 1},
#                        {'company': 'Deepgram', 'speaker_count': 1},
#                        {'company': 'Toyota', 'speaker_count': 1},
#                        {'company': 'Groq', 'speaker_count': 1},
#                        {'company': 'RBC', 'speaker_count': 1},
#                        {'company': 'SickKids', 'speaker_count': 1},
#                        {'company': 'lakeFS', 'speaker_count': 1},
#                        {'company': 'Iterative.ai', 'speaker_count': 1},
#                        {'company': 'Stitch Fix', 'speaker_count': 1},
#                        {'company': 'Explosion AI', 'speaker_count': 1},
#                        {'company': 'NLP from Scratch', 'speaker_count': 1},
#                        {'company': 'Symbl.ai', 'speaker_count': 1},
#                        {'company': 'Weights & Biases', 'speaker_count': 1},
#                        {'company': 'Recursion', 'speaker_count': 1}],
#  'repeat_speakers': [{'avg_views': 292,
#                       'categories': ['Model dev, training, arch.'],
#                       'companies': ['AI Makerspace'],
#                       'events': ['MLOps & GenAI World 2024', 'TMLS 2024'],
#                       'speaker_name': 'Greg Loughnane, Chris Alexiuk',
#                       'total_talks': 3,
#                       'total_views': 876},
#                      {'avg_views': 748,
#                       'categories': ['Model dev, training, arch.'],
#                       'companies': ['Lightning AI'],
#                       'events': ['MLOps & GenAI World 2023', 'TMLS 2024'],
#                       'speaker_name': 'Aniket Maurya',
#                       'total_talks': 2,
#                       'total_views': 1496}],
#  'speaker_stats': [{'avg_views': 292,
#                     'categories': ['Model dev, training, arch.'],
#                     'companies': ['AI Makerspace'],
#                     'events': ['MLOps & GenAI World 2024', 'TMLS 2024'],
#                     'speaker_name': 'Greg Loughnane, Chris Alexiuk',
#                     'total_talks': 3,
#                     'total_views': 876},
#                    {'avg_views': 748,
#                     'categories': ['Model dev, training, arch.'],
#                     'companies': ['Lightning AI'],
#                     'events': ['MLOps & GenAI World 2023', 'TMLS 2024'],
#                     'speaker_name': 'Aniket Maurya',
#                     'total_talks': 2,
#                     'total_views': 1496},
#                    {'avg_views': 28,
#                     'categories': ['Model dev, training, arch.'],
#                     'companies': ['Liquid AI'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Maxime Labonne',
#                     'total_talks': 1,
#                     'total_views': 28},
#                    {'avg_views': 34,
#                     'categories': ['Model dev, training, arch.'],
#                     'companies': ['Voiceflow'],
#                     'events': ['TMLS 2024'],
#                     'speaker_name': 'Bhuvana Adur Kannan, Yoyo Yang',
#                     'total_talks': 1,
#                     'total_views': 34},
#                    {'avg_views': 12,
#                     'categories': ['Model dev, training, arch.'],
#                     'companies': ['SambaNova Systems'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Urmish Thakker',
#                     'total_talks': 1,
#                     'total_views': 12},
#                    {'avg_views': 59,
#                     'categories': ['Model dev, training, arch.'],
#                     'companies': ['Deepgram'],
#                     'events': ['MLOps & GenAI World 2023'],
#                     'speaker_name': 'Jose Nicholas Francisco',
#                     'total_talks': 1,
#                     'total_views': 59},
#                    {'avg_views': 106,
#                     'categories': ['Model dev, training, arch.'],
#                     'companies': ['Toyota'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Ravi Chandu Ummadisetti, Stephen Ellis, '
#                                     'Kordel France, Eric Swei',
#                     'total_talks': 1,
#                     'total_views': 106},
#                    {'avg_views': 262,
#                     'categories': ['Model dev, training, arch.'],
#                     'companies': ['Groq'],
#                     'events': ['TMLS 2024'],
#                     'speaker_name': 'Arash Taheri-Dezfouli',
#                     'total_talks': 1,
#                     'total_views': 262},
#                    {'avg_views': 1126,
#                     'categories': ['Model dev, training, arch.'],
#                     'companies': ['RBC'],
#                     'events': ['TMLS 2023'],
#                     'speaker_name': 'Arthur  Berrill',
#                     'total_talks': 1,
#                     'total_views': 1126},
#                    {'avg_views': 635,
#                     'categories': ['Model dev, training, arch.'],
#                     'companies': ['SickKids'],
#                     'events': [],
#                     'speaker_name': 'Alistair Johnson',
#                     'total_talks': 1,
#                     'total_views': 635}],
#  'success': True,
#  'topic_analysis': {},
#  'total_speakers': 64}

# %% [markdown]
# ### Test 8: High-Frequency Speaker Analysis
# **Query**: "Find super active speakers who gave 3+ presentations - identify key thought leaders"
#
# This identifies the most prolific speakers who have given multiple presentations, helping find key thought leaders and most active community members.

# %%
# Test 8: High-Frequency Speaker Analysis
result8 = analyze_speaker_activity.invoke({
    "min_talk_count": 3,
    "analysis_type": "talk_count",
    "limit": 8
})

print("=== HIGH-FREQUENCY SPEAKERS (3+ talks) ===")
pprint(result8)
# Out:
# === HIGH-FREQUENCY SPEAKERS (3+ talks) ===
# {'analysis_summary': 'Speaker activity analysis: speaker talk counts',
#  'company_breakdown': {},
#  'repeat_speakers': [{'avg_views': 510,
#                       'categories': ['Deployment and integration',
#                                      'Model dev, training, arch.'],
#                       'companies': ['Lightning AI'],
#                       'events': ['MLOps & GenAI World 2024',
#                                  'MLOps & GenAI World 2023',
#                                  'TMLS 2024'],
#                       'speaker_name': 'Aniket Maurya',
#                       'total_talks': 3,
#                       'total_views': 1529},
#                      {'avg_views': 28,
#                       'categories': ['Ethics, governance compliance'],
#                       'companies': ['Armilla AI', 'AutoAlign AI'],
#                       'events': ['TMLS 2022',
#                                  'MLOps & GenAI World 2024',
#                                  'TMLS 2023'],
#                       'speaker_name': 'Dan Adamson',
#                       'total_talks': 3,
#                       'total_views': 83},
#                      {'avg_views': 292,
#                       'categories': ['Model dev, training, arch.'],
#                       'companies': ['AI Makerspace'],
#                       'events': ['MLOps & GenAI World 2024', 'TMLS 2024'],
#                       'speaker_name': 'Greg Loughnane, Chris Alexiuk',
#                       'total_talks': 3,
#                       'total_views': 876}],
#  'speaker_stats': [{'avg_views': 510,
#                     'categories': ['Deployment and integration',
#                                    'Model dev, training, arch.'],
#                     'companies': ['Lightning AI'],
#                     'events': ['MLOps & GenAI World 2024',
#                                'MLOps & GenAI World 2023',
#                                'TMLS 2024'],
#                     'speaker_name': 'Aniket Maurya',
#                     'total_talks': 3,
#                     'total_views': 1529},
#                    {'avg_views': 28,
#                     'categories': ['Ethics, governance compliance'],
#                     'companies': ['Armilla AI', 'AutoAlign AI'],
#                     'events': ['TMLS 2022',
#                                'MLOps & GenAI World 2024',
#                                'TMLS 2023'],
#                     'speaker_name': 'Dan Adamson',
#                     'total_talks': 3,
#                     'total_views': 83},
#                    {'avg_views': 292,
#                     'categories': ['Model dev, training, arch.'],
#                     'companies': ['AI Makerspace'],
#                     'events': ['MLOps & GenAI World 2024', 'TMLS 2024'],
#                     'speaker_name': 'Greg Loughnane, Chris Alexiuk',
#                     'total_talks': 3,
#                     'total_views': 876}],
#  'success': True,
#  'topic_analysis': {},
#  'total_speakers': 3}

# %% [markdown]
# ### Test 9: Multi-Company Analysis (Microsoft Focus)
# **Query**: "Analyze Microsoft's speaker representation and compare to the broader ecosystem"
#
# This examines Microsoft's presence in the MLOps community through their speakers, useful for competitive analysis and understanding corporate participation patterns.

# %%
# Test 9: Multi-Company Analysis (Microsoft Focus)
result9 = analyze_speaker_activity.invoke({
    "company_name": "Microsoft",
    "analysis_type": "companies",
    "limit": 15
})

print("=== MICROSOFT SPEAKER ANALYSIS ===")
pprint(result9)
# Out:
# === MICROSOFT SPEAKER ANALYSIS ===
# {'analysis_summary': 'Speaker activity analysis: company representation, '
#                      "filtered by company 'Microsoft'",
#  'company_breakdown': [{'company': 'Microsoft', 'speaker_count': 1}],
#  'repeat_speakers': [],
#  'speaker_stats': [{'avg_views': 34,
#                     'categories': ['Deployment and integration'],
#                     'companies': ['Microsoft'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Pablo  Salvador Lopez',
#                     'total_talks': 1,
#                     'total_views': 34}],
#  'success': True,
#  'topic_analysis': {},
#  'total_speakers': 1}

# %% [markdown]
# ### Test 10: Quarterly Speaker Activity Analysis
# **Query**: "Analyze speaker activity for Q2 2024 (April-June) to understand seasonal patterns"
#
# This examines speaker activity within a specific quarter to identify seasonal trends, event clustering, and temporal patterns in conference participation.

# %%
# Test 10: Quarterly Speaker Activity Analysis
result10 = analyze_speaker_activity.invoke({
    "date_from": "2024-04-01",
    "date_to": "2024-06-30",
    "analysis_type": "all",
    "limit": 12
})

print("=== Q2 2024 SPEAKER ACTIVITY ===")
pprint(result10)
# Out:
# === Q2 2024 SPEAKER ACTIVITY ===
# {'analysis_summary': 'Speaker activity analysis: speaker talk counts, company '
#                      'representation, filtered by from 2024-04-01, until '
#                      '2024-06-30',
#  'company_breakdown': [{'company': 'Instacart', 'speaker_count': 1},
#                        {'company': 'Stitch Fix', 'speaker_count': 1},
#                        {'company': 'Syngenta', 'speaker_count': 1},
#                        {'company': 'TitanML', 'speaker_count': 1},
#                        {'company': 'Grammarly', 'speaker_count': 1},
#                        {'company': 'Ford Motor Company', 'speaker_count': 1},
#                        {'company': 'Canva', 'speaker_count': 1},
#                        {'company': 'Stripe', 'speaker_count': 1},
#                        {'company': 'Aporia', 'speaker_count': 1},
#                        {'company': 'Abnormal Security', 'speaker_count': 1},
#                        {'company': 'DVC', 'speaker_count': 1},
#                        {'company': 'YData', 'speaker_count': 1},
#                        {'company': 'Forethought', 'speaker_count': 1},
#                        {'company': 'Pinterest', 'speaker_count': 1},
#                        {'company': 'TrueFoundry', 'speaker_count': 1},
#                        {'company': 'ZenML', 'speaker_count': 1},
#                        {'company': 'Capital One', 'speaker_count': 1},
#                        {'company': 'John Snow Labs', 'speaker_count': 1},
#                        {'company': 'Hugging Face', 'speaker_count': 1},
#                        {'company': 'Saxifrage', 'speaker_count': 1}],
#  'repeat_speakers': [],
#  'speaker_stats': [{'avg_views': 207,
#                     'categories': ['Deployment and integration'],
#                     'companies': ['Instacart'],
#                     'events': [],
#                     'speaker_name': 'Guanghua Shu',
#                     'total_talks': 1,
#                     'total_views': 207},
#                    {'avg_views': 108,
#                     'categories': ['Model dev, training, arch.'],
#                     'companies': ['Stitch Fix'],
#                     'events': ['MLOps & GenAI World 2023'],
#                     'speaker_name': 'Susrutha Gongalla',
#                     'total_talks': 1,
#                     'total_views': 108},
#                    {'avg_views': 708,
#                     'categories': ['Ethics, governance compliance'],
#                     'companies': ['Syngenta'],
#                     'events': [],
#                     'speaker_name': 'Serg Masis',
#                     'total_talks': 1,
#                     'total_views': 708},
#                    {'avg_views': 49,
#                     'categories': ['Performance optimization and efficiency'],
#                     'companies': ['TitanML'],
#                     'events': ['MLOps & GenAI World 2023'],
#                     'speaker_name': 'Jamie Dborin',
#                     'total_talks': 1,
#                     'total_views': 49},
#                    {'avg_views': 38,
#                     'categories': ['Model dev, training, arch.'],
#                     'companies': ['Grammarly'],
#                     'events': [],
#                     'speaker_name': 'Vipul Raheja',
#                     'total_talks': 1,
#                     'total_views': 38},
#                    {'avg_views': 243,
#                     'categories': ['Business and stakeholder alignment'],
#                     'companies': ['Ford Motor Company'],
#                     'events': [],
#                     'speaker_name': 'Naiel Samaan, Valmir Bucaj',
#                     'total_talks': 1,
#                     'total_views': 243},
#                    {'avg_views': 87,
#                     'categories': ['Performance optimization and efficiency'],
#                     'companies': ['Canva'],
#                     'events': [],
#                     'speaker_name': 'Xin Liang',
#                     'total_talks': 1,
#                     'total_views': 87},
#                    {'avg_views': 108,
#                     'categories': ['Model dev, training, arch.'],
#                     'companies': ['Stripe'],
#                     'events': [],
#                     'speaker_name': 'Sophie Daly',
#                     'total_talks': 1,
#                     'total_views': 108},
#                    {'avg_views': 127,
#                     'categories': ['Introduction to MLOps and GenAI'],
#                     'companies': ['Aporia'],
#                     'events': ['MLOps & GenAI World 2023'],
#                     'speaker_name': 'Marcelo Litovsky',
#                     'total_talks': 1,
#                     'total_views': 127},
#                    {'avg_views': 104,
#                     'categories': ['Performance optimization and efficiency'],
#                     'companies': ['Abnormal Security'],
#                     'events': [],
#                     'speaker_name': 'Dan Shiebler',
#                     'total_talks': 1,
#                     'total_views': 104},
#                    {'avg_views': 232,
#                     'categories': ['Model dev, training, arch.'],
#                     'companies': ['DVC'],
#                     'events': ['MLOps & GenAI World 2023'],
#                     'speaker_name': 'Dmitry  Petrov',
#                     'total_talks': 1,
#                     'total_views': 232},
#                    {'avg_views': 159,
#                     'categories': ['Introduction to MLOps and GenAI'],
#                     'companies': ['YData'],
#                     'events': [],
#                     'speaker_name': 'Fabiana Clemente',
#                     'total_talks': 1,
#                     'total_views': 159}],
#  'success': True,
#  'topic_analysis': {},
#  'total_speakers': 21}

# %% [markdown]
# ### Test 11: Future Trends Specialists Analysis
# **Query**: "Find speakers who focus on future trends - identify forward-thinking thought leaders"
#
# This identifies speakers who specialize in future trends and emerging technologies, useful for finding visionaries and strategic thinkers in the MLOps space.

# %%
# Test 11: Future Trends Specialists Analysis
result11 = analyze_speaker_activity.invoke({
    "category": "Future trends",
    "analysis_type": "all",
    "min_talk_count": 1,
    "limit": 8
})

print("=== FUTURE TRENDS SPECIALISTS ===")
pprint(result11)
# Out:
# === FUTURE TRENDS SPECIALISTS ===
# {'analysis_summary': 'Speaker activity analysis: speaker talk counts, company '
#                      "representation, filtered by category 'Future trends'",
#  'company_breakdown': [{'company': 'University of British Columbia',
#                         'speaker_count': 1},
#                        {'company': 'CARTE, University of Toronto',
#                         'speaker_count': 1},
#                        {'company': 'Sematic', 'speaker_count': 1},
#                        {'company': 'Tentorrent', 'speaker_count': 1},
#                        {'company': 'Half Helix', 'speaker_count': 1},
#                        {'company': 'University of Toronto', 'speaker_count': 1},
#                        {'company': 'Ternary Data, LLC, VEOX Inc, Independent '
#                                    'Data and AI Scientist',
#                         'speaker_count': 1},
#                        {'company': 'Georgian', 'speaker_count': 1},
#                        {'company': 'WhyHow.AI', 'speaker_count': 1},
#                        {'company': 'AutoGPT', 'speaker_count': 1},
#                        {'company': 'AI Index, Stanford Institute for '
#                                    'Human-Centered AI',
#                         'speaker_count': 1},
#                        {'company': 'Navblue, An Airbus Company',
#                         'speaker_count': 1},
#                        {'company': 'VEOX Inc', 'speaker_count': 1},
#                        {'company': 'Canonical', 'speaker_count': 1}],
#  'repeat_speakers': [],
#  'speaker_stats': [{'avg_views': 18,
#                     'categories': ['Future trends'],
#                     'companies': ['University of British Columbia'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Jeff Clune',
#                     'total_talks': 1,
#                     'total_views': 18},
#                    {'avg_views': 1151,
#                     'categories': ['Future trends'],
#                     'companies': ['CARTE, University of Toronto'],
#                     'events': ['TMLS 2023'],
#                     'speaker_name': 'Alex Olsen, Somayeh Sadat',
#                     'total_talks': 1,
#                     'total_views': 1151},
#                    {'avg_views': 14,
#                     'categories': ['Future trends'],
#                     'companies': ['Sematic'],
#                     'events': ['MLOps & GenAI World 2023'],
#                     'speaker_name': 'Emmanuel Turlay',
#                     'total_talks': 1,
#                     'total_views': 14},
#                    {'avg_views': 255,
#                     'categories': ['Future trends'],
#                     'companies': ['Tentorrent'],
#                     'events': ['TMLS 2023'],
#                     'speaker_name': 'Eric Duffy',
#                     'total_talks': 1,
#                     'total_views': 255},
#                    {'avg_views': 17,
#                     'categories': ['Future trends'],
#                     'companies': ['Half Helix'],
#                     'events': ['TMLS 2022'],
#                     'speaker_name': 'Jordan Shaw',
#                     'total_talks': 1,
#                     'total_views': 17},
#                    {'avg_views': 149,
#                     'categories': ['Future trends'],
#                     'companies': ['University of Toronto'],
#                     'events': ['TMLS 2022'],
#                     'speaker_name': 'Steven Waslander',
#                     'total_talks': 1,
#                     'total_views': 149},
#                    {'avg_views': 13,
#                     'categories': ['Future trends'],
#                     'companies': ['Ternary Data, LLC, VEOX Inc, Independent '
#                                   'Data and AI Scientist'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Joe Reis, Jepson Taylor, Hugo '
#                                     'Bowne-Anderson',
#                     'total_talks': 1,
#                     'total_views': 13},
#                    {'avg_views': 20,
#                     'categories': ['Future trends'],
#                     'companies': ['Georgian'],
#                     'events': ['TMLS 2024'],
#                     'speaker_name': 'Margo Wu',
#                     'total_talks': 1,
#                     'total_views': 20}],
#  'success': True,
#  'topic_analysis': {},
#  'total_speakers': 14}

# %% [markdown]
# ### Test 12: Top Speaker Engagement Analysis
# **Query**: "Find the top 5 most active speakers across all events and analyze their impact"
#
# This identifies the most prolific speakers in the entire dataset, providing a comprehensive view of who are the key voices and thought leaders in the MLOps community.

# %%
# Test 12: Top Speaker Engagement Analysis
result12 = analyze_speaker_activity.invoke({
    "analysis_type": "talk_count",
    "limit": 5
})

print("=== TOP 5 MOST ACTIVE SPEAKERS ===")
pprint(result12)
# Out:
# === TOP 5 MOST ACTIVE SPEAKERS ===
# {'analysis_summary': 'Speaker activity analysis: speaker talk counts',
#  'company_breakdown': {},
#  'repeat_speakers': [{'avg_views': 510,
#                       'categories': ['Deployment and integration',
#                                      'Model dev, training, arch.'],
#                       'companies': ['Lightning AI'],
#                       'events': ['MLOps & GenAI World 2024',
#                                  'MLOps & GenAI World 2023',
#                                  'TMLS 2024'],
#                       'speaker_name': 'Aniket Maurya',
#                       'total_talks': 3,
#                       'total_views': 1529},
#                      {'avg_views': 28,
#                       'categories': ['Ethics, governance compliance'],
#                       'companies': ['Armilla AI', 'AutoAlign AI'],
#                       'events': ['TMLS 2022',
#                                  'MLOps & GenAI World 2024',
#                                  'TMLS 2023'],
#                       'speaker_name': 'Dan Adamson',
#                       'total_talks': 3,
#                       'total_views': 83},
#                      {'avg_views': 292,
#                       'categories': ['Model dev, training, arch.'],
#                       'companies': ['AI Makerspace'],
#                       'events': ['MLOps & GenAI World 2024', 'TMLS 2024'],
#                       'speaker_name': 'Greg Loughnane, Chris Alexiuk',
#                       'total_talks': 3,
#                       'total_views': 876},
#                      {'avg_views': 65,
#                       'categories': ['Deployment and integration',
#                                      'Introduction to MLOps and GenAI'],
#                       'companies': ['Outerbounds'],
#                       'events': ['MLOps & GenAI World 2024',
#                                  'MLOps & GenAI World 2023'],
#                       'speaker_name': 'Eddie Mattia',
#                       'total_talks': 2,
#                       'total_views': 130},
#                      {'avg_views': 13,
#                       'categories': ['Ethics, governance compliance'],
#                       'companies': ['Arya.ai'],
#                       'events': ['MLOps & GenAI World 2024'],
#                       'speaker_name': 'Vinay Kumar Sankarapu',
#                       'total_talks': 2,
#                       'total_views': 26}],
#  'speaker_stats': [{'avg_views': 510,
#                     'categories': ['Deployment and integration',
#                                    'Model dev, training, arch.'],
#                     'companies': ['Lightning AI'],
#                     'events': ['MLOps & GenAI World 2024',
#                                'MLOps & GenAI World 2023',
#                                'TMLS 2024'],
#                     'speaker_name': 'Aniket Maurya',
#                     'total_talks': 3,
#                     'total_views': 1529},
#                    {'avg_views': 28,
#                     'categories': ['Ethics, governance compliance'],
#                     'companies': ['Armilla AI', 'AutoAlign AI'],
#                     'events': ['TMLS 2022',
#                                'MLOps & GenAI World 2024',
#                                'TMLS 2023'],
#                     'speaker_name': 'Dan Adamson',
#                     'total_talks': 3,
#                     'total_views': 83},
#                    {'avg_views': 292,
#                     'categories': ['Model dev, training, arch.'],
#                     'companies': ['AI Makerspace'],
#                     'events': ['MLOps & GenAI World 2024', 'TMLS 2024'],
#                     'speaker_name': 'Greg Loughnane, Chris Alexiuk',
#                     'total_talks': 3,
#                     'total_views': 876},
#                    {'avg_views': 65,
#                     'categories': ['Deployment and integration',
#                                    'Introduction to MLOps and GenAI'],
#                     'companies': ['Outerbounds'],
#                     'events': ['MLOps & GenAI World 2024',
#                                'MLOps & GenAI World 2023'],
#                     'speaker_name': 'Eddie Mattia',
#                     'total_talks': 2,
#                     'total_views': 130},
#                    {'avg_views': 13,
#                     'categories': ['Ethics, governance compliance'],
#                     'companies': ['Arya.ai'],
#                     'events': ['MLOps & GenAI World 2024'],
#                     'speaker_name': 'Vinay Kumar Sankarapu',
#                     'total_talks': 2,
#                     'total_views': 26}],
#  'success': True,
#  'topic_analysis': {},
#  'total_speakers': 261}
