# %%
# Import required libraries and tools
import os
import sys
import json
from pprint import pprint

# Load environment variables
from dotenv import load_dotenv
load_dotenv()

# Add tools directory to path
sys.path.append('.')

# Import all our tools
from search_talks_by_filters import search_talks_by_filters
from search_talks_semantically import search_talks_semantically
from analyze_speaker_activity import analyze_speaker_activity
from get_talk_details import get_talk_details
from find_similar_content import find_similar_content
from analyze_topics_and_trends import analyze_topics_and_trends

print("✅ All tools imported successfully!")
print(f"🔑 ApertureDB Key configured: {'Yes' if os.getenv('APERTUREDB_KEY') else 'No'}")

# Helper function for pretty printing results
def print_results(result, max_results=5):
    """Pretty print tool results with truncation"""
    if isinstance(result, dict) and 'results' in result:
        print(f"Total found: {result.get('total_found', 'Unknown')}")
        if result.get('query_summary'):
            print(f"Query: {result['query_summary']}")
        if result.get('sort_info'):
            print(f"Sorting: {result['sort_info']}")
        
        results = result['results'][:max_results]
        for i, talk in enumerate(results, 1):
            print(f"\n{i}. {talk.get('title', 'No Title')}")
            print(f"   Speaker: {talk.get('speaker', 'Unknown')}")
            print(f"   Company: {talk.get('company', 'Unknown')}")
            print(f"   Views: {talk.get('views', 0):,}")
            if talk.get('published_date'):
                print(f"   Date: {talk['published_date']}")
    else:
        pprint(result)
# Out:
# ✅ All tools imported successfully!
# 🔑 ApertureDB Key configured: Yes

# %% [markdown]
# ## Tool 2: `search_talks_semantically` - Comprehensive Semantic Search Testing
#
# This tool performs semantic search across talk content using natural language queries and embeddings. It searches through video transcripts, talk abstracts/metadata, and speaker bios using the SentenceTransformer model to find semantically similar content.
#
# ### Test 1: General AI Agents Concept Search
# **Query**: "Find talks that discuss AI agents with memory and reasoning capabilities"
#
# This tests broad conceptual semantic search across all content types to find talks about AI agents, a popular MLOps topic. The tool will search transcripts, abstracts, and speaker bios for semantically related content.

# %%
# Test 1: General AI Agents Concept Search
result1 = search_talks_semantically.invoke({
    "query": "AI agents with memory and reasoning capabilities",
    "search_type": "all",
    "k_neighbors": 8
})

pprint(result1)
# Out:
# {'query_vector_info': 'Generated 768D embedding using '
#                       'google/embeddinggemma-300m',
#  'results': [{'category': 'Future trends',
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': 'TMLS 2024',
#               'matching_text': 'GenAI Investing in 2024 | An updated overview '
#                                'on the Gen Ai market landscape and investment '
#                                'activity, along with investor insights for '
#                                'fundraising. | An updated overview on the Gen '
#                                'Ai landscape and investment activity, as well '
#                                'as some investor insights for fundraising. | '
#                                'Future trends | GenAI Landsc...',
#               'similarity_score': 0.439,
#               'speaker': 'Margo Wu',
#               'talk_id': 'dacfab95-57e8-5086-bc22-74b86cf3fbb3',
#               'title': 'GenAI Investing in 2024',
#               'youtube_url': 'https://www.youtube.com/watch?v=QBNX72rckbc'},
#              {'category': 'Model dev, training, arch.',
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': 'TMLS 2024',
#               'matching_text': 'AI Agents with Function Calling/Tool Use | '
#                                'Learn about Agentic workflows with LLM tool '
#                                'use. Generate structured JSON output and '
#                                'execute external tools/functions. | By the end '
#                                'of this workshop you will learn how to build '
#                                'AI Agents and make use of function calling '
#                                'with OpenAI and open-source LLMs | Py...',
#               'similarity_score': 0.427,
#               'speaker': 'Aniket Maurya',
#               'talk_id': 'f604c4a8-6a7f-5835-8ca8-92542dd2d710',
#               'title': 'AI Agents with Function Calling/Tool Use',
#               'youtube_url': 'https://www.youtube.com/watch?v=46x7WbaSgqs'},
#              {'category': 'Business and stakeholder alignment',
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': 'MLOps & GenAI World 2024',
#               'matching_text': 'Panel: The Current Investment Landscape. '
#                                'Opportunities & Challenges in ML/Gen AI | '
#                                'Business and stakeholder alignment | '
#                                'Investment landscape, Opportunities, ML/GenAI',
#               'similarity_score': 0.425,
#               'speaker': 'George Matthew, Prerna Sharma, Mark Weber',
#               'talk_id': '4e0c7f79-d08a-5eed-8500-eda5faa5ec2f',
#               'title': 'Panel: The Current Investment Landscape. Opportunities '
#                        '& Challenges in ML/Gen AI',
#               'youtube_url': 'https://www.youtube.com/watch?v=V5k4Mpbd0h4'},
#              {'category': 'Deployment and integration',
#               'content_type': 'speaker bio',
#               'context_info': 'From speaker bio',
#               'event': 'MLOps & GenAI World 2024',
#               'matching_text': 'Distinguished Engineer, AI/ML | Dre is a '
#                                'Distinguished Engineer at LinkedIn, where he '
#                                'leads wide-ranging initiatives relevant to '
#                                'large model training, serving, MLOps and more.',
#               'similarity_score': 0.425,
#               'speaker': 'Dre Olgiati',
#               'talk_id': '7da06749-38e6-59c8-b00d-e39b115894d0',
#               'title': 'Large Language Model Training and Serving at LinkedIn',
#               'youtube_url': 'https://www.youtube.com/watch?v=yx_BKcAPoQs'},
#              {'category': 'Deployment and integration',
#               'content_type': 'speaker bio',
#               'context_info': 'From speaker bio',
#               'event': 'MLOps & GenAI World 2024',
#               'matching_text': 'Senior Software Engineer | Anu is a senior '
#                                'software engineer working on optimizing Google '
#                                'Kubernetes Engine for techniques like RAG and '
#                                'supporting popular AI/ML framework and tools '
#                                'such as Ray.',
#               'similarity_score': 0.422,
#               'speaker': 'Anu Reddy',
#               'talk_id': '3bec210f-b106-5ff7-ab2c-3b467ff012d9',
#               'title': 'Optimizing AI/ML Workflows on Kubernetes: Advanced '
#                        'Techniques and Integration',
#               'youtube_url': 'https://www.youtube.com/watch?v=grCvM9tkS7Q'},
#              {'category': 'Introduction to MLOps and GenAI',
#               'content_type': 'speaker bio',
#               'context_info': 'From speaker bio',
#               'event': 'TMLS 2022',
#               'matching_text': 'Director, Machine Learning Platform | Rex Lam '
#                                'leads the Machine Learning Platform team to '
#                                'build platform capabilities that enable full '
#                                'ML cycle development and operational tools at '
#                                'Autodesk that aim to enable ML solutions '
#                                'faster, trusted and scalable.',
#               'similarity_score': 0.421,
#               'speaker': 'Rex Lam',
#               'talk_id': '1ae37e7c-d3b5-510c-b9aa-bc74f9a2cf41',
#               'title': 'The transformative role of AI/ML in heavy industries',
#               'youtube_url': 'https://www.youtube.com/watch?v=Wk64V7G6sHA'},
#              {'category': 'Business and stakeholder alignment',
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': None,
#               'matching_text': 'Business Panel: GenAI Use-cases Across '
#                                'Industry Verticals. Early Trends and ROI | '
#                                'Business and stakeholder alignment | GenAI '
#                                'use-cases, Industry verticals, ROI',
#               'similarity_score': 0.416,
#               'speaker': 'Surbhi Rathore, Kamelia Aryafar, Shingai Manjengwa, '
#                          'Manas Bhuyan, Laila Paszti',
#               'talk_id': 'e39c7304-db05-518d-a3db-8c962214dc8f',
#               'title': 'Business Panel: GenAI Use-cases Across Industry '
#                        'Verticals. Early Trends and ROI',
#               'youtube_url': 'https://www.youtube.com/watch?v=r1FVentlxw8'},
#              {'category': 'Business and stakeholder alignment',
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': None,
#               'matching_text': 'Panel: How companies can navigate and approach '
#                                'the new advancements in generative AI | '
#                                'Business and stakeholder alignment | '
#                                'Generative AI, Business Strategy, Panel '
#                                'Discussion',
#               'similarity_score': 0.409,
#               'speaker': 'Michel Dubois, Cameron Schuler, Alex LaPlante, Sara '
#                          'Hooker',
#               'talk_id': '7255dc0f-0f29-5aad-9a95-a7956c44673a',
#               'title': 'Panel: How companies can navigate and approach the new '
#                        'advancements in generative AI',
#               'youtube_url': 'https://www.youtube.com/watch?v=BzS74tByHpw'}],
#  'search_summary': "Semantic search for 'AI agents with memory and reasoning "
#                    "capabilities' (Searched: transcript search, "
#                    'abstract/metadata search, speaker bio search)',
#  'success': True,
#  'total_found': 8}

# %% [markdown]
# ### Test 2: Transcript-Specific Technical Search
# **Query**: "Vector databases and embeddings in production systems"
#
# This tests semantic search specifically within video transcripts to find technical discussions about vector databases. Using search_type="transcript" focuses only on spoken content from the videos.

# %%
# Test 2: Transcript-Specific Technical Search
result2 = search_talks_semantically.invoke({
    "query": "vector databases and embeddings in production systems",
    "search_type": "transcript",
    "k_neighbors": 6
})

pprint(result2)
# Out:
# {'query_vector_info': 'Generated 768D embedding using '
#                       'google/embeddinggemma-300m',
#  'results': [{'category': 'Business and stakeholder alignment',
#               'content_type': 'transcript',
#               'context_info': 'Timestamp: 294-319s',
#               'event': 'TMLS 2023',
#               'matching_text': 'like how data science interacts and provides '
#                                'like value how they communicate that value can '
#                                'look super different so data science reporting '
#                                'into itself into engineering into Finance into '
#                                'product all changes the shape of the nature of '
#                                'your communication it also changes how they '
#                                'interact with business ...',
#               'similarity_score': 0.365,
#               'speaker': 'Wendy Foster',
#               'talk_id': 'a8b6ed5b-0ca2-5b23-9d9d-8afd0213f7b3',
#               'title': 'Data Storytelling for Beginners',
#               'youtube_url': 'https://www.youtube.com/watch?v=rC07Yp3SrF0'},
#              {'category': 'Deployment and integration',
#               'content_type': 'transcript',
#               'context_info': 'Timestamp: 1454-1474s',
#               'event': 'MLOps & GenAI World 2024',
#               'matching_text': "something that's typically not built within "
#                                'the core product but built at the application '
#                                'layer um but we have Integrations with most of '
#                                'the major Vector databases and you can just '
#                                'kind of treat them either as separate Vector '
#                                'databases or do hard filtering when you when '
#                                'you do those queries um we do...',
#               'similarity_score': 0.364,
#               'speaker': 'Meryem Arik, Hannes Hapke',
#               'talk_id': '97315b8f-3fb8-5dd9-aa22-818a4eeac23e',
#               'title': 'Creating our own private OpenAI API',
#               'youtube_url': 'https://www.youtube.com/watch?v=NQXw8JA9QHM'},
#              {'category': 'Introduction to MLOps and GenAI',
#               'content_type': 'transcript',
#               'context_info': 'Timestamp: 1198-1223s',
#               'event': None,
#               'matching_text': 'you for the vector database to do the '
#                                "similarity search um but that's that's another "
#                                'topic later um and then you need to choose '
#                                'what embeddings you want to use you can use a '
#                                'um opening eye embeddings or you can use any '
#                                'embedding models from uh huging face you and '
#                                'then we create a vector store to sto...',
#               'similarity_score': 0.363,
#               'speaker': 'Sophia  Yang',
#               'talk_id': '1bd658ed-401e-57d2-ba99-c268fd9f9757',
#               'title': 'Introduction to LangChain and Retrieval Augmented '
#                        'Generation (RAG)',
#               'youtube_url': 'https://www.youtube.com/watch?v=oL-SR1U9g0k'},
#              {'category': 'Deployment and integration',
#               'content_type': 'transcript',
#               'context_info': 'Timestamp: 1341-1363s',
#               'event': 'TMLS 2023',
#               'matching_text': "I'm curious if there is embedding support into "
#                                'the logging um these are not related to '
#                                'logging we use these embeddings in our model '
#                                "serving apis uh uh you're right like there's "
#                                'different types of embeddings different '
#                                'versions of these embeddings with different '
#                                'architectures um we will measure we lik...',
#               'similarity_score': 0.363,
#               'speaker': 'Adhithya Ravichandran',
#               'talk_id': '902d023c-6c80-5dda-94f8-783668244f8e',
#               'title': 'ML in Production: Implementation, Tooling & '
#                        'Engineering, Data/ML Ops',
#               'youtube_url': 'https://www.youtube.com/watch?v=VqdsKNvLrhE'},
#              {'category': 'Introduction to MLOps and GenAI',
#               'content_type': 'transcript',
#               'context_info': 'Timestamp: 51-79s',
#               'event': 'TMLS 2022',
#               'matching_text': 'real in construction manufacturing and '
#                                'entertainment Industries a technology connect '
#                                'people to processes automate complex workflows '
#                                'to enable designers suppliers engineers and '
#                                'support a manufacturers who work together to '
#                                'start their work digitally and stay digital '
#                                'throughout their constructions and ...',
#               'similarity_score': 0.345,
#               'speaker': 'Rex Lam',
#               'talk_id': '1ae37e7c-d3b5-510c-b9aa-bc74f9a2cf41',
#               'title': 'The transformative role of AI/ML in heavy industries',
#               'youtube_url': 'https://www.youtube.com/watch?v=Wk64V7G6sHA'},
#              {'category': 'Performance optimization and efficiency',
#               'content_type': 'transcript',
#               'context_info': 'Timestamp: 520-520s',
#               'event': 'MLOps & GenAI World 2023',
#               'matching_text': 'which is linked at our various GitHub repos is '
#                                'probably the best place I personally as well '
#                                'as our CTO and CEO are always on there '
#                                'answering questions uh chatting about Vector '
#                                'search uh and AI data legs thank you',
#               'similarity_score': 0.343,
#               'speaker': 'Will Jones',
#               'talk_id': 'c27e4511-ee11-5dfa-be8a-a2d481a4af17',
#               'title': 'LanceDB: a unified storage layer for vector search, '
#                        'analytics, and model training',
#               'youtube_url': 'https://www.youtube.com/watch?v=s3L35puUWSA'}],
#  'search_summary': "Semantic search for 'vector databases and embeddings in "
#                    "production systems' (Searched: transcript search)",
#  'success': True,
#  'total_found': 6}

# %% [markdown]
# ### Test 3: Abstract/Metadata Search for RAG Systems
# **Query**: "Retrieval Augmented Generation and knowledge retrieval"
#
# This focuses on talk abstracts and keywords to find structured descriptions of RAG systems. Using search_type="meta" searches through curated abstracts and metadata rather than raw transcripts.

# %%
# Test 3: Abstract/Metadata Search for RAG Systems
result3 = search_talks_semantically.invoke({
    "query": "machine learning",
    "search_type": "meta",
    "k_neighbors": 7
})

pprint(result3)
# Out:
# {'query_vector_info': 'Generated 768D embedding using '
#                       'google/embeddinggemma-300m',
#  'results': [{'category': 'Business and stakeholder alignment',
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': None,
#               'matching_text': 'Business Panel: GenAI Use-cases Across '
#                                'Industry Verticals. Early Trends and ROI | '
#                                'Business and stakeholder alignment | GenAI '
#                                'use-cases, Industry verticals, ROI',
#               'similarity_score': 0.452,
#               'speaker': 'Surbhi Rathore, Kamelia Aryafar, Shingai Manjengwa, '
#                          'Manas Bhuyan, Laila Paszti',
#               'talk_id': 'e39c7304-db05-518d-a3db-8c962214dc8f',
#               'title': 'Business Panel: GenAI Use-cases Across Industry '
#                        'Verticals. Early Trends and ROI',
#               'youtube_url': 'https://www.youtube.com/watch?v=r1FVentlxw8'},
#              {'category': 'Deployment and integration',
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': 'MLOps & GenAI World 2024',
#               'matching_text': 'Large Language Model Training and Serving at '
#                                'LinkedIn | In this talk, Dre will describe '
#                                'some of the fundamental challenges and '
#                                'solutions faced by the LinkedIn team as they '
#                                'build innovative products based on LLMs and '
#                                'agents. | How do I build scalable training and '
#                                'serving solutions for large language ...',
#               'similarity_score': 0.445,
#               'speaker': 'Dre Olgiati',
#               'talk_id': '7da06749-38e6-59c8-b00d-e39b115894d0',
#               'title': 'Large Language Model Training and Serving at LinkedIn',
#               'youtube_url': 'https://www.youtube.com/watch?v=yx_BKcAPoQs'},
#              {'category': 'Performance optimization and efficiency',
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': 'MLOps & GenAI World 2023',
#               'matching_text': 'How do you scale to billions of fine-tuned '
#                                'LLMs? | Batched LORA Inference, a method '
#                                'gaining popularity that could be used to scale '
#                                'to billions of personalized, finetuned llms '
#                                'without paying the compute cost that this '
#                                'would naively imply. | Performance '
#                                'optimization and efficiency | Batched LORA '
#                                'Infer...',
#               'similarity_score': 0.44,
#               'speaker': 'Jamie Dborin',
#               'talk_id': '9cc32db2-9f03-591a-88e4-1b0def8fdba0',
#               'title': 'How do you scale to billions of fine-tuned LLMs?',
#               'youtube_url': 'https://www.youtube.com/watch?v=JGzas8cfrtw'},
#              {'category': 'Business and stakeholder alignment',
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': None,
#               'matching_text': 'Panel: How companies can navigate and approach '
#                                'the new advancements in generative AI | '
#                                'Business and stakeholder alignment | '
#                                'Generative AI, Business Strategy, Panel '
#                                'Discussion',
#               'similarity_score': 0.438,
#               'speaker': 'Michel Dubois, Cameron Schuler, Alex LaPlante, Sara '
#                          'Hooker',
#               'talk_id': '7255dc0f-0f29-5aad-9a95-a7956c44673a',
#               'title': 'Panel: How companies can navigate and approach the new '
#                        'advancements in generative AI',
#               'youtube_url': 'https://www.youtube.com/watch?v=BzS74tByHpw'},
#              {'category': 'Business and stakeholder alignment',
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': 'MLOps & GenAI World 2024',
#               'matching_text': 'Panel: The Current Investment Landscape. '
#                                'Opportunities & Challenges in ML/Gen AI | '
#                                'Business and stakeholder alignment | '
#                                'Investment landscape, Opportunities, ML/GenAI',
#               'similarity_score': 0.412,
#               'speaker': 'George Matthew, Prerna Sharma, Mark Weber',
#               'talk_id': '4e0c7f79-d08a-5eed-8500-eda5faa5ec2f',
#               'title': 'Panel: The Current Investment Landscape. Opportunities '
#                        '& Challenges in ML/Gen AI',
#               'youtube_url': 'https://www.youtube.com/watch?v=V5k4Mpbd0h4'},
#              {'category': 'Future trends',
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': 'MLOps & GenAI World 2024',
#               'matching_text': 'Panel: Achieving Long-Term AI Growth: Real '
#                                'Problem Solving vs. Trend-Based Solutions | '
#                                'Future trends | Long-term growth, AI '
#                                'problem-solving, Trend-based solutions',
#               'similarity_score': 0.408,
#               'speaker': 'Joe Reis, Jepson Taylor, Hugo Bowne-Anderson',
#               'talk_id': 'df7ba3f6-88d0-5225-96e9-4d66d969b090',
#               'title': 'Panel: Achieving Long-Term AI Growth: Real Problem '
#                        'Solving vs. Trend-Based Solutions',
#               'youtube_url': 'https://www.youtube.com/watch?v=Swof2q5zTyI'},
#              {'category': 'Deployment and integration',
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': 'MLOps & GenAI World 2024',
#               'matching_text': 'Optimized AI Deployment Platform | Showcasing '
#                                'CentMLs ability to streamline the process of '
#                                'deploying and optimizing LLMs in production. | '
#                                'Deployment and integration | CentML, LLM '
#                                'deployment, Optimization',
#               'similarity_score': 0.394,
#               'speaker': 'Vasilis Vagias',
#               'talk_id': '6b8d79ff-1417-57e1-9263-12d335800919',
#               'title': 'Optimized AI Deployment Platform',
#               'youtube_url': 'https://www.youtube.com/watch?v=pNgwVCrpUJU'}],
#  'search_summary': "Semantic search for 'machine learning' (Searched: "
#                    'abstract/metadata search)',
#  'success': True,
#  'total_found': 7}

# %% [markdown]
# ### Test 4: Speaker Expertise Discovery
# **Query**: "Machine learning deployment and containerization expertise"
#
# This searches speaker bios to find experts in ML deployment. Using search_type="bio" focuses on speaker background information to identify domain experts and their areas of specialization.

# %%
# Test 4: Speaker Expertise Discovery
result4 = search_talks_semantically.invoke({
    "query": "machine learning",
    "search_type": "bio",
    "k_neighbors": 5
})

pprint(result4)
# Out:
# {'query_vector_info': 'Generated 768D embedding using '
#                       'google/embeddinggemma-300m',
#  'results': [{'category': 'Deployment and integration',
#               'content_type': 'speaker bio',
#               'context_info': 'From speaker bio',
#               'event': 'TMLS 2024',
#               'matching_text': 'Engineering Manager | I lead the Content '
#                                'Mining team at Pinterest. We use ML to '
#                                'understand the webpages and extract useful '
#                                'information for our users.',
#               'similarity_score': 0.32,
#               'speaker': 'Patrick Halina',
#               'talk_id': 'ec25523f-194c-588d-a930-264aaa0fa4a3',
#               'title': 'Web Extraction With LLMs',
#               'youtube_url': 'https://www.youtube.com/watch?v=olf7hs0c0zk'},
#              {'category': 'Model dev, training, arch.',
#               'content_type': 'speaker bio',
#               'context_info': 'From speaker bio',
#               'event': 'TMLS 2024',
#               'matching_text': 'Developer Advocate | I’m Aniket, a Machine '
#                                'Learning - Software Engineer with with over 4 '
#                                'years of experience, demonstrating a strong '
#                                'track record in developing and deploying '
#                                'machine learning models to production.',
#               'similarity_score': 0.313,
#               'speaker': 'Aniket Maurya',
#               'talk_id': 'f604c4a8-6a7f-5835-8ca8-92542dd2d710',
#               'title': 'AI Agents with Function Calling/Tool Use',
#               'youtube_url': 'https://www.youtube.com/watch?v=46x7WbaSgqs'},
#              {'category': 'Future trends',
#               'content_type': 'speaker bio',
#               'context_info': 'From speaker bio',
#               'event': 'MLOps & GenAI World 2024',
#               'matching_text': 'Technical Founder | Co-Founder @ WhyHow.AI',
#               'similarity_score': 0.285,
#               'speaker': 'Tom Smoker',
#               'talk_id': 'a55d2cac-4def-52a7-9232-d1e28fea0aa7',
#               'title': 'Multi-Graph Multi-Agent systems - Determinism through '
#                        'Structured Representations',
#               'youtube_url': 'https://www.youtube.com/watch?v=wup9vlT03H8'},
#              {'category': 'Performance optimization and efficiency',
#               'content_type': 'speaker bio',
#               'context_info': 'From speaker bio',
#               'event': 'MLOps & GenAI World 2024',
#               'matching_text': 'Senior Data Scientist | Vatsal Patel, Senior '
#                                'Data Scientist, MongoDB',
#               'similarity_score': 0.283,
#               'speaker': 'Vatsal Patel',
#               'talk_id': '85361907-d39c-5970-ab4e-2c7b0b9d9da9',
#               'title': 'A Data Scientist Guide to Unit & End to End Testing',
#               'youtube_url': 'https://www.youtube.com/watch?v=6iKu2_suYrE'},
#              {'category': 'Model dev, training, arch.',
#               'content_type': 'speaker bio',
#               'context_info': 'From speaker bio',
#               'event': 'TMLS 2024',
#               'matching_text': 'Member of Technical Staff | Work on LLMs, '
#                                'pretraining, long-context and deep-learning '
#                                'engineering.',
#               'similarity_score': 0.28,
#               'speaker': 'Bowen Yang',
#               'talk_id': '8a1b1e9a-6b99-5282-9032-61bf3da02ccb',
#               'title': 'Unraveling Long Context: Existing Methods, Challenges, '
#                        'and Future Directions',
#               'youtube_url': 'https://www.youtube.com/watch?v=jT0g7-GUMGY'}],
#  'search_summary': "Semantic search for 'machine learning' (Searched: speaker "
#                    'bio search)',
#  'success': True,
#  'total_found': 5}

# %% [markdown]
# ### Test 5: Time-Filtered Semantic Search
# **Query**: "LangChain and LangGraph frameworks for building AI applications"
#
# This combines semantic search with temporal filtering to find recent discussions about popular AI frameworks. The date filter helps focus on current trends and recent developments.

# %%
# Test 5: Time-Filtered Semantic Search
result5 = search_talks_semantically.invoke({
    "query": "LangChain and LangGraph frameworks for building AI applications",
    "search_type": "all",
    "date_from": "2024-01-01",
    "k_neighbors": 8
})

pprint(result5)
# Out:
# {'query_vector_info': 'Generated 768D embedding using '
#                       'google/embeddinggemma-300m',
#  'results': [{'category': None,
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': None,
#               'matching_text': 'Deploying and Evaluating RAG pipelines with '
#                                'Lightning Studios | Learn how to use Lightning '
#                                'Studios to quickly deploy AI agents and '
#                                'accelerate your evaluation of RAG pipelines. | '
#                                'Learn how to use Lightning Studios to quickly '
#                                'deploy AI agents and accelerate your '
#                                'evaluation of RAG pipelines. | Deployme...',
#               'similarity_score': 0.405,
#               'speaker': None,
#               'talk_id': '0c7e727c-214e-5fc1-954e-3aa19bd8a513',
#               'title': None,
#               'youtube_url': None},
#              {'category': None,
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': None,
#               'matching_text': 'Large Language Model Training and Serving at '
#                                'LinkedIn | In this talk, Dre will describe '
#                                'some of the fundamental challenges and '
#                                'solutions faced by the LinkedIn team as they '
#                                'build innovative products based on LLMs and '
#                                'agents. | How do I build scalable training and '
#                                'serving solutions for large language ...',
#               'similarity_score': 0.399,
#               'speaker': None,
#               'talk_id': '7da06749-38e6-59c8-b00d-e39b115894d0',
#               'title': None,
#               'youtube_url': None},
#              {'category': None,
#               'content_type': 'speaker bio',
#               'context_info': 'From speaker bio',
#               'event': None,
#               'matching_text': 'Co-Founder | Jamie Dborin is a co-founder of '
#                                'TitanML, and works at TitanML building '
#                                'inference infrastructure for LLMs.',
#               'similarity_score': 0.396,
#               'speaker': None,
#               'talk_id': '9cc32db2-9f03-591a-88e4-1b0def8fdba0',
#               'title': None,
#               'youtube_url': None},
#              {'category': None,
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': None,
#               'matching_text': 'Optimized AI Deployment Platform | Showcasing '
#                                'CentMLs ability to streamline the process of '
#                                'deploying and optimizing LLMs in production. | '
#                                'Deployment and integration | CentML, LLM '
#                                'deployment, Optimization',
#               'similarity_score': 0.391,
#               'speaker': None,
#               'talk_id': '6b8d79ff-1417-57e1-9263-12d335800919',
#               'title': None,
#               'youtube_url': None},
#              {'category': None,
#               'content_type': 'speaker bio',
#               'context_info': 'From speaker bio',
#               'event': None,
#               'matching_text': 'Member of Technical Staff | Work on LLMs, '
#                                'pretraining, long-context and deep-learning '
#                                'engineering.',
#               'similarity_score': 0.385,
#               'speaker': None,
#               'talk_id': '8a1b1e9a-6b99-5282-9032-61bf3da02ccb',
#               'title': None,
#               'youtube_url': None},
#              {'category': None,
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': None,
#               'matching_text': 'Panel: The Current Investment Landscape. '
#                                'Opportunities & Challenges in ML/Gen AI | '
#                                'Business and stakeholder alignment | '
#                                'Investment landscape, Opportunities, ML/GenAI',
#               'similarity_score': 0.376,
#               'speaker': None,
#               'talk_id': '4e0c7f79-d08a-5eed-8500-eda5faa5ec2f',
#               'title': None,
#               'youtube_url': None},
#              {'category': None,
#               'content_type': 'transcript',
#               'context_info': 'Timestamp: 1512-1554s',
#               'event': None,
#               'matching_text': 'practical and that wraps up our techniques for '
#                                'today so keep in mind these five dimensions of '
#                                'AI efficiency try all of these approaches keep '
#                                'in mind those small language models keep in '
#                                'mind the posttraining quantization and build '
#                                'your own efficient AI recipes thank you so '
#                                'much it was great being [Ap...',
#               'similarity_score': 0.364,
#               'speaker': None,
#               'talk_id': 'fc3efe32-e399-5dfc-9cd5-70912f545122',
#               'title': None,
#               'youtube_url': None},
#              {'category': None,
#               'content_type': 'transcript',
#               'context_info': 'Timestamp: 247-268s',
#               'event': None,
#               'matching_text': "vendor where's this vendor from do do we "
#                                'establish a tax Nexus etc etc um at the same '
#                                'time we have some Bank information there like '
#                                'we would like to validate them so really good '
#                                'use cases for large language models in um '
#                                "their applications and then there's always "
#                                'this big question why should we host ...',
#               'similarity_score': 0.363,
#               'speaker': None,
#               'talk_id': '97315b8f-3fb8-5dd9-aa22-818a4eeac23e',
#               'title': None,
#               'youtube_url': None}],
#  'search_summary': "Semantic search for 'LangChain and LangGraph frameworks "
#                    "for building AI applications' (Searched: transcript "
#                    'search, abstract/metadata search, speaker bio search, Date '
#                    'range: 2024-01-01 to end)',
#  'success': True,
#  'total_found': 8}

# %% [markdown]
# ### Test 7: Category-Filtered DevOps Search
# **Query**: "Kubernetes orchestration and container scaling strategies"
#
# This combines semantic search with category filtering to find DevOps-related content. The category filter helps narrow results to deployment and infrastructure topics.

# %%
# Test 7: Category-Filtered DevOps Search
result7 = search_talks_semantically.invoke({
    "query": "Kubernetes orchestration and container scaling strategies",
    "search_type": "all",
    "category": "Deployment and integration",
    "k_neighbors": 6
})


pprint(result7)
# Out:
# {'query_vector_info': 'Generated 768D embedding using '
#                       'google/embeddinggemma-300m',
#  'results': [{'category': None,
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': None,
#               'matching_text': 'Optimized AI Deployment Platform | Showcasing '
#                                'CentMLs ability to streamline the process of '
#                                'deploying and optimizing LLMs in production. | '
#                                'Deployment and integration | CentML, LLM '
#                                'deployment, Optimization',
#               'similarity_score': 0.344,
#               'speaker': None,
#               'talk_id': '6b8d79ff-1417-57e1-9263-12d335800919',
#               'title': None,
#               'youtube_url': None},
#              {'category': None,
#               'content_type': 'speaker bio',
#               'context_info': 'From speaker bio',
#               'event': None,
#               'matching_text': 'Senior Software Engineer | Anu is a senior '
#                                'software engineer working on optimizing Google '
#                                'Kubernetes Engine for techniques like RAG and '
#                                'supporting popular AI/ML framework and tools '
#                                'such as Ray.',
#               'similarity_score': 0.329,
#               'speaker': None,
#               'talk_id': '3bec210f-b106-5ff7-ab2c-3b467ff012d9',
#               'title': None,
#               'youtube_url': None},
#              {'category': None,
#               'content_type': 'speaker bio',
#               'context_info': 'From speaker bio',
#               'event': None,
#               'matching_text': 'Data Scientist | Data scientist at '
#                                'Outerbounds\n'
#                                '\n'
#                                'Building AI developer tools and many '
#                                'applications on top of them!',
#               'similarity_score': 0.328,
#               'speaker': None,
#               'talk_id': '427ecc83-6138-57d0-bb04-d2b4d61eb6a6',
#               'title': None,
#               'youtube_url': None},
#              {'category': None,
#               'content_type': 'transcript',
#               'context_info': 'Timestamp: 313-341s',
#               'event': None,
#               'matching_text': 'scripts that abstract away deployment runtime '
#                                'permissions container containerization and '
#                                'artifact versioning much much more it also '
#                                'includes infrastructure such as highly '
#                                'available key value stores airflow instances '
#                                'and data Lake as well as the cost and '
#                                'performance monitoring infrastructure for all '
#                                '...',
#               'similarity_score': 0.322,
#               'speaker': None,
#               'talk_id': '902d023c-6c80-5dda-94f8-783668244f8e',
#               'title': None,
#               'youtube_url': None}],
#  'search_summary': "Semantic search for 'Kubernetes orchestration and "
#                    "container scaling strategies' (Searched: transcript "
#                    'search, abstract/metadata search, speaker bio search, '
#                    'Category: Deployment and integration)',
#  'success': True,
#  'total_found': 4}

# %% [markdown]
# ### Test 8: Event-Specific AI Search
# **Query**: "Generative AI and large language models in production"
#
# This searches for GenAI content within a specific event context. Event filtering helps focus on content from particular conferences or symposiums with relevant themes.

# %%
# Test 8: Event-Specific AI Search  
result8 = search_talks_semantically.invoke({
    "query": "generative AI and large language models in production",
    "search_type": "all",
    "event_name": "MLOps & GenAI World 2024",
    "k_neighbors": 7
})

pprint(result8)
# Out:
# {'query_vector_info': 'Generated 768D embedding using '
#                       'google/embeddinggemma-300m',
#  'results': [{'category': None,
#               'content_type': 'speaker bio',
#               'context_info': 'From speaker bio',
#               'event': None,
#               'matching_text': 'Senior Software Engineer | Anu is a senior '
#                                'software engineer working on optimizing Google '
#                                'Kubernetes Engine for techniques like RAG and '
#                                'supporting popular AI/ML framework and tools '
#                                'such as Ray.',
#               'similarity_score': 0.352,
#               'speaker': None,
#               'talk_id': '3bec210f-b106-5ff7-ab2c-3b467ff012d9',
#               'title': None,
#               'youtube_url': None},
#              {'category': None,
#               'content_type': 'speaker bio',
#               'context_info': 'From speaker bio',
#               'event': None,
#               'matching_text': 'Data Scientist | Data scientist at '
#                                'Outerbounds\n'
#                                '\n'
#                                'Building AI developer tools and many '
#                                'applications on top of them!',
#               'similarity_score': 0.328,
#               'speaker': None,
#               'talk_id': '427ecc83-6138-57d0-bb04-d2b4d61eb6a6',
#               'title': None,
#               'youtube_url': None},
#              {'category': None,
#               'content_type': 'speaker bio',
#               'context_info': 'From speaker bio',
#               'event': None,
#               'matching_text': 'Senior Data Scientist | Vatsal Patel, Senior '
#                                'Data Scientist, MongoDB',
#               'similarity_score': 0.325,
#               'speaker': None,
#               'talk_id': '85361907-d39c-5970-ab4e-2c7b0b9d9da9',
#               'title': None,
#               'youtube_url': None},
#              {'category': None,
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': None,
#               'matching_text': 'Panel: The Current Investment Landscape. '
#                                'Opportunities & Challenges in ML/Gen AI | '
#                                'Business and stakeholder alignment | '
#                                'Investment landscape, Opportunities, ML/GenAI',
#               'similarity_score': 0.323,
#               'speaker': None,
#               'talk_id': '4e0c7f79-d08a-5eed-8500-eda5faa5ec2f',
#               'title': None,
#               'youtube_url': None},
#              {'category': None,
#               'content_type': 'transcript',
#               'context_info': 'Timestamp: 0-28s',
#               'event': None,
#               'matching_text': '[Applause] [Music] to my talk uh from paper to '
#                                "production where I'll be talking about uh "
#                                'taking generative AI research techniques and '
#                                'um pushing things to production um so a little '
#                                "bit about myself um I'm an AI engineer at "
#                                'autog GPT um which is an open source platform '
#                                'to allow users to build uh agen...',
#               'similarity_score': 0.315,
#               'speaker': None,
#               'talk_id': 'dda7a80b-dbbd-58aa-bb8b-5f1ef4425341',
#               'title': None,
#               'youtube_url': None},
#              {'category': None,
#               'content_type': 'transcript',
#               'context_info': 'Timestamp: 531-555s',
#               'event': None,
#               'matching_text': 'very slow so what we did is that we apply '
#                                'generative EI in combination with natural '
#                                "language processing techniques where we didn't "
#                                'just dumped to the llm all the public comments '
#                                'but we applied some filtering with NLP and '
#                                'text analytics to only feature the llm the '
#                                'most relevant and the most sensitive...',
#               'similarity_score': 0.315,
#               'speaker': None,
#               'talk_id': 'dc2f63ce-931e-59c0-912b-97738a2979ee',
#               'title': None,
#               'youtube_url': None},
#              {'category': None,
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': None,
#               'matching_text': 'Panel: Achieving Long-Term AI Growth: Real '
#                                'Problem Solving vs. Trend-Based Solutions | '
#                                'Future trends | Long-term growth, AI '
#                                'problem-solving, Trend-based solutions',
#               'similarity_score': 0.313,
#               'speaker': None,
#               'talk_id': 'df7ba3f6-88d0-5225-96e9-4d66d969b090',
#               'title': None,
#               'youtube_url': None}],
#  'search_summary': "Semantic search for 'generative AI and large language "
#                    "models in production' (Searched: transcript search, "
#                    'abstract/metadata search, speaker bio search, Event: MLOps '
#                    '& GenAI World 2024)',
#  'success': True,
#  'total_found': 7}

# %% [markdown]
# ### Test 9: Speaker-Specific Expertise Search
# **Query**: "Python applications"
#
# This searches for technical content but only within talks by a specific speaker. This helps analyze what particular experts discuss and their areas of deep expertise.

# %%
# Test 9: Speaker-Specific Expertise Search
result9 = search_talks_semantically.invoke({
    "query": "python applications",
    "search_type": "all",
    "speaker_name": "Sophia Yang",  
    "k_neighbors": 5
})

pprint(result9)
# Out:
# {'query_vector_info': 'Generated 768D embedding using '
#                       'google/embeddinggemma-300m',
#  'results': [{'category': None,
#               'content_type': 'transcript',
#               'context_info': 'Timestamp: 268-294s',
#               'event': None,
#               'matching_text': 'execute python in the web browser it actually '
#                                'brings the whole ecosystem whole python '
#                                'ecosystem into the browser for you when we use '
#                                "Python we're not just use the standard python "
#                                'libraries we actually import numpy scipy '
#                                'pandas cycling learn all those python '
#                                'ecosystems are can be used in the browser ...',
#               'similarity_score': 0.364,
#               'speaker': None,
#               'talk_id': 'd915e5d8-a34e-5576-85a5-1d23c1bc41de',
#               'title': None,
#               'youtube_url': None}],
#  'search_summary': "Semantic search for 'python applications' (Searched: "
#                    'transcript search, abstract/metadata search, speaker bio '
#                    'search, Speaker: Sophia Yang)',
#  'success': True,
#  'total_found': 1}

# %% [markdown]
# ### Test 10: Multi-Modal Data Science Search
# **Query**: "Feature stores and data versioning for machine learning"
#
# This searches across all content types for data engineering topics. This tests how well the semantic search handles ML infrastructure concepts across different content modalities.

# %%
# Test 10: Multi-Modal Data Science Search
result10 = search_talks_semantically.invoke({
    "query": "feature stores and data versioning for machine learning",
    "search_type": "all",
    "k_neighbors": 8
})

pprint(result10)
# Out:
# {'query_vector_info': 'Generated 768D embedding using '
#                       'google/embeddinggemma-300m',
#  'results': [{'category': 'Business and stakeholder alignment',
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': None,
#               'matching_text': 'Panel: How companies can navigate and approach '
#                                'the new advancements in generative AI | '
#                                'Business and stakeholder alignment | '
#                                'Generative AI, Business Strategy, Panel '
#                                'Discussion',
#               'similarity_score': 0.451,
#               'speaker': 'Michel Dubois, Cameron Schuler, Alex LaPlante, Sara '
#                          'Hooker',
#               'talk_id': '7255dc0f-0f29-5aad-9a95-a7956c44673a',
#               'title': 'Panel: How companies can navigate and approach the new '
#                        'advancements in generative AI',
#               'youtube_url': 'https://www.youtube.com/watch?v=BzS74tByHpw'},
#              {'category': 'Performance optimization and efficiency',
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': 'TMLS 2024',
#               'matching_text': 'Compute Strategies for Generative AI | '
#                                'Distributing computing efforts strategically '
#                                'to maximize resource utilization and minimize '
#                                "wastage. Investing in Spotify's Hendrix ML "
#                                'Platform, which streamlines AI training and '
#                                'serving processes for models with over 70 '
#                                'billion parameters. | Performance optimiz...',
#               'similarity_score': 0.445,
#               'speaker': 'Avin Regmi',
#               'talk_id': '0189dc07-e081-587d-bc59-055c29a4635e',
#               'title': 'Compute Strategies for Generative AI',
#               'youtube_url': 'https://www.youtube.com/watch?v=0OEcXIL-piE'},
#              {'category': 'Model dev, training, arch.',
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': None,
#               'matching_text': 'ML Experimentation with DVC and VS Code | '
#                                'Learn how to manage and make your machine '
#                                'learning projects reproducible with an '
#                                'open-source tool DVC and its extension for VS '
#                                'Code. \n'
#                                'We will see how to track datasets and models, '
#                                'run, compare, visualize, and track machine '
#                                'learning experiments right in VS Co...',
#               'similarity_score': 0.427,
#               'speaker': 'Alex Kim',
#               'talk_id': 'ab9bdb57-34f3-5218-9b82-99ecb0fdbc92',
#               'title': 'ML Experimentation with DVC and VS Code',
#               'youtube_url': 'https://www.youtube.com/watch?v=sRpKkbN6U-M'},
#              {'category': 'Business and stakeholder alignment',
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': 'MLOps & GenAI World 2024',
#               'matching_text': 'Panel: The Current Investment Landscape. '
#                                'Opportunities & Challenges in ML/Gen AI | '
#                                'Business and stakeholder alignment | '
#                                'Investment landscape, Opportunities, ML/GenAI',
#               'similarity_score': 0.422,
#               'speaker': 'George Matthew, Prerna Sharma, Mark Weber',
#               'talk_id': '4e0c7f79-d08a-5eed-8500-eda5faa5ec2f',
#               'title': 'Panel: The Current Investment Landscape. Opportunities '
#                        '& Challenges in ML/Gen AI',
#               'youtube_url': 'https://www.youtube.com/watch?v=V5k4Mpbd0h4'},
#              {'category': 'Future trends',
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': 'MLOps & GenAI World 2024',
#               'matching_text': 'Panel: Achieving Long-Term AI Growth: Real '
#                                'Problem Solving vs. Trend-Based Solutions | '
#                                'Future trends | Long-term growth, AI '
#                                'problem-solving, Trend-based solutions',
#               'similarity_score': 0.415,
#               'speaker': 'Joe Reis, Jepson Taylor, Hugo Bowne-Anderson',
#               'talk_id': 'df7ba3f6-88d0-5225-96e9-4d66d969b090',
#               'title': 'Panel: Achieving Long-Term AI Growth: Real Problem '
#                        'Solving vs. Trend-Based Solutions',
#               'youtube_url': 'https://www.youtube.com/watch?v=Swof2q5zTyI'},
#              {'category': 'Business and stakeholder alignment',
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': None,
#               'matching_text': 'Business Panel: GenAI Use-cases Across '
#                                'Industry Verticals. Early Trends and ROI | '
#                                'Business and stakeholder alignment | GenAI '
#                                'use-cases, Industry verticals, ROI',
#               'similarity_score': 0.414,
#               'speaker': 'Surbhi Rathore, Kamelia Aryafar, Shingai Manjengwa, '
#                          'Manas Bhuyan, Laila Paszti',
#               'talk_id': 'e39c7304-db05-518d-a3db-8c962214dc8f',
#               'title': 'Business Panel: GenAI Use-cases Across Industry '
#                        'Verticals. Early Trends and ROI',
#               'youtube_url': 'https://www.youtube.com/watch?v=r1FVentlxw8'},
#              {'category': 'Deployment and integration',
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': 'TMLS 2024',
#               'matching_text': 'Deploying and Evaluating RAG pipelines with '
#                                'Lightning Studios | Learn how to use Lightning '
#                                'Studios to quickly deploy AI agents and '
#                                'accelerate your evaluation of RAG pipelines. | '
#                                'Learn how to use Lightning Studios to quickly '
#                                'deploy AI agents and accelerate your '
#                                'evaluation of RAG pipelines. | Deployme...',
#               'similarity_score': 0.412,
#               'speaker': 'Rob Levy',
#               'talk_id': '0c7e727c-214e-5fc1-954e-3aa19bd8a513',
#               'title': 'Deploying and Evaluating RAG pipelines with Lightning '
#                        'Studios',
#               'youtube_url': 'https://www.youtube.com/watch?v=JO2mJ00rCkU'},
#              {'category': 'Deployment and integration',
#               'content_type': 'speaker bio',
#               'context_info': 'From speaker bio',
#               'event': 'MLOps & GenAI World 2024',
#               'matching_text': 'Distinguished Engineer, AI/ML | Dre is a '
#                                'Distinguished Engineer at LinkedIn, where he '
#                                'leads wide-ranging initiatives relevant to '
#                                'large model training, serving, MLOps and more.',
#               'similarity_score': 0.391,
#               'speaker': 'Dre Olgiati',
#               'talk_id': '7da06749-38e6-59c8-b00d-e39b115894d0',
#               'title': 'Large Language Model Training and Serving at LinkedIn',
#               'youtube_url': 'https://www.youtube.com/watch?v=yx_BKcAPoQs'}],
#  'search_summary': "Semantic search for 'feature stores and data versioning "
#                    "for machine learning' (Searched: transcript search, "
#                    'abstract/metadata search, speaker bio search)',
#  'success': True,
#  'total_found': 8}

# %% [markdown]
# ### Test 11: Broad Discovery with Large K
# **Query**: "Python libraries and frameworks for AI development"
#
# This uses a larger k_neighbors value to get a comprehensive overview of Python-related AI content. Useful for broad topic exploration and discovering diverse perspectives.

# %%
# Test 11: Broad Discovery with Large K
result11 = search_talks_semantically.invoke({
    "query": "Python libraries and frameworks for AI development",
    "search_type": "all",
    "k_neighbors": 15
})

pprint(result11)
# Out:
# {'query_vector_info': 'Generated 768D embedding using '
#                       'google/embeddinggemma-300m',
#  'results': [{'category': 'Deployment and integration',
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': 'MLOps & GenAI World 2024',
#               'matching_text': 'Large Language Model Training and Serving at '
#                                'LinkedIn | In this talk, Dre will describe '
#                                'some of the fundamental challenges and '
#                                'solutions faced by the LinkedIn team as they '
#                                'build innovative products based on LLMs and '
#                                'agents. | How do I build scalable training and '
#                                'serving solutions for large language ...',
#               'similarity_score': 0.452,
#               'speaker': 'Dre Olgiati',
#               'talk_id': '7da06749-38e6-59c8-b00d-e39b115894d0',
#               'title': 'Large Language Model Training and Serving at LinkedIn',
#               'youtube_url': 'https://www.youtube.com/watch?v=yx_BKcAPoQs'},
#              {'category': 'Business and stakeholder alignment',
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': 'TMLS 2023',
#               'matching_text': 'Understanding\xa0 Where Generative AI fits '
#                                'into Business | Additional Questions: How '
#                                'dangerous is Generative AI? | Understand where '
#                                'Generative AI fits into business | Business '
#                                'and stakeholder alignment | Generative AI, '
#                                'Business Integration, Panel Discussion',
#               'similarity_score': 0.45,
#               'speaker': 'Miguel Mendez, Anand Nimkar, Preeti Shivpuri',
#               'talk_id': 'f9b8beb1-45bb-560c-b75a-745ad5759cac',
#               'title': 'Understanding\xa0 Where Generative AI fits into '
#                        'Business',
#               'youtube_url': 'https://www.youtube.com/watch?v=1l2W8YlvVM4'},
#              {'category': 'Introduction to MLOps and GenAI',
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': 'TMLS 2022',
#               'matching_text': 'The transformative role of AI/ML in heavy '
#                                'industries | AI/ML represents opportunities '
#                                'for Autodesk to drive insights & innovative '
#                                'solutions in architecture, design, and '
#                                'manufacturing tools. | Introduction to MLOps '
#                                'and GenAI | AI/ML, Heavy Industries, '
#                                'Architecture and Design',
#               'similarity_score': 0.447,
#               'speaker': 'Rex Lam',
#               'talk_id': '1ae37e7c-d3b5-510c-b9aa-bc74f9a2cf41',
#               'title': 'The transformative role of AI/ML in heavy industries',
#               'youtube_url': 'https://www.youtube.com/watch?v=Wk64V7G6sHA'},
#              {'category': 'Performance optimization and efficiency',
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': 'MLOps & GenAI World 2023',
#               'matching_text': 'How do you scale to billions of fine-tuned '
#                                'LLMs? | Batched LORA Inference, a method '
#                                'gaining popularity that could be used to scale '
#                                'to billions of personalized, finetuned llms '
#                                'without paying the compute cost that this '
#                                'would naively imply. | Performance '
#                                'optimization and efficiency | Batched LORA '
#                                'Infer...',
#               'similarity_score': 0.446,
#               'speaker': 'Jamie Dborin',
#               'talk_id': '9cc32db2-9f03-591a-88e4-1b0def8fdba0',
#               'title': 'How do you scale to billions of fine-tuned LLMs?',
#               'youtube_url': 'https://www.youtube.com/watch?v=JGzas8cfrtw'},
#              {'category': 'Future trends',
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': 'TMLS 2024',
#               'matching_text': 'GenAI Investing in 2024 | An updated overview '
#                                'on the Gen Ai market landscape and investment '
#                                'activity, along with investor insights for '
#                                'fundraising. | An updated overview on the Gen '
#                                'Ai landscape and investment activity, as well '
#                                'as some investor insights for fundraising. | '
#                                'Future trends | GenAI Landsc...',
#               'similarity_score': 0.441,
#               'speaker': 'Margo Wu',
#               'talk_id': 'dacfab95-57e8-5086-bc22-74b86cf3fbb3',
#               'title': 'GenAI Investing in 2024',
#               'youtube_url': 'https://www.youtube.com/watch?v=QBNX72rckbc'},
#              {'category': 'Performance optimization and efficiency',
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': None,
#               'matching_text': 'Evolved Structures: Using AI and Robots to '
#                                'build spaceflight structures at NASA | Come '
#                                'get a first hand account of how NASA is '
#                                'leveraging Generative Design to reduce the '
#                                'cost and increase the performance of '
#                                'spaceflight missions. Also, how the concept of '
#                                'AI Prompt Engineering can be practically '
#                                'appli...',
#               'similarity_score': 0.424,
#               'speaker': 'Ryan McClelland',
#               'talk_id': '70e58e65-6369-53a3-a6f6-97cf4e303e6d',
#               'title': 'Evolved Structures: Using AI and Robots to build '
#                        'spaceflight structures at NASA',
#               'youtube_url': 'https://www.youtube.com/watch?v=kXo6SZXWaXQ'},
#              {'category': 'Model dev, training, arch.',
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': 'TMLS 2024',
#               'matching_text': 'AI Agents with Function Calling/Tool Use | '
#                                'Learn about Agentic workflows with LLM tool '
#                                'use. Generate structured JSON output and '
#                                'execute external tools/functions. | By the end '
#                                'of this workshop you will learn how to build '
#                                'AI Agents and make use of function calling '
#                                'with OpenAI and open-source LLMs | Py...',
#               'similarity_score': 0.421,
#               'speaker': 'Aniket Maurya',
#               'talk_id': 'f604c4a8-6a7f-5835-8ca8-92542dd2d710',
#               'title': 'AI Agents with Function Calling/Tool Use',
#               'youtube_url': 'https://www.youtube.com/watch?v=46x7WbaSgqs'},
#              {'category': 'Performance optimization and efficiency',
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': 'TMLS 2024',
#               'matching_text': 'Compute Strategies for Generative AI | '
#                                'Distributing computing efforts strategically '
#                                'to maximize resource utilization and minimize '
#                                "wastage. Investing in Spotify's Hendrix ML "
#                                'Platform, which streamlines AI training and '
#                                'serving processes for models with over 70 '
#                                'billion parameters. | Performance optimiz...',
#               'similarity_score': 0.417,
#               'speaker': 'Avin Regmi',
#               'talk_id': '0189dc07-e081-587d-bc59-055c29a4635e',
#               'title': 'Compute Strategies for Generative AI',
#               'youtube_url': 'https://www.youtube.com/watch?v=0OEcXIL-piE'},
#              {'category': 'Business and stakeholder alignment',
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': 'TMLS 2024',
#               'matching_text': 'How Is GenAI Reshaping the Business? | '
#                                'Generative AI offers transformative advantages '
#                                'across all sectors with unlimited '
#                                'possibilities. Audience will learn about AI '
#                                'application and how it enhances efficiency, '
#                                'fosters innovation, and elevates '
#                                'problem-solving with real examples. | Business '
#                                'and stakehol...',
#               'similarity_score': 0.403,
#               'speaker': 'Jaime Tatis',
#               'talk_id': '640c9b59-8c66-5643-a922-f2d1f95c00b5',
#               'title': 'How Is GenAI Reshaping the Business?',
#               'youtube_url': 'https://www.youtube.com/watch?v=M8QBzroN3WA'},
#              {'category': 'Introduction to MLOps and GenAI',
#               'content_type': 'speaker bio',
#               'context_info': 'From speaker bio',
#               'event': 'MLOps & GenAI World 2023',
#               'matching_text': 'Data Scientist | Eddie Mattia is a data '
#                                'scientist working on Metaflow and foundation '
#                                'models at Outerbounds. He began using Python '
#                                'to teach applied math in grad school. Since '
#                                'then, Eddie has worked at startups and at '
#                                'Intel building machine learning software.',
#               'similarity_score': 0.402,
#               'speaker': 'Eddie Mattia',
#               'talk_id': '5f2373fa-7ceb-584e-93ec-8a644c574355',
#               'title': 'LLMs from hallucinations to relevant responses',
#               'youtube_url': 'https://www.youtube.com/watch?v=sm4QGPcXCuA'},
#              {'category': 'Deployment and integration',
#               'content_type': 'speaker bio',
#               'context_info': 'From speaker bio',
#               'event': 'MLOps & GenAI World 2023',
#               'matching_text': 'Software Engineer | Richie Frost is a software '
#                                'engineer on the ML Foundations team at '
#                                'Dropbox, specializing in rapid iteration on ML '
#                                'inference platforms. Previously, he worked as '
#                                'a data scientist and software engineer at '
#                                'Microsoft, where he built and analyzed '
#                                'innovative AI-based solutions.',
#               'similarity_score': 0.397,
#               'speaker': 'Richie Frost',
#               'talk_id': 'ae406be8-88aa-584a-adc8-5e46f08655b2',
#               'title': 'From Prototype to Product: Rapid iteration and ML '
#                        'model deployment at Dropbox',
#               'youtube_url': 'https://www.youtube.com/watch?v=nIIBQXOz7dA'},
#              {'category': 'Business and stakeholder alignment',
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': None,
#               'matching_text': 'Business Panel: GenAI Use-cases Across '
#                                'Industry Verticals. Early Trends and ROI | '
#                                'Business and stakeholder alignment | GenAI '
#                                'use-cases, Industry verticals, ROI',
#               'similarity_score': 0.393,
#               'speaker': 'Surbhi Rathore, Kamelia Aryafar, Shingai Manjengwa, '
#                          'Manas Bhuyan, Laila Paszti',
#               'talk_id': 'e39c7304-db05-518d-a3db-8c962214dc8f',
#               'title': 'Business Panel: GenAI Use-cases Across Industry '
#                        'Verticals. Early Trends and ROI',
#               'youtube_url': 'https://www.youtube.com/watch?v=r1FVentlxw8'},
#              {'category': 'Business and stakeholder alignment',
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': None,
#               'matching_text': 'Panel: How companies can navigate and approach '
#                                'the new advancements in generative AI | '
#                                'Business and stakeholder alignment | '
#                                'Generative AI, Business Strategy, Panel '
#                                'Discussion',
#               'similarity_score': 0.391,
#               'speaker': 'Michel Dubois, Cameron Schuler, Alex LaPlante, Sara '
#                          'Hooker',
#               'talk_id': '7255dc0f-0f29-5aad-9a95-a7956c44673a',
#               'title': 'Panel: How companies can navigate and approach the new '
#                        'advancements in generative AI',
#               'youtube_url': 'https://www.youtube.com/watch?v=BzS74tByHpw'},
#              {'category': 'Deployment and integration',
#               'content_type': 'speaker bio',
#               'context_info': 'From speaker bio',
#               'event': 'MLOps & GenAI World 2024',
#               'matching_text': 'Distinguished Engineer, AI/ML | Dre is a '
#                                'Distinguished Engineer at LinkedIn, where he '
#                                'leads wide-ranging initiatives relevant to '
#                                'large model training, serving, MLOps and more.',
#               'similarity_score': 0.39,
#               'speaker': 'Dre Olgiati',
#               'talk_id': '7da06749-38e6-59c8-b00d-e39b115894d0',
#               'title': 'Large Language Model Training and Serving at LinkedIn',
#               'youtube_url': 'https://www.youtube.com/watch?v=yx_BKcAPoQs'},
#              {'category': 'Future trends',
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': 'MLOps & GenAI World 2024',
#               'matching_text': 'Panel: Achieving Long-Term AI Growth: Real '
#                                'Problem Solving vs. Trend-Based Solutions | '
#                                'Future trends | Long-term growth, AI '
#                                'problem-solving, Trend-based solutions',
#               'similarity_score': 0.381,
#               'speaker': 'Joe Reis, Jepson Taylor, Hugo Bowne-Anderson',
#               'talk_id': 'df7ba3f6-88d0-5225-96e9-4d66d969b090',
#               'title': 'Panel: Achieving Long-Term AI Growth: Real Problem '
#                        'Solving vs. Trend-Based Solutions',
#               'youtube_url': 'https://www.youtube.com/watch?v=Swof2q5zTyI'}],
#  'search_summary': "Semantic search for 'Python libraries and frameworks for "
#                    "AI development' (Searched: transcript search, "
#                    'abstract/metadata search, speaker bio search)',
#  'success': True,
#  'total_found': 15}

# %% [markdown]
# ### Test 12: Complex Multi-Filter Semantic Search
# **Query**: "GPU acceleration and distributed training for deep learning"
#
# This combines semantic search with multiple filters (time, category) to find recent, technical content about GPU computing. Tests the tool's ability to handle complex, multi-dimensional queries.

# %%
# Test 12: Complex Multi-Filter Semantic Search
result12 = search_talks_semantically.invoke({
    "query": "GPU acceleration and distributed training for deep learning",
    "search_type": "all",
    "date_from": "2024-01-01",
    "category": "Model dev, training, arch.",
    "k_neighbors": 6
})

pprint(result12)
# Out:
# {'query_vector_info': 'Generated 768D embedding using '
#                       'google/embeddinggemma-300m',
#  'results': [{'category': None,
#               'content_type': 'abstract/metadata',
#               'context_info': 'From talk abstract/metadata',
#               'event': None,
#               'matching_text': 'Supercharging Recommender Systems: Unleashing '
#                                'the Power of Distributed Model Training | '
#                                'Stitch Fix utilizes a sophisticated '
#                                'multi-tiered recommender system stack, '
#                                'encompassing feature generation, scoring, '
#                                'ranking, and business policy decision-making. '
#                                'This presentation delves into the training '
#                                'archit...',
#               'similarity_score': 0.419,
#               'speaker': None,
#               'talk_id': '29a3f0f3-f82a-5291-8e6e-76b201799176',
#               'title': None,
#               'youtube_url': None},
#              {'category': None,
#               'content_type': 'transcript',
#               'context_info': 'Timestamp: 1532-1552s',
#               'event': None,
#               'matching_text': 'in having the ability to make sure that the '
#                                'Streamline execution can efficiently use a GPU '
#                                "and CPU resources and I'll going to like this "
#                                'is like how the training pipeline looks like '
#                                'even like rake and bring these based on the '
#                                'machine learning iterations we see that most '
#                                'of these iterations are not h...',
#               'similarity_score': 0.319,
#               'speaker': None,
#               'talk_id': 'd20cff86-35ee-54ac-90a7-d7290704cf41',
#               'title': None,
#               'youtube_url': None},
#              {'category': None,
#               'content_type': 'transcript',
#               'context_info': 'Timestamp: 508-528s',
#               'event': None,
#               'matching_text': 'understanding your featur Crossing having '
#                                'support for doing distributed training '
#                                'training through mixed precision and also '
#                                'being able to serve these models through GPU '
#                                'serving and quantization as such so these are '
#                                'some of the pillars that we build over time so '
#                                "just let's take a step back and see bef...",
#               'similarity_score': 0.295,
#               'speaker': None,
#               'talk_id': 'd20cff86-35ee-54ac-90a7-d7290704cf41',
#               'title': None,
#               'youtube_url': None},
#              {'category': None,
#               'content_type': 'speaker bio',
#               'context_info': 'From speaker bio',
#               'event': None,
#               'matching_text': 'Member of Technical Staff | Work on LLMs, '
#                                'pretraining, long-context and deep-learning '
#                                'engineering.',
#               'similarity_score': 0.274,
#               'speaker': None,
#               'talk_id': '8a1b1e9a-6b99-5282-9032-61bf3da02ccb',
#               'title': None,
#               'youtube_url': None}],
#  'search_summary': "Semantic search for 'GPU acceleration and distributed "
#                    "training for deep learning' (Searched: transcript search, "
#                    'abstract/metadata search, speaker bio search, Date range: '
#                    '2024-01-01 to end, Category: Model dev, training, arch.)',
#  'success': True,
#  'total_found': 4}
