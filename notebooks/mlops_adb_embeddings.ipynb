# %%
# !pip install -qU "numpy==2.0.2" "pandas==2.2.2"

# !pip install -qU \
  "torch==2.8.0+cu126" "torchvision==0.19.0+cu126" "torchaudio==2.8.0+cu126" \
  --index-url https://download.pytorch.org/whl/cu126

# !pip install -qU sentence-transformers aperturedb
# Out:
# ERROR: Could not find a version that satisfies the requirement torchvision==0.19.0+cu126 (from versions: 0.1.6, 0.2.0, 0.21.0+cu126, 0.22.0+cu126, 0.22.1+cu126, 0.23.0+cu126)
# ERROR: No matching distribution found for torchvision==0.19.0+cu126
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.6/486.6 kB 26.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 14.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.8/137.8 kB 13.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 13.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 84.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 77.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 56.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 72.0 MB/s eta 0:00:00
#   Building wheel for keepalive-socket (setup.py) ... done

# %%
import os, json, math
import numpy as np
import pandas as pd
from datetime import datetime
from google.colab import userdata
import uuid
import re

import torch
from sentence_transformers import SentenceTransformer

from aperturedb.CommonLibrary import create_connector
from aperturedb.Utils import Utils
from aperturedb.ParallelLoader import ParallelLoader
from aperturedb import Connector

# %%
# ---------- CONFIG ----------
APERTUREDB_KEY=userdata.get('APERTUREDB_KEY') # HF_TOKEN is also needed
CSV_PATH = "/content/mlops-events-enriched.csv"
TALK_TITLE_COL = "Talk Title"          # must exist
YOUTUBE_ID_COL = "YouTube ID"          # preferred; we’ll fall back to URL
YOUTUBE_URL_COL = "YouTube Link"       # fallback for extracting ID
TRANSCRIPT_COL = "yt_transcript"         # JSON array of {text, timestamp}

TALK_CLASS = "Talk"
SET_NAME = "ds_transcript_chunks_v1"
CONNECTION_CLASS = "TalkHasTranscriptChunk"

CHUNK_LEN = 10
OVERLAP = 2
STRIDE = CHUNK_LEN - OVERLAP

EMBED_MODEL = "google/embeddinggemma-300m"
EMBED_DIM = 768
EMBED_BATCH = 64

DB_THREADS = 4
DB_BATCHSIZE = 16                                 # commands per transaction


DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print("device:", DEVICE)

# ---------- Connect to ApertureDB ----------
con = create_connector(key=APERTUREDB_KEY)
utils = Utils(con)

# ---------- Ensure DescriptorSet exists (HNSW + cosine) ----------
# Safe to call repeatedly; adds set only if it doesn't already exist.
# Engine "HNSW" and metric ["CS"] (cosine similarity).
utils.add_descriptorset(SET_NAME, EMBED_DIM, metric=["CS"], engine="HNSW")
print("DescriptorSet ready:", SET_NAME)

# ---------- Load model ----------
model = SentenceTransformer("google/embeddinggemma-300m", device=DEVICE)
model.max_seq_length = 512
# Out:
# device: cuda
# WARNING:aperturedb.CommonLibrary:Partial errors:
# [{"AddDescriptorSet": {"name": "ds_transcript_chunks_v1", "dimensions": 768, "metric": ["CS"], "engine": "HNSW"}}]
# [{"AddDescriptorSet": {"info": "A descriptor set with this name already exists!", "status": 2}}]
# DescriptorSet ready: ds_transcript_chunks_v1
# modules.json:   0%|          | 0.00/573 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/997 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/18.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/58.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.49k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.21G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.69M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/312 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/134 [00:00<?, ?B/s]
# 2_Dense/model.safetensors:   0%|          | 0.00/9.44M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/134 [00:00<?, ?B/s]
# 3_Dense/model.safetensors:   0%|          | 0.00/9.44M [00:00<?, ?B/s]

# %%
# ---------- Helpers ----------
def extract_youtube_id(url: str) -> str | None:
    if not isinstance(url, str):
        return None
    m = re.search(r"[?&]v=([A-Za-z0-9_-]{6,})", url)
    if m: return m.group(1)
    m = re.search(r"youtu\.be/([A-Za-z0-9_-]{6,})", url)
    if m: return m.group(1)
    return None

def make_talk_id(talk_title: str, youtube_id: str | None) -> str:
    base = f"{(talk_title or '').strip()}|{(youtube_id or '').strip()}"
    return str(uuid.uuid5(uuid.NAMESPACE_URL, base))

def ts_to_seconds(ts: str) -> int:
    """
    ts examples: '0:07', '1:05:12'
    """
    parts = [int(p) for p in ts.split(":")]
    if len(parts) == 2:
        m, s = parts
        return m * 60 + s
    elif len(parts) == 3:
        h, m, s = parts
        return h * 3600 + m * 60 + s
    return 0

def chunk_transcript(items, talk_id):
    """
    items: list of {'text': str, 'timestamp': 'M:SS' or 'H:MM:SS'}
    returns list of chunk dicts with seq, start_sec, end_sec, chunk_text, chunk_id, talk_id
    """
    chunks = []
    n = len(items)
    if n == 0:
        return chunks

    i = 0
    seq = 1
    while i < n:
        part = items[i:i+CHUNK_LEN]
        if not part:
            break
        start_sec = ts_to_seconds(part[0].get("timestamp", "0:00"))
        # End time: next item right after this window; for last window fall back to start_sec
        next_idx = i + CHUNK_LEN
        if next_idx < n:
            end_sec = ts_to_seconds(items[next_idx].get("timestamp", "0:00"))
        else:
            end_sec = start_sec

        chunk_text = " ".join([p.get("text", "").strip() for p in part if p.get("text")])
        chunk_id = f"{talk_id}#ch{seq:04d}"

        chunks.append({
            "seq": seq,
            "start_sec": int(start_sec),
            "end_sec": int(end_sec),
            "chunk_text": chunk_text,
            "chunk_id": chunk_id,
            "talk_id": talk_id,
        })
        seq += 1
        i += STRIDE
    return chunks

def load_transcript_cell(raw):
    """
    Returns a Python list of {text, timestamp} or None if parse fails.
    Handles (a) already-parsed list; (b) JSON string; (c) double-encoded JSON string.
    """
    if raw is None or (isinstance(raw, float) and np.isnan(raw)):
        return None
    if isinstance(raw, list):
        return raw
    if isinstance(raw, str) and raw.strip():
        try:
            data = json.loads(raw)
            if isinstance(data, str):
                # double-encoded: decode once more
                data = json.loads(data)
            if isinstance(data, list):
                return data
        except Exception:
            return None
    return None

def to_blob(vec: np.ndarray) -> bytes:
    """
    ApertureDB expects raw float32 little-endian bytes for descriptors.
    """
    return np.asarray(vec, dtype="<f4").tobytes()

# %%
# ---------- Build queries ----------
def build_queries_for_df(df: pd.DataFrame):
    queries = []

    for _, row in df.iterrows():
        title = str(row.get(TALK_TITLE_COL, "")).strip()
        if not title:
            continue

        yt_id = str(row.get(YOUTUBE_ID_COL)).strip() if pd.notna(row.get(YOUTUBE_ID_COL)) else None
        if not yt_id:
            yt_id = extract_youtube_id(str(row.get(YOUTUBE_URL_COL, "")).strip())

        talk_id = make_talk_id(title, yt_id)

        raw = row.get(TRANSCRIPT_COL, "")
        items = load_transcript_cell(raw)
        if not items:
            continue

        chunks = chunk_transcript(items, talk_id)
        if not chunks:
            continue

        # embed texts (normalized for cosine)
        texts = [c["chunk_text"] for c in chunks]
        embs = model.encode(texts, batch_size=EMBED_BATCH, show_progress_bar=False, normalize_embeddings=True)
        assert embs.shape[1] == EMBED_DIM, f"expected {EMBED_DIM}, got {embs.shape[1]}"

        for c, vec in zip(chunks, embs):
            cmd = [
                # find the Talk by talk_id (unique) to connect the descriptor
                {
                    "FindEntity": {
                        "_ref": 1,
                        "with_class": TALK_CLASS,
                        "unique": True,
                        "constraints": {"talk_id": ["==", c["talk_id"]]},
                        "results": {"count": True}
                    }
                },
                {
                    "AddDescriptor": {                                              # AddDescriptor command
                        "set": SET_NAME,
                        "properties": {
                            "chunk_id": c["chunk_id"],
                            "talk_id": c["talk_id"],           # keep as metadata
                            "seq": c["seq"],
                            "start_sec": c["start_sec"],
                            "end_sec": c["end_sec"],
                            "chunk_text": c["chunk_text"],
                        },
                        "if_not_found": {"chunk_id": ["==", c["chunk_id"]]},        # idempotent upsert
                        "connect": { "class": CONNECTION_CLASS, "ref": 1, "direction": "in" }  # Talk -> Descriptor
                    }
                }
            ]
            queries.append((cmd, [to_blob(vec)]))
    return queries

# %%
df = pd.read_csv(CSV_PATH)
print("rows read:", len(df))
has_tx = df[TRANSCRIPT_COL].notna() & (df[TRANSCRIPT_COL].astype(str).str.len() > 2)
print("rows with non-empty transcript:", has_tx.sum())

# Peek one parsed transcript to verify shape
sample_raw = df.loc[has_tx.idxmax(), TRANSCRIPT_COL]
sample_items = load_transcript_cell(sample_raw)
print("sample items len:", len(sample_items))
print("first 2 items:", sample_items[:2])
# Out:
# rows read: 278
# rows with non-empty transcript: 278
# sample items len: 316
# first 2 items: [{'text': '[Applause] [Music]', 'timestamp': '0:00'}, {'text': 'hello everyone my name is OSI and together with DAR Adam will to today', 'timestamp': '0:07'}]

# %%
# ---------- Run ----------
df = pd.read_csv(CSV_PATH)
print("rows read:", len(df))

queries = build_queries_for_df(df)
print("descriptor chunks to ingest:", len(queries))

loader = ParallelLoader(con)
loader.ingest(queries, batchsize=DB_BATCHSIZE, numthreads=DB_THREADS, stats=True)  # parallel/batched
print("Done.")
# Out:
# rows read: 278
# descriptor chunks to ingest: 16887
# Progress: 100%|██████████| 16.9k/16.9k [03:56<00:00, 71.5items/s]
# ============ ApertureDB Loader Stats ============
# Total time (s): 236.04042387008667
# Total queries executed: 1056
# Avg Query time (s): 0.8875651413744147
# Query time std: 0.27220850394400053
# Avg Query Throughput (q/s): 4.506711466615182
# Overall insertion throughput (element/s): 71.5428303471204
# Total inserted elements: 16887
# Total successful commands: 33774
# =================================================
# Done.

# %%
# List all talk titles from Talk entities
q = [{
  "FindEntity": {
    "with_class": "Talk",
    "sort": { "key": "talk_title", "order": "ascending" },
    "limit": 10000,
    "results": { "list": ["talk_title"] }
  }
}]

resp, _ = con.query(q)
rows = resp[0]["FindEntity"].get("entities", [])
titles = [r["talk_title"] for r in rows]

# Pretty print
for i, t in enumerate(titles, 1):
    print(f"{i:3d}. {t}")
# Out:
#   1. 2022 AI Index Report Briefing
#   2. 7 Questions for Data Scientists
#   3. A Data Scientist Guide to Unit & End to End Testing
#   4. A Guide to Putting Together a Continuous ML Stack
#   5. A machine learning-driven phenotyping platform for rapid in vivo target validation and precision medicine development
#   6. A Practical Guide to Efficient AI
#   7. A Practitioner's Guide To Safeguarding Your LLM Applications
#   8. Advances in Algorithmic Recourse: Ensuring Causal Consistency, Fairness, & Robustness
#   9. Agentic AI: Learning Iteratively, Acting Autonomously
#  10. Agentic AI: Unlocking Emergent Behavior in LLMs for Adaptive Workflow Automation
#  11. AI @ Scale to Understand Impact of Weather on Businesses
#  12. AI & Sustainability: A $50 trillion opportunity
#  13. AI Agents with Function Calling/Tool Use
#  14. AI as an Engineering Discipline
#  15. AI Features Demand Evidence-Based Decisions
#  16. AI for AI-Scotiabank's Award-Winning ML Models
#  17. AI for Hospitals at Scale
#  18. AI Governance: Accelerate Responsible, Transparent, and Explainable AI Workflows
#  19. AI Tools Under Control: Keeping Your Agents Secure and Reliable
#  20. AI-ready Data Infrastructure for Real-time Sensor Data Analytics on the Edge
#  21. An Introduction to Drift Detection
#  22. An open-source approach to build guardrails for deploying ML models in healthcare
#  23. Applying GitOps principles at every step of an E2E MLOps project - an interactive workshop
#  24. Applying Responsible AI with the Open-Source LangTest Library
#  25. Artificial Intelligence And Digital Pathology: Making The Most of Limited Annotated Data
#  26. Ask the Graph: How Knowledge Graphs Helps Generative AI Models Answer Questions
#  27. Assessing Alignment of Climate Disclosures Using NLP for the Financial Markets
#  28. AutoGen: Enabling Next-Gen AI Applications via Multi-Agent Conversation
#  29. Automated Inspection for rail cars using computer vision and machine learning
#  30. Automating Knowledge Work with Generative AI
#  31. Avoid ML OOps with ML Ops: A modular approach to scaling Forethought’s E2E ML Platform
#  32. Beyond the Kaggle Paradigm: Future of End-to-End ML Platforms
#  33. BloombergGPT: How we built a 50 billion parameter financial language model
#  34. Build with Mistral
#  35. Building a Conversation-focused LLM on Communication Data
#  36. Building a Fraud Detection Model with Feature Stores (Includes Bonus Case Study: How Shopify uses Feast to Manage its ML Features)
#  37. Building a Measurement System for Personalization: A Bayesian Approach
#  38. Building a Multimodal RAG: A Step-by-Step Guide for AI/ML practitioners
#  39. Building a Production-Grade Document Understanding System with LLMs
#  40. Building Agentic and Multi-Agent Systems with LangGraph
#  41. Building Agentic and Multi-Agent Systems with LangGraph (Pt. 2)
#  42. Building AI Applications as a Developer
#  43. Building AI Applications with Transformers
#  44. Building AI Infrastructure for the GenAI Wave
#  45. Building an end-to-end MLOps Pipeline
#  46. Building an end-to-end web application integrated with Microsoft's Semantic Kernel and a Large Language Model
#  47. Building an MLOps Team
#  48. Building an Open-Source Agentic RAG Application with Llama
#  49. Building and Evaluating Prompts on Production Grade Datasets
#  50. Building Automated Model Life Cycles to Show Data Science Business Contribution, Minimize the Impact of Regulation & Governance Requirements,& Keep the Freedom of Innovation
#  51. Building GenAI-Powered Apps: A Workshop for Software Engineers
#  52. Building Reproducible ML Processes with an Open Source Stack
#  53. Building state-of-the-art chat bot using open source models and composite systems
#  54. Building Trust in ML Systems
#  55. Builidng a fully automated ML Platform using Kubeflow and declarative approach to development of end-to-end ML pipelines.
#  56. Business Panel: GenAI Use-cases Across Industry Verticals. Early Trends and ROI
#  57. Challenges and Learnings of Machine Learning at scale
#  58. Chat with MLOpsWorld: Engineering an LLM Application
#  59. Code Generation Agents: Architecture, Data Modeling Challenges, and Production-Ready Considerations
#  60. Code Smarter, not harder: Generative AI in the Software Development Lifecycle
#  61. Compute Strategies for Generative AI
#  62. Connecting the Dots Between AI Ethics and Sustainability
#  63. Creating an ML model as a business user
#  64. Creating our own private OpenAI API
#  65. Creating the World’s Premier Biological Foundation Model
#  66. Data FAILS
#  67. Data Storytelling for Beginners
#  68. Data Versioning in Generative AI: A Pathway to Cost-Effective ML
#  69. De-Risk Your AI Efforts by Removing Friction From Your MLOps Processes
#  70. Demystifying Large Language Models: ChatGPT, GPT-4, and the Future of AI Communication
#  71. Demystifying Multi-Agent Patterns
#  72. Deploying a Machine Learning Model in under 15 Minutes at Wealthsimple
#  73. Deploying and Evaluating RAG pipelines with Lightning Studios
#  74. Deploying Generative AI Models: Best Practices and an Interactive Example
#  75. Deploying LLMs on Kubernetes environments
#  76. Digital Twin as a tool for Industrial Asset Management
#  77. DL-Backtrace by AryaXAI: A Model Agnostic Explainability for Any Deep Learning Models (LLMs to CV)
#  78. Do we still need clinical large language models?
#  79. Driving GenAI Success in Production: Proven Approaches for Data Quality, Context, and Logging
#  80. Dynamic Huff's Gravity Model with Covariates for Site Visitation Prediction
#  81. Efficient Inference of Extremely Large Transformer Models
#  82. Enabling GenAI Breakthroughs with Knowledge Graphs
#  83. Era of Multimodal AI & Reasoning
#  84. Evaluating LLM-Judge Evaluations: Best Practices
#  85. Evaluation Techniques for Large Language Models
#  86. Everything You Need to Know about Fine-Tuning
#  87. Evolution of ML Training and Serving Infrastructure at Pinterest
#  88. Evolved Structures: Using AI and Robots to build spaceflight structures at NASA
#  89. Evolving with AI: Insights from Nyla's Generative AI Journey
#  90. Expert Insight - The Value of Solving Business Weather Challenges
#  91. Explainable Machine Learning in Finance – What If Machines Beat the Human Intelligence?
#  92. Exploring the Frontier of Graph Neural Networks: Key Concepts, Architectures, and Trends
#  93. Extending PyTorch for Custom Compiler Targets
#  94. Fast and Reproducible: Taming AI/ML dependencies
#  95. Fast Data Loading for Deep Learning Workloads with lakeFS Mount
#  96. Feature Stores in Practice: Train and Deploy an End-to-End Fraud Detection Model with Featureform, Redis, and AWS.
#  97. Finding the hidden drivers of AI business value
#  98. Fine-tune LLMs or Integrate 3rd party APIs? A financial Case-study
#  99. Fine-tuning Language Models with Declarative ML Orchestration
# 100. Finetuning a large language model on a custom dataset
# 101. FL4Health: Private and Personal Clinical Modeling
# 102. From Black Box to Glass Box: Interpreting your Model
# 103. From Black Box to Mission Critical: Implementing Advanced AI Explainability and Alignment in FSIs
# 104. From Chaos to Control: Mastering ML Reproducibility at scale
# 105. From ML Repository to ML Production Pipeline
# 106. From Model T to Machine Learning: A Glimpse into Ford's MLOps and Hybrid Infrastructure Strategy
# 107. From Paper to Production in 30 Minutes: Implementing code-less Gen AI Research
# 108. From Prototype to Product: Rapid iteration and ML model deployment at Dropbox
# 109. From silo to collaboration - building tooling to support distributed ML teams at Twitch
# 110. From Silos to Synergy: MLOps & Developers Unified
# 111. Fuel iX: An enterprise grade Gen AI platform
# 112. GenAI Investing in 2024
# 113. GenAI ROI: From Pilot to Profit
# 114. GenAI: A New Renaissance in Product Development
# 115. Generative AI Design Patterns
# 116. Generative AI: the open source way
# 117. Getting higher ROI on MLOps initiatives: five lessons learned while building out the MLOps Platform for 100+ Data Scientists
# 118. Getting started with Generative Text and Fine-tuning LLMs in Hugging Face
# 119. Goose, Chewbacca, and AI: Safely flying the generative AI coding skies
# 120. Growing your ML career via technical writing and speaking: Tips and lessons
# 121. Hands-on Scalable Edge-to-Core ML Pipelines
# 122. Hemm: Holistic Evaluation of Multi-modal Generative Models
# 123. How do you make GenAI safe, trustworthy and useful for enterprises?
# 124. How do you scale to billions of fine-tuned LLMs?
# 125. How GenAI is Being Used for Productivity at Wealthsimple
# 126. How Is GenAI Reshaping the Business?
# 127. How many Labelled Examples do you need for a BERT-sized Model to Beat GPT4 on Predictive Tasks?
# 128. How NOT to get ML Models into production
# 129. How to Build your Own LLM User Feedback Loop with Nebuly.
# 130. How to Design and Build Resilient Machine Learning Systems
# 131. How to Run Your Own LLMs, From Silicon to Service
# 132. Hyper-scaling Real-time Personalization with Privacy via on-device computing
# 133. Industrializing ML Workflows in Drug Discovery
# 134. Intelligent Writing Assistants in the era of Large Language Models
# 135. Interpretability Tools are Feedback Loops
# 136. Introducing the Tenstorrent Model Zoo
# 137. Introduction to Building ML Microservices: A hands-on approach with examples from the music industry
# 138. Introduction to LangChain and Retrieval Augmented Generation (RAG)
# 139. Investigating the Evolution of Evaluation from Model Training to GenAI inference
# 140. Is it too much to ask for a stable baseline?
# 141. Kùzu - A fast, scalable graph database for analytical workloads
# 142. LanceDB: a unified storage layer for vector search, analytics, and model training
# 143. Large Language Model Training and Serving at LinkedIn
# 144. Large Neural Nets for Amortized Probabilistic Inference for Highly Multimodal Distributions and Model-Based ML
# 145. Latent User Intent Modeling in Recommender Systems
# 146. Launching Scotiabank's Customer Facing Chatbot for a Large Organization: From Cold Start Problem to Implementation
# 147. Learn Your Codebase: Fine-tuning CodeLlama with Flyte… to Learn Flyte
# 148. Learning Embedded Representation of the Stock Correlation Matrix using Graph Machine Learning
# 149. Learning from Extremes: What Fraud-Fighting at Scale Can Teach Us About MLOps Across Domains
# 150. LeRobot: Democratizing Robotics
# 151. Lessons Learned Productionising LLMs for Stripe Support
# 152. Lessons Learned: The Journey to Real-Time Machine Learning at Instacart
# 153. Leverage Kubernetes To Optimize the Utilization of Your AI Accelerators
# 154. Leveraging Large Language Models to build Enterprise AI
# 155. Leveraging ML in Multi-Family Real Estate Industry: From Predicting Rentals to Streamlining Operations
# 156. LLM economics : The Cost of leveraging Large Language Models
# 157. LLM evaluation to craft delightful content from messy inputs
# 158. LLMidas' Touch; Safely adopting GenAI for production use-cases
# 159. LLMs Alone Do Not Solve Business Problems
# 160. LLMs for Leaders & Senior Product Managers
# 161. LLMs for Revolutionizing Credit Risk Assessment
# 162. LLMs from hallucinations to relevant responses
# 163. LLMs in Practice: A Guide to Recent Techniques and Trends
# 164. LLMs, Big Data, and Audio: Breaching an Untapped Gold Mine
# 165. LLMs, from Playgrounds to Production-ready Pipelines
# 166. Looking into AI/ML from a Venture Capital lens
# 167. Low-latency Model Inference in Finance
# 168. Machine Unlearning: Addressing Bias, Privacy, and Regulation in LLMs and Multimodal Models
# 169. Making ChatGPT funny with Prompt Optimization
# 170. Making GenAI Safe, Trustworthy and Fit-for-purpose with Auto Alignment
# 171. Making RAG (Retrieval Augmented Generation) Work
# 172. Managing AI and the Associated Risks in a Regulatory Environment
# 173. Marketplace experimentation at SpotHero
# 174. Mastering Enterprise-Grade LLM Deployment: Overcoming Production Challenges
# 175. Measuring the Minds of Machines: Evaluating Generative AI Systems
# 176. MemeGPT: Creating a Large Language Model to Generate Memes
# 177. Memory Optimizations for Machine Learning
# 178. ML Deployment at Faire: Predicting the Future, Serving the Present
# 179. ML Experimentation with DVC and VS Code
# 180. ML in Production: Implementation, Tooling & Engineering, Data/ML Ops
# 181. MLOps for AgenticAI: How to manage Agents in production
# 182. MLOps isn't that hard: Create a Modular Stack with Open-Source Tools
# 183. MLOps Template for Time Series in Production
# 184. Model Lifecycle in Banking
# 185. Modular Solutions for Knowledge Management at scale in RAG Systems
# 186. Monitoring LLMs: Where to Begin? What's Important?
# 187. Monitoring Unstructured Models in Production
# 188. Multi-Graph Multi-Agent systems - Determinism through Structured Representations
# 189. Multimodal Agents You Can Deploy Anywhere
# 190. Multimodal LLMs for product taxonomy at Shopify
# 191. Navigating LLM Deployment: Tips, Tricks and Techniques
# 192. Navigating the Tradeoff Between Privacy and Fairness in ML
# 193. On-Device ML for LLMs: Post-training Optimization Techniques with T5 and Beyond
# 194. Open-Ended and AI-Generating Algorithms in the Era of Foundation Models
# 195. OpenFL: A Federated Learning Project to Power (and secure) Your Projects
# 196. Operationalizing data-centric AI: Practical algorithms + software to quickly improve ML datasets
# 197. Optimal Beer Pricing: An Optimization Layer for Price Elasticities
# 198. Optimized AI Deployment Platform
# 199. Optimizing AI/ML Workflows on Kubernetes: Advanced Techniques and Integration
# 200. Optimizing LLM apps through usage: Implicit feedback, given explicitly
# 201. Optimizing Personalized User Experience: In-session Recommendations Across E-commerce Verticals
# 202. Optimizing Recommendations on Wattpad Home
# 203. Oracles and Worker Bees: The future of AI models
# 204. Outracing Champion Gran Turismo Drivers With Deep Reinforcement Learning
# 205. Panel: "Bias and Relevance in Application of ML in Healthcare"
# 206. Panel: Achieving Long-Term AI Growth: Real Problem Solving vs. Trend-Based Solutions
# 207. Panel: How companies can navigate and approach the new advancements in generative AI
# 208. Panel: RAGs in Production: Delivering Impact Safely and Efficiently
# 209. Panel: The Current Investment Landscape. Opportunities & Challenges in ML/Gen AI
# 210. Pre-Trained Multilingual Sequence-to-Sequence Models for NMT: Tips, Tricks and Challenges
# 211. Privacy & Security of Large Language Models, Risks and Mitigation
# 212. Privacy Risks and Protections in Machine Learning Systems
# 213. Production ML Serving & Monitoring in Kubernetes
# 214. Prompt Optimization and Parameter Efficient Fine-Tuning
# 215. ProxyLM: Predicting Language Model Performance on Multilingual Tasks via Proxy Models
# 216. PyScript for data science
# 217. QA in ML
# 218. Quantifying the uncertainty in model predictions
# 219. RAG Hyperparameter Optimization: Translating a Traditional ML Design Pattern to RAG Applications
# 220. Rapid Deployment of LLMs into Production: Strategies and Insights
# 221. Real-time Machine Learning: Architecture and Challenges
# 222. Recommender Systems at Loblaw Digital
# 223. Revolutionizing Cloud Storage: From Petabytes to Intelligence
# 224. Revolutionizing Fraud Prevention: Harnessing AI and ML to Safeguard Banking from Fraud
# 225. Revolutionizing the skies: Mlops case study of LATAM airlines
# 226. RISC-y Business: How open chip architectures are changing the AI ecosystem for the better
# 227. Robustness with Sidecars: Weak-To-Strong Supervision For Making Generative AI Robust For Enterprise
# 228. Saga: Continuous Construction and Serving of Large Scale Knowledge Graphs
# 229. Saving Lives with ML: Applications and Learnings
# 230. Scale Expert Review by 10x to Ship AI Apps at Lightning Speed
# 231. Scaling & Evolving the Machine Learning Platform at DoorDash
# 232. Scaling Advanced Analytics in the Worst Crisis in the Industry Area
# 233. Scaling Vector Database Usage Without Breaking the Bank: Quantization and Adaptive Retrieval
# 234. Sensitivity and interpretability of AI-models
# 235. Serving GenAI Workload At Scale With LitServe
# 236. Simulation and Prediction - exploring the Digital Twin Technology stack.
# 237. Solving Product Substitutions, A Big Problem in Grocery E-Commerce – Through Self-Supervised ML
# 238. Spend Less Time Troubleshooting ML Production Issues
# 239. Stable Diffusion for Your Images: Custom Dream
# 240. Striking the Balance: Leveraging Human Intelligence with LLMs for Cost-Effective Annotations
# 241. Successfully integrating AI in your strategy and business operations – Lessons learnt from investing
# 242. Supercharge ML Teams: ZenML's Real World Impact in the MLOps Jungle
# 243. Supercharging Recommender Systems: Unleashing the Power of Distributed Model Training
# 244. Supercharging Search with LLMs: The Instacart Journey
# 245. Synthetic Data: Generative AI for Enhanced Data Quality in the Era of Foundational Models
# 246. Testing for fairness in AI HR systems: hidden dangers and real-world lessons on how to detect and prevent bias
# 247. The Application of Mobile Location Data for Vending Machine Site Selection and Revenue Optimization.
# 248. The Dual Nature of Consistency in Foundation Models: Challenges and Opportunities
# 249. The fairness of fairness: Evaluating, Monitoring, and Impacts of ML in Insurance
# 250. The framework for great ML products
# 251. The Gap From Prototype to Production: Lessons Learned from Implementing Applications with LLMs
# 252. The Missing Piece of MLOps
# 253. The Natural Language Processing Revolution in Investment Management: Advice and Responsible Investing
# 254. The risks of excluding the disengaged from your dataset
# 255. The Role of Alternative Data in Investing
# 256. The State-of-the-Art in Software Development Agents
# 257. The transformative role of AI/ML in heavy industries
# 258. Tips & Tricks for Intentional Text-to-Image Generation
# 259. Towards Trustworthy Automatic Diagnosis Systems by Emulating Doctors’ Reasoning with Deep Reinforcement Learning
# 260. Toyota's Generative AI Journey
# 261. Training large language models: lessons from the trenches
# 262. Transforming The Retail Industry with Transformers
# 263. Transitioning from LLMs to Autonomous Agents in Programming and Software Engineering
# 264. Troubleshooting Unstructured Data with Embeddings
# 265. Troubleshooting your ML Models in Production
# 266. Uncertainty Quantification with Conformal Prediction: A Path to Reliable ML Models
# 267. Understanding  Where Generative AI fits into Business
# 268. Unleashing the Algorithm Genie: AI as the Ultimate Inventor
# 269. Unleashing the Full Potential of Your Recommender System in Production
# 270. Unlocking the Potential of Data in the Aviation Industry
# 271. Unraveling Long Context: Existing Methods, Challenges, and Future Directions
# 272. Upskilling Your Full-Stack Development Team in Machine Learning
# 273. We’re Doing RAG All Wrong—and How We Can Do So Much Better
# 274. Web Extraction With LLMs
# 275. What To Look For In Your Next ML Pipeline
# 276. Where's the Road? The Challenge of Autonomous Driving Perception in Winter
# 277. Why real-time event streaming pattern is indispensable for an AI native future
# 278. Your AI applications need Guardrails: Here's how to build them

# %% [markdown]
# ### Sanity check queries

# %%
client = create_connector(key=APERTUREDB_KEY)

def run(q):
    resp, blobs = client.query(q)
    client.print_last_response()
    return resp

# %% [markdown]
# 1) How many transcript chunks are in the set?

# %%
run([{
  "FindDescriptor": {
    "set": "ds_transcript_chunks_v1",
    "results": { "count": True }
  }
}])
# Out:
# [
#     {
#         "FindDescriptor": {
#             "count": 16887,
#             "returned": 0,
#             "status": 0
#         }
#     }
# ]
# [{'FindDescriptor': {'count': 16887, 'returned': 0, 'status': 0}}]

# %% [markdown]
# 2) How many chunks for a specific talk (by talk_title)?

# %%
run([
  {
    "FindEntity": {
      "_ref": 1,
      "with_class": "Talk",
      "unique": True,
      "constraints": { "talk_title": ["==", "LLMs, from Playgrounds to Production-ready Pipelines"] },
      "results": { "list": ["talk_id","talk_title"] }
    }
  },
  {
    "FindDescriptor": {
      "set": "ds_transcript_chunks_v1",
      "is_connected_to": { "ref": 1, "connection_class": "TalkHasTranscriptChunk" },
      "results": { "count": True }
    }
  }
]
)
# Out:
# [
#     {
#         "FindEntity": {
#             "entities": [
#                 {
#                     "talk_id": "cade4e0c-5922-57c4-9dba-98ea942da9de",
#                     "talk_title": "LLMs, from Playgrounds to Production-ready Pipelines"
#                 }
#             ],
#             "returned": 1,
#             "status": 0
#         }
#     },
#     {
#         "FindDescriptor": {
#             "count": 36,
#             "returned": 0,
#             "status": 0
#         }
#     }
# ]
# [{'FindEntity': {'entities': [{'talk_id': 'cade4e0c-5922-57c4-9dba-98ea942da9de',
#      'talk_title': 'LLMs, from Playgrounds to Production-ready Pipelines'}],
#    'returned': 1,
#    'status': 0}},
#  {'FindDescriptor': {'count': 36, 'returned': 0, 'status': 0}}]

# %% [markdown]
# 3) Show the first 3 chunks (by seq) for that talk

# %%
run([
  {
    "FindEntity": {
      "_ref": 1,
      "with_class": "Talk",
      "unique": True,
      "constraints": { "talk_title": ["==", "LLMs, from Playgrounds to Production-ready Pipelines"] },
      "results": { "list": ["talk_id"] }
    }
  },
  {
    "FindDescriptor": {
      "set": "ds_transcript_chunks_v1",
      "is_connected_to": { "ref": 1, "connection_class": "TalkHasTranscriptChunk" },
      "sort": { "key": "seq", "order": "ascending" },
      "limit": 3,
      "results": { "list": ["chunk_id","seq","start_sec","end_sec","chunk_text"] }
    }
  }
]
)
# Out:
# [
#     {
#         "FindEntity": {
#             "entities": [
#                 {
#                     "talk_id": "cade4e0c-5922-57c4-9dba-98ea942da9de"
#                 }
#             ],
#             "returned": 1,
#             "status": 0
#         }
#     },
#     {
#         "FindDescriptor": {
#             "entities": [
#                 {
#                     "chunk_id": "cade4e0c-5922-57c4-9dba-98ea942da9de#ch0001",
#                     "chunk_text": "yeah thanks for coming my name is Inu I'm a CPO and co-founder of SL aai and um yeah I'm also uh UT Austin computer science alumni so I can see some few longer so welcome welcome to uh Austin so yeah I'm going to start with um today's goal here uh we're going to start from the inference demo with llama 2 C and then uh starting from there we can do uh we'll do some training fine-tuning serving and um lastly we do some uh putting everything together as a cicd pipelines uh I'm going to do some rag examples so yeah I don't know if you guys have familiar with these terms um so yeah llama 2 is uh published by meta and Lama 2.c is uh uh is a mini uh Mini model of llama 2 uh which is made by uh Andre Kacy from open AI so you can learn uh I mean you can training on um gpus but you can influence them in uh in the CPUs so I take this as a playground um",
#                     "end_sec": 76,
#                     "seq": 1,
#                     "start_sec": 4
#                 },
#                 {
#                     "chunk_id": "cade4e0c-5922-57c4-9dba-98ea942da9de#ch0002",
#                     "chunk_text": "Andre Kacy from open AI so you can learn uh I mean you can training on um gpus but you can influence them in uh in the CPUs so I take this as a playground um examples so uh rag I'm going to explain a little bit more about the rag uh in the last um last few minutes but uh it's basically the retrieval thing so you can reduce your hallucinations of large language models so yeah um let's get started so um you might have a this three questions like why open source large language models I mean there are um like tons of uh propriety models like GPT 4 gpt2 and um some Cloud uh from entropic but uh why are we going to talk about open source large language models and secondly why self-hosted open source models um so a company like open AI uh release their features like uh fine",
#                     "end_sec": 128,
#                     "seq": 2,
#                     "start_sec": 60
#                 },
#                 {
#                     "chunk_id": "cade4e0c-5922-57c4-9dba-98ea942da9de#ch0003",
#                     "chunk_text": "open source large language models and secondly why self-hosted open source models um so a company like open AI uh release their features like uh fine tuning and also you can do some API calls to the open AI models but why do you why do we need to have self-hosted open source large language models um and third uh okay so I'm uh I know why we want uh why we need llama and uh why we need to self hostage them then how to deploy large language models into production so yeah that's uh those three questions is a main uh subject of this speak so yeah um the first question uh open open source models versus propriety models um Accord according to the language model system.org leaderboard um unfortunately no open source model has beaten the propriety models yet so the top five models are propriety models it's uh GPT 4 Cloud one",
#                     "end_sec": 185,
#                     "seq": 3,
#                     "start_sec": 116
#                 }
#             ],
#             "returned": 3,
#             "status": 0
#         }
#     }
# ]
# [{'FindEntity': {'entities': [{'talk_id': 'cade4e0c-5922-57c4-9dba-98ea942da9de'}],
#    'returned': 1,
#    'status': 0}},
#  {'FindDescriptor': {'entities': [{'chunk_id': 'cade4e0c-5922-57c4-9dba-98ea942da9de#ch0001',
#      'chunk_text': "yeah thanks for coming my name is Inu I'm a CPO and co-founder of SL aai and um yeah I'm also uh UT Austin computer science alumni so I can see some few longer so welcome welcome to uh Austin so yeah I'm going to start with um today's goal here uh we're going to start from the inference demo with llama 2 C and then uh starting from there we can do uh we'll do some training fine-tuning serving and um lastly we do some uh putting everything together as a cicd pipelines uh I'm going to do some rag examples so yeah I don't know if you guys have familiar with these terms um so yeah llama 2 is uh published by meta and Lama 2.c is uh uh is a mini uh Mini model of llama 2 uh which is made by uh Andre Kacy from open AI so you can learn uh I mean you can training on um gpus but you can influence them in uh in the CPUs so I take this as a playground um",
#      'end_sec': 76,
#      'seq': 1,
#      'start_sec': 4},
#     {'chunk_id': 'cade4e0c-5922-57c4-9dba-98ea942da9de#ch0002',
#      'chunk_text': "Andre Kacy from open AI so you can learn uh I mean you can training on um gpus but you can influence them in uh in the CPUs so I take this as a playground um examples so uh rag I'm going to explain a little bit more about the rag uh in the last um last few minutes but uh it's basically the retrieval thing so you can reduce your hallucinations of large language models so yeah um let's get started so um you might have a this three questions like why open source large language models I mean there are um like tons of uh propriety models like GPT 4 gpt2 and um some Cloud uh from entropic but uh why are we going to talk about open source large language models and secondly why self-hosted open source models um so a company like open AI uh release their features like uh fine",
#      'end_sec': 128,
#      'seq': 2,
#      'start_sec': 60},
#     {'chunk_id': 'cade4e0c-5922-57c4-9dba-98ea942da9de#ch0003',
#      'chunk_text': "open source large language models and secondly why self-hosted open source models um so a company like open AI uh release their features like uh fine tuning and also you can do some API calls to the open AI models but why do you why do we need to have self-hosted open source large language models um and third uh okay so I'm uh I know why we want uh why we need llama and uh why we need to self hostage them then how to deploy large language models into production so yeah that's uh those three questions is a main uh subject of this speak so yeah um the first question uh open open source models versus propriety models um Accord according to the language model system.org leaderboard um unfortunately no open source model has beaten the propriety models yet so the top five models are propriety models it's uh GPT 4 Cloud one",
#      'end_sec': 185,
#      'seq': 3,
#      'start_sec': 116}],
#    'returned': 3,
#    'status': 0}}]

# %% [markdown]
# 4) Fetch chunks for a time range within a talk (e.g., 60s–300s)

# %%
run([
  {
    "FindEntity": {
      "_ref": 1,
      "with_class": "Talk",
      "unique": True,
      "constraints": { "talk_title": ["==", "LLMs, from Playgrounds to Production-ready Pipelines"] },
      "results": { "list": ["talk_id"] }
    }
  },
  {
    "FindDescriptor": {
      "set": "ds_transcript_chunks_v1",
      "is_connected_to": { "ref": 1, "connection_class": "TalkHasTranscriptChunk" },
      "constraints": {
        "start_sec": [">=", 60],
        "end_sec": ["<=", 300]
      },
      "sort": "seq",
      "results": { "list": ["seq","start_sec","end_sec","chunk_id"] }
    }
  }
])
# Out:
# [
#     {
#         "FindEntity": {
#             "entities": [
#                 {
#                     "talk_id": "cade4e0c-5922-57c4-9dba-98ea942da9de"
#                 }
#             ],
#             "returned": 1,
#             "status": 0
#         }
#     },
#     {
#         "FindDescriptor": {
#             "entities": [
#                 {
#                     "chunk_id": "cade4e0c-5922-57c4-9dba-98ea942da9de#ch0002",
#                     "end_sec": 128,
#                     "seq": 2,
#                     "start_sec": 60
#                 },
#                 {
#                     "chunk_id": "cade4e0c-5922-57c4-9dba-98ea942da9de#ch0003",
#                     "end_sec": 185,
#                     "seq": 3,
#                     "start_sec": 116
#                 },
#                 {
#                     "chunk_id": "cade4e0c-5922-57c4-9dba-98ea942da9de#ch0004",
#                     "end_sec": 240,
#                     "seq": 4,
#                     "start_sec": 170
#                 },
#                 {
#                     "chunk_id": "cade4e0c-5922-57c4-9dba-98ea942da9de#ch0005",
#                     "end_sec": 297,
#                     "seq": 5,
#                     "start_sec": 229
#                 }
#             ],
#             "returned": 4,
#             "status": 0
#         }
#     }
# ]
# [{'FindEntity': {'entities': [{'talk_id': 'cade4e0c-5922-57c4-9dba-98ea942da9de'}],
#    'returned': 1,
#    'status': 0}},
#  {'FindDescriptor': {'entities': [{'chunk_id': 'cade4e0c-5922-57c4-9dba-98ea942da9de#ch0002',
#      'end_sec': 128,
#      'seq': 2,
#      'start_sec': 60},
#     {'chunk_id': 'cade4e0c-5922-57c4-9dba-98ea942da9de#ch0003',
#      'end_sec': 185,
#      'seq': 3,
#      'start_sec': 116},
#     {'chunk_id': 'cade4e0c-5922-57c4-9dba-98ea942da9de#ch0004',
#      'end_sec': 240,
#      'seq': 4,
#      'start_sec': 170},
#     {'chunk_id': 'cade4e0c-5922-57c4-9dba-98ea942da9de#ch0005',
#      'end_sec': 297,
#      'seq': 5,
#      'start_sec': 229}],
#    'returned': 4,
#    'status': 0}}]

# %% [markdown]
# 5) Grab a specific chunk by chunk_id

# %%
run([{
  "FindDescriptor": {
    "set": "ds_transcript_chunks_v1",
    "unique": True,
    "constraints": { "chunk_id": ["==", "cade4e0c-5922-57c4-9dba-98ea942da9de#ch0004"] },
    "results": { "list": ["chunk_id","talk_id","seq","start_sec","end_sec","chunk_text"] }
  }
}]
)
# Out:
# [
#     {
#         "FindDescriptor": {
#             "entities": [
#                 {
#                     "chunk_id": "cade4e0c-5922-57c4-9dba-98ea942da9de#ch0004",
#                     "chunk_text": "language model system.org leaderboard um unfortunately no open source model has beaten the propriety models yet so the top five models are propriety models it's uh GPT 4 Cloud one two and another cloud and GPT 3.5 turbo so um yeah uh also there's like hyper gap between open and close model uh due to the investment because um I mean uh for instance like an entropic interview uh a CEO of the entropic they're going to uh invest like1 billion by 2025 uh that's a lot of investment and it's about like 10% of Enterprise value of open AI um yeah well let alone with the investment open AI has a great uh infrastructure um so I do a little bit of math here so let's say you're going to fine tuning with open AI versus hiring engineers and tuning on",
#                     "end_sec": 240,
#                     "seq": 4,
#                     "start_sec": 170,
#                     "talk_id": "cade4e0c-5922-57c4-9dba-98ea942da9de"
#                 }
#             ],
#             "returned": 1,
#             "status": 0
#         }
#     }
# ]
# [{'FindDescriptor': {'entities': [{'chunk_id': 'cade4e0c-5922-57c4-9dba-98ea942da9de#ch0004',
#      'chunk_text': "language model system.org leaderboard um unfortunately no open source model has beaten the propriety models yet so the top five models are propriety models it's uh GPT 4 Cloud one two and another cloud and GPT 3.5 turbo so um yeah uh also there's like hyper gap between open and close model uh due to the investment because um I mean uh for instance like an entropic interview uh a CEO of the entropic they're going to uh invest like1 billion by 2025 uh that's a lot of investment and it's about like 10% of Enterprise value of open AI um yeah well let alone with the investment open AI has a great uh infrastructure um so I do a little bit of math here so let's say you're going to fine tuning with open AI versus hiring engineers and tuning on",
#      'end_sec': 240,
#      'seq': 4,
#      'start_sec': 170,
#      'talk_id': 'cade4e0c-5922-57c4-9dba-98ea942da9de'}],
#    'returned': 1,
#    'status': 0}}]

# %% [markdown]
# 6) List the first & last chunk for a talk (check boundaries)

# %%
run([
  {
    "FindEntity": {
      "_ref": 1,
      "with_class": "Talk",
      "unique": True,
      "constraints": { "talk_title": ["==", "LLMs, from Playgrounds to Production-ready Pipelines"] }
    }
  },
  {
    "FindDescriptor": {
      "set": "ds_transcript_chunks_v1",
      "is_connected_to": { "ref": 1, "connection_class": "TalkHasTranscriptChunk" },
      "sort": { "key": "seq", "order": "ascending" },
      "limit": 1,
      "results": { "list": ["seq","start_sec","end_sec","chunk_id"] }
    }
  },
  {
    "FindDescriptor": {
      "set": "ds_transcript_chunks_v1",
      "is_connected_to": { "ref": 1, "connection_class": "TalkHasTranscriptChunk" },
      "sort": { "key": "seq", "order": "descending" },
      "limit": 1,
      "results": { "list": ["seq","start_sec","end_sec","chunk_id"] }
    }
  }
])
# Out:
# [
#     {
#         "FindEntity": {
#             "returned": 0,
#             "status": 0
#         }
#     },
#     {
#         "FindDescriptor": {
#             "entities": [
#                 {
#                     "chunk_id": "cade4e0c-5922-57c4-9dba-98ea942da9de#ch0001",
#                     "end_sec": 76,
#                     "seq": 1,
#                     "start_sec": 4
#                 }
#             ],
#             "returned": 1,
#             "status": 0
#         }
#     },
#     {
#         "FindDescriptor": {
#             "entities": [
#                 {
#                     "chunk_id": "cade4e0c-5922-57c4-9dba-98ea942da9de#ch0036",
#                     "end_sec": 1911,
#                     "seq": 36,
#                     "start_sec": 1911
#                 }
#             ],
#             "returned": 1,
#             "status": 0
#         }
#     }
# ]
# [{'FindEntity': {'returned': 0, 'status': 0}},
#  {'FindDescriptor': {'entities': [{'chunk_id': 'cade4e0c-5922-57c4-9dba-98ea942da9de#ch0001',
#      'end_sec': 76,
#      'seq': 1,
#      'start_sec': 4}],
#    'returned': 1,
#    'status': 0}},
#  {'FindDescriptor': {'entities': [{'chunk_id': 'cade4e0c-5922-57c4-9dba-98ea942da9de#ch0036',
#      'end_sec': 1911,
#      'seq': 36,
#      'start_sec': 1911}],
#    'returned': 1,
#    'status': 0}}]

# %% [markdown]
# 7) Pull chunks for multiple talks and group by source (nice visual check)

# %%
run([
  {
    "FindEntity": {
      "_ref": 1,
      "with_class": "Talk",
      "constraints": {
        "talk_title": ["in", ["LLMs, from Playgrounds to Production-ready Pipelines","Leverage Kubernetes To Optimize the Utilization of Your AI Accelerators","LLMs, Big Data, and Audio: Breaching an Untapped Gold Mine"]]
      },
      "results": { "list": ["talk_title","talk_id"] }
    }
  },
  {
    "FindDescriptor": {
      "set": "ds_transcript_chunks_v1",
      "is_connected_to": { "ref": 1, "connection_class": "TalkHasTranscriptChunk" },
      "group_by_source": True,
      "sort": "seq",
      "limit": 2,
      "results": { "list": ["seq","chunk_id"] }
    }
  }
]
)
# Out:
# [
#     {
#         "FindEntity": {
#             "entities": [
#                 {
#                     "talk_id": "cade4e0c-5922-57c4-9dba-98ea942da9de",
#                     "talk_title": "LLMs, from Playgrounds to Production-ready Pipelines"
#                 },
#                 {
#                     "talk_id": "02f5e445-8821-5cb1-bada-88586b0f9ac8",
#                     "talk_title": "Leverage Kubernetes To Optimize the Utilization of Your AI Accelerators"
#                 },
#                 {
#                     "talk_id": "95c82848-d9f9-54c3-a7eb-2f3fed38adac",
#                     "talk_title": "LLMs, Big Data, and Audio: Breaching an Untapped Gold Mine"
#                 }
#             ],
#             "returned": 3,
#             "status": 0
#         }
#     },
#     {
#         "FindDescriptor": {
#             "entities": {
#                 "7.12.260": [],
#                 "7.2.260": [
#                     {
#                         "chunk_id": "cade4e0c-5922-57c4-9dba-98ea942da9de#ch0001",
#                         "seq": 1
#                     }
#                 ],
#                 "7.3.260": [
#                     {
#                         "chunk_id": "02f5e445-8821-5cb1-bada-88586b0f9ac8#ch0001",
#                         "seq": 1
#                     }
#                 ]
#             },
#             "group_by_source": true,
#             "returned": 2,
#             "status": 0
#         }
#     }
# ]
# [{'FindEntity': {'entities': [{'talk_id': 'cade4e0c-5922-57c4-9dba-98ea942da9de',
#      'talk_title': 'LLMs, from Playgrounds to Production-ready Pipelines'},
#     {'talk_id': '02f5e445-8821-5cb1-bada-88586b0f9ac8',
#      'talk_title': 'Leverage Kubernetes To Optimize the Utilization of Your AI Accelerators'},
#     {'talk_id': '95c82848-d9f9-54c3-a7eb-2f3fed38adac',
#      'talk_title': 'LLMs, Big Data, and Audio: Breaching an Untapped Gold Mine'}],
#    'returned': 3,
#    'status': 0}},
#  {'FindDescriptor': {'entities': {'7.12.260': [],
#     '7.2.260': [{'chunk_id': 'cade4e0c-5922-57c4-9dba-98ea942da9de#ch0001',
#       'seq': 1}],
#     '7.3.260': [{'chunk_id': '02f5e445-8821-5cb1-bada-88586b0f9ac8#ch0001',
#       'seq': 1}]},
#    'group_by_source': True,
#    'returned': 2,
#    'status': 0}}]

# %% [markdown]
# 8) Quick K-NN sanity check from Python (embed a short phrase)

# %%
import numpy as np
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("google/embeddinggemma-300m")
qvec = model.encode(["query: Strategies to drive adoption of GenAI tools"], normalize_embeddings=True)[0].astype("<f4")

q = [{
  "FindDescriptor": {
    "set": "ds_transcript_chunks_v1",
    "k_neighbors": 20,
    "distances": True,
    "results": { "list": ["_distance","chunk_id","talk_id","seq","start_sec","end_sec","chunk_text"] }
  }
}]

resp, _ = con.query(q, blobs=[qvec.tobytes()])  # vector must be supplied as a blob
print(resp)
# Out:
# [{'FindDescriptor': {'entities': [{'_distance': 0.6840075254440308, 'chunk_id': '9726ea3b-4357-5b5b-823e-9d396e90da8c#ch0091', 'chunk_text': 'wonderful talk', 'end_sec': 1723, 'seq': 91, 'start_sec': 1723, 'talk_id': '9726ea3b-4357-5b5b-823e-9d396e90da8c'}, {'_distance': 0.6814993619918823, 'chunk_id': '2a206d50-b361-55a8-88ef-038e761ca717#ch0108', 'chunk_text': 'audience thank you', 'end_sec': 5344, 'seq': 108, 'start_sec': 5344, 'talk_id': '2a206d50-b361-55a8-88ef-038e761ca717'}, {'_distance': 0.678869366645813, 'chunk_id': 'a2d77613-e36e-5abd-bce1-89e08c2a075d#ch0010', 'chunk_text': "Enterprises are saying that they're already using generative AI or they have plans to use generative AI in the next one to two years and I would say that the these organizations are very smart to do so I truly believe that those organizations who are embracing and employing generative AI across their business are going to succeed and they are going to win over the organizations", 'end_sec': 212, 'seq': 10, 'start_sec': 184, 'talk_id': 'a2d77613-e36e-5abd-bce1-89e08c2a075d'}, {'_distance': 0.6725130081176758, 'chunk_id': 'cd9725e0-8921-53ee-8df8-1bdfc1476d5a#ch0101', 'chunk_text': 'address those questions right awesome thank you so much', 'end_sec': 1770, 'seq': 101, 'start_sec': 1770, 'talk_id': 'cd9725e0-8921-53ee-8df8-1bdfc1476d5a'}, {'_distance': 0.6718725562095642, 'chunk_id': '7ea49301-9f90-5352-92e8-841856646ef0#ch0082', 'chunk_text': 'version yeah', 'end_sec': 4241, 'seq': 82, 'start_sec': 4241, 'talk_id': '7ea49301-9f90-5352-92e8-841856646ef0'}, {'_distance': 0.6676285266876221, 'chunk_id': 'ac6e8399-8e2a-55b9-b323-49ba6b1dcc46#ch0095', 'chunk_text': 'um but all these techniques should be applicable for most most gpus that we are running it', 'end_sec': 1689, 'seq': 95, 'start_sec': 1689, 'talk_id': 'ac6e8399-8e2a-55b9-b323-49ba6b1dcc46'}, {'_distance': 0.6663516759872437, 'chunk_id': '658b3cca-7c39-5cd5-acf2-85c8451677b1#ch0105', 'chunk_text': 'the summit', 'end_sec': 5410, 'seq': 105, 'start_sec': 5410, 'talk_id': '658b3cca-7c39-5cd5-acf2-85c8451677b1'}, {'_distance': 0.665303111076355, 'chunk_id': '03fba756-58a1-557f-b60e-a39e948b557e#ch0072', 'chunk_text': 'thanks everyone', 'end_sec': 3610, 'seq': 72, 'start_sec': 3610, 'talk_id': '03fba756-58a1-557f-b60e-a39e948b557e'}, {'_distance': 0.663785457611084, 'chunk_id': '78cf2324-8257-527b-96a9-4b0e0af48312#ch0040', 'chunk_text': 'thank you [Applause]', 'end_sec': 1995, 'seq': 40, 'start_sec': 1995, 'talk_id': '78cf2324-8257-527b-96a9-4b0e0af48312'}, {'_distance': 0.6637853384017944, 'chunk_id': 'eb28b723-35d1-53cd-9155-8ad563a2c070#ch0096', 'chunk_text': 'thank you [Applause]', 'end_sec': 1786, 'seq': 96, 'start_sec': 1786, 'talk_id': 'eb28b723-35d1-53cd-9155-8ad563a2c070'}, {'_distance': 0.6627872586250305, 'chunk_id': '1fcefe17-ef25-5cee-910c-ad6f429e5b22#ch0016', 'chunk_text': 'chat with you guys [Applause]', 'end_sec': 298, 'seq': 16, 'start_sec': 298, 'talk_id': '1fcefe17-ef25-5cee-910c-ad6f429e5b22'}, {'_distance': 0.6592143774032593, 'chunk_id': '148d0355-aba5-5571-95d9-a73f0e19a551#ch0091', 'chunk_text': 'right', 'end_sec': 1722, 'seq': 91, 'start_sec': 1722, 'talk_id': '148d0355-aba5-5571-95d9-a73f0e19a551'}, {'_distance': 0.656467854976654, 'chunk_id': 'd0166d30-da69-5c07-a0ea-e5e18980e32c#ch0072', 'chunk_text': 'e e e e', 'end_sec': 3774, 'seq': 72, 'start_sec': 3774, 'talk_id': 'd0166d30-da69-5c07-a0ea-e5e18980e32c'}, {'_distance': 0.6553422212600708, 'chunk_id': 'd7406d7f-c4a3-5752-98aa-1d63110a9d64#ch0018', 'chunk_text': 'time today', 'end_sec': 302, 'seq': 18, 'start_sec': 302, 'talk_id': 'd7406d7f-c4a3-5752-98aa-1d63110a9d64'}, {'_distance': 0.6513859033584595, 'chunk_id': '50d69ac8-50d6-59f5-81c4-8cff1a4946ea#ch0033', 'chunk_text': 'much', 'end_sec': 571, 'seq': 33, 'start_sec': 571, 'talk_id': '50d69ac8-50d6-59f5-81c4-8cff1a4946ea'}, {'_distance': 0.6496061086654663, 'chunk_id': '4b5ed1f3-6dc6-5b0f-9dfb-03f9e027f218#ch0016', 'chunk_text': 'thank you', 'end_sec': 300,  ...

# %% [markdown]
# ### Delete filler chunks
# As observed from above query, a lot of small filler chunks are addig a lot of noise so lets delete them

# %%
MIN_LEN = 200           # threshold
PAGE = 2000            # descriptors per page to scan
BATCH_DELETE = 500     # delete up to this many chunk_ids per DeleteDescriptor
DRY_RUN = True         # set to False to actually delete

SET_NAME = "ds_transcript_chunks_v1"

def page_descriptors(offset=0, limit=PAGE):
    q = [{
        "FindDescriptor": {
            "set": SET_NAME,
            "offset": offset,             # shared param: skip N results
            "limit": limit,               # shared param: cap result size
            "results": {"list": ["chunk_id", "chunk_text"]}
        }
    }]
    resp, _ = con.query(q)
    items = resp[0]["FindDescriptor"].get("entities", [])
    return items, len(items)

# %%
# 1) Scan & collect short ones
to_delete = []
to_del_text = []
offset = 0
total_scanned = 0

while True:
    items, n = page_descriptors(offset=offset, limit=PAGE)
    if n == 0:
        break
    total_scanned += n
    for it in items:
        txt = (it.get("chunk_text") or "").strip()
        if len(txt) < MIN_LEN:
            cid = it.get("chunk_id")
            ct = it.get("chunk_text")
            if cid:
                to_delete.append(cid)
                to_del_text.append(ct)
    offset += n
    print(f"scanned={total_scanned}, collected_for_delete={len(to_delete)}")

print(f"\nScan complete. total_scanned={total_scanned}, short_chunks={len(to_delete)}, threshold={MIN_LEN} chars")
# Out:
# scanned=2000, collected_for_delete=13
# scanned=4000, collected_for_delete=26
# scanned=6000, collected_for_delete=41
# scanned=8000, collected_for_delete=60
# scanned=10000, collected_for_delete=72
# scanned=12000, collected_for_delete=82
# scanned=14000, collected_for_delete=98
# scanned=16000, collected_for_delete=110
# scanned=16887, collected_for_delete=117
#
# Scan complete. total_scanned=16887, short_chunks=117, threshold=200 chars

# %%
# 2) Dry-run sample
print("\nshort chunks):")
for c in to_del_text:
  print(c)
# Out:
# short chunks):
# usually that's hidden in the developer platforms
# now well yeah okay I I'll do it and I'll do it in a sec and then if you want to if you want to come see it come down by the booth and I can I can show you the URL cool all right thanks everyone
# right there neb. me and my cooworker Christian in the back will'll be around to answer any questions thank you all so much and have a wonderful day zun everybody zun
# and follow the LinkedIn um yeah any questions I mean there's a my there so you can um okay thanks for calling [Applause] me
# all right so time is 2:30 thank you guys again for for your for being here I hope you enjoy the rest of the summit thank you
# also if you need my email address there we are so thank you very much [Applause]
# again Nathan we greatly appreciate you taking time out of your day to be here with us thanks everyone for joining by now
# diand for providing us with the unique data set and for NVIDIA for providing the amazing Hardware to build these large models thank you very much
# money so my name is Jamie and I'm here at mlops downstairs if you want to talk more about this thank you
# there in case uh you want to have more discussions thank you [Applause]
# here sorry I was too slow thank you guys for listening
# Eric uh so we're going to give him some credit here at the end so thanks Eric for providing some of this content for us and thank you for attending
# then it said well I don't know your name goish so zero to python hero in 6 months it's a very simple go let's go
# framework okay thank you awesome no more no more questions thank you thank you
# right then we're going to wrap up thank you so much thank you
# okay so yeah okay thank you thank you all right thank you any other questions uh we're out of time oh okay yeah thank you thank you thank you very much
# alternatives to it but I think a key advantage that Seldon has is that it really brings that all packaged in one offer cool that concludes the session let them thank one more time thank you
# more or less competitive that market generally you'll never go beyond what is available everywhere thank all right thank you question
# and then I'll go into more details about what you care about
# teams that bring this best experience to our users and thank you for staying and aome for [Applause] questions
# now we know and like our decisions would be based on these things it's not these are experiments uh all of these these are not models in production okay thank you thanks very much
# address those questions right awesome thank you so much
# um but all these techniques should be applicable for most most gpus that we are running it
# um I know that there are other sessions that are running in the in parallel so you might be catching up but I will be here to answer any questions thank you s
# appreciate it one more round of applause
# time today
# you well let's give a big hand to [Applause] Ryan
# like big part of Storytelling is relationship building so okay please
# broader question answer thanks
# thank you [Applause]
# turn it over to the next speaker thanks again again try out app. sent.com and let us know what you think thank you all right vasel a
# yeah still 43 people in the room cool all right thank you everyone thanks
# much
# but we'll be around here afterwards as well um if there are any other questions but thanks again yeah thank you
# being here thank you everyone
# application out there thank you so much Conor appreciate it thank you thank you everybody
# um thank you so much for for attending the talk and have a wonderful day and enjoy the rest of the MLS
# days booth number 10 uh thank you
# thank you so much everyone unfortunately don't have any more time for questions we be outside so thank
# support that but um yeah it's an interesting question thank you
# at the mlops world event thank you so much take care byebye
# the summit
# work against maybe we can I can share with you the link to the talk very informative no more questions well thank you for your time
# a lot of that cognition from humans to algorithms thank you thank you thanks everyone thank you for coming
# from yeah thank you it's time
# so uh thanks for the time I know we're out of time but if there's any questions for Lee otherwise uh find the aoria folks in the conference thanks guys so that's it thank you
# innovate at speed with open source AI for your gener projects or for the others and if you have questions meet us at the boot we're in the orange T-shirt
# what to do the next time
# know the next stage of development and stuff like that so thank you very much my name is Jeffrey Hunter thank you very much [Applause]
# uh yeah feel invited and looking forward take care
# even right so that's why you give the the for the pride you give all the groups the same priors for the alpha and beta that that's pretty common practice
# we need we need to talk with the organizer yeah okay but for
# syntax this is zml thank you so much please book a demo um and I'm very looking forward to welcome you also in in our booth in the back thank you so much
# direct comparison all right thanks everyone for sticking around
# results and great success well done so can we now move on to our next project right like it's been fun we have our model let's move on to another challenge well seems like future is not happy
# find a lot of tutorial online uh so just search for lfs samples on your Google search and you'll find lot of tutorials okay any more questions no let's end this call thank you very much bye-bye
# well hello one more question sadly thank you so much thank you everyone yes please thank speaker
# thank you [Applause]
# thank you
# designed and made smartly ml will transform traditional computer aided tools into AI aided technology of the future thank you we have a boot there athletic system and talk to us thank you
# good tmls uh the rest of tmls as well hopefully we enjoy thank you everybody much appreciate good evening e e e e e e e
# e e e e
# a round of applause for the speakers and thanks everyone for your time today it's time to break up for lunch thanks
# I okay I think the might be some system ma settings oh I think that could be so let me see is the F connected to yeah maybe one not see that e e e e um backgrounds of
# a minute to um go ahead and H take a break before the next uh meeting thank you all very much I'm going to drop off
# reach out to me directly on slack tool I'm also available on LinkedIn if you want to reach out to me on LinkedIn
# major reason why we're looking more to transfer learning and pre-trained models rather than building one from scratch per se
# uh there is a role for you cool so that's all for my presentation thank you so much for all your questions and uh hope you learn something Have Fun
# to find me I'll be standing somewhere in the corner awkwardly staring at my own food so yeah cool friends thank you so much
# into your applications and have a wonderful afternoon thank you everyone
# there so please check it out thank you very much
# use I know we are probably very out of time oh cool we have 30 seconds left cool um yeah so so that's it for this talk I know it's a lot of information thank you so much for being here um thank you
# minutes uh if you want to follow up there be happy to answer any questions also happy to to you know schedule a call if you're you want to just chitchat about AI stuff thank you
# centralized stack we will make it even easier
# yeah yeah awesome thank you so much why don't we give Norma a round of applause here
# right
# intuition on what is good and what is bad is more important today thank you anyone else no I think that's it thank you very much
# used
# time but thank you all um again I'm send by feature form feel free to email me if you have any questions you can always get me on LinkedIn too there's non loss in boders um so easy find
# us today hope hope you have some something out of value for this and again feel free to connect and stay in touch foreign
# chat with you guys [Applause]
# instructions on how to do that yeah and also like how do you make an issue request to build packages alrighty I guess no questions no more questions thank you so much
# all right thank you so much I let's give him a good Round of Applause
# I that's good that is coming through and thank you all guys for joining I don't want to go over time um but I appreciate you guys joining
# physically present in the in this uh conference where can we apply for new positions you can check out the lightning. site for that uh thank you so much for joining
# it thank you
# thanks everyone
# very happy to be here um and excited to share yeah can't wait to see all in present on Friday and Monday all right we're gations thanks every thanks David bye bye
# we can use all of this as a uh as compilation rather than as the program itself thanks
# apply it and you'll get free Nimble credits it will give you an way to try Edge and see for yourself all I am talking about is that really possible or not for you that's it guys
# we used were Revenue at your car rate and mrr and we saw performance boost across all metrics and that's the reference for the paper proposed mcpr and thank you for your time
# intuition on what is good and what is bad is more important today thank you anyone else no I think that's it thank you very much
# in person and we'll be at the conference as well thank you so much let's connect thank you so much for listening and I hope you learned something bye
# definitely want to kind of uh support those use cases thank you you great thank you so much everyone
# of you thank you
# want to use the product they're not really understanding what they're consenting to uh so I think there's a lot of work to be done in that context
# move on to the next okay yeah sure but I will be around feel free to find me um in this venue and uh I look forward to talking to you all right thank you [Applause]
# have some code examples in here so there's a few links in the Q&A I'm going to stick around for one or two minutes so you can all copy paste them um but thanks all and have a good rest of your day
# questions and take a look at the manuscripts if you are interested and yeah looking forward to checking and received thank you
# yes happy to make referrals just uh let me know all righty thank you so much everyone
# sorry but due to our time we
# couple of days here uh otherwise thank you so much for joining today
# I'm not familiar but I've heard it's a cool spot so hope to see you there
# version everything else with get okay so thank you very much also and I know you're going to different workshops now and talks so enjoy the rest of the conference thank you byebye
# notes and so on all of that with their voice which makes the writing experience con convenient and easy to use on the go and that's it thank you so much everyone
# what we're doing at feature form is actually making it possible to quickly implement this feature rag uh implementation thank you
# of this on modal serverless compute platform if you'd like to hear about that please come find me thank you [Applause]
# realtime ml I'm definitely up for it so thanks a lot
# wonderful talk
# everyone for being in this talk and uh enjoy the conference
# version yeah
# catching up after like the fun of happy hour so thank you everyone
# guys so as I said we are on bsan uh yeah so happy to drop by you can get a free energy bar if you're low on energy thank you see
# continue your conversation outside because we are preparing for the next we're getting kicked out so thank you so much thank you very much
# yeah awesome thank you so much Dr Shi thank you apprciate it take care than
# audience thank you
# business with AI and with that thank you so much for your time and come shout out for thank you Jacob awesome

# %%
# 3) Delete in batches
if to_delete:
    for i in range(0, len(to_delete), BATCH_DELETE):
        batch_ids = to_delete[i:i+BATCH_DELETE]
        q = [{
            "DeleteDescriptor": {
                "set": SET_NAME,
                "constraints": { "chunk_id": ["in", batch_ids] }
            }
        }]
        resp, _ = con.query(q)
        print("Deleted batch", i, "->", i+len(batch_ids), resp)
    print("Deletion completed.")
else:
    print("\nNothing to delete.")
# Out:
# Deleted batch 0 -> 117 [{'DeleteDescriptor': {'count': 117, 'status': 0}}]
# Deletion completed.

# %% [markdown]
# No filler results now :D

# %%
import numpy as np
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("google/embeddinggemma-300m")
qvec = model.encode(["query: Strategies to drive adoption of GenAI tools"], normalize_embeddings=True)[0].astype("<f4")

q = [{
  "FindDescriptor": {
    "set": "ds_transcript_chunks_v1",
    "k_neighbors": 20,
    "distances": True,
    "results": { "list": ["_distance","chunk_id","talk_id","seq","start_sec","end_sec","chunk_text"] }
  }
}]

resp, _ = con.query(q, blobs=[qvec.tobytes()])  # vector must be supplied as a blob
print(resp)
# Out:
# [{'FindDescriptor': {'entities': [{'_distance': 0.678869366645813, 'chunk_id': 'a2d77613-e36e-5abd-bce1-89e08c2a075d#ch0010', 'chunk_text': "Enterprises are saying that they're already using generative AI or they have plans to use generative AI in the next one to two years and I would say that the these organizations are very smart to do so I truly believe that those organizations who are embracing and employing generative AI across their business are going to succeed and they are going to win over the organizations", 'end_sec': 212, 'seq': 10, 'start_sec': 184, 'talk_id': 'a2d77613-e36e-5abd-bce1-89e08c2a075d'}, {'_distance': 0.6416062712669373, 'chunk_id': '14b1947c-c2ac-5777-8a3b-4593460325f7#ch0001', 'chunk_text': "[Applause] [Music] yep thanks everyone so nice to meet you Michael triffle here with Rea AI um so to rea the future of AI is multimodal so our mission is to develop Next Generation AI to empower the most capable agents that can see hear as well as speak we'll play a little", 'end_sec': 38, 'seq': 1, 'start_sec': 0, 'talk_id': '14b1947c-c2ac-5777-8a3b-4593460325f7'}], 'returned': 2, 'status': 0}}]

# %%
import numpy as np
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("google/embeddinggemma-300m")
qvec = model.encode(["query: How are models deployed in production?"], normalize_embeddings=True)[0].astype("<f4")

q = [{
  "FindDescriptor": {
    "set": "ds_transcript_chunks_v1",
    "k_neighbors": 20,
    "distances": True,
    "results": { "list": ["_distance","chunk_id","talk_id","seq","start_sec","end_sec","chunk_text"] }
  }
}]

resp, _ = con.query(q, blobs=[qvec.tobytes()])  # vector must be supplied as a blob
print(resp)
# Out:
# [{'FindDescriptor': {'entities': [{'_distance': 0.656283974647522, 'chunk_id': '9e8a70e7-08e2-5335-87f2-2e959c0253ea#ch0088', 'chunk_text': 'later you realize that that model is deprecated and you really have to change your entire system um I would think that is a problem that should get resolved at the model provider level itself like we should have more stable models over time and like I was mentioning if there are metrics that you can kind of um', 'end_sec': 1769, 'seq': 88, 'start_sec': 1749, 'talk_id': '9e8a70e7-08e2-5335-87f2-2e959c0253ea'}, {'_distance': 0.6542110443115234, 'chunk_id': '902d023c-6c80-5dda-94f8-783668244f8e#ch0044', 'chunk_text': 'this so that we ingest model inputs and outputs into our data warehouse to enable observability this way we can achieve some division of labor so this is how our vision for the ml stack looks like we are already familiar with the model sending inputs and their inferences', 'end_sec': 950, 'seq': 44, 'start_sec': 926, 'talk_id': '902d023c-6c80-5dda-94f8-783668244f8e'}, {'_distance': 0.6467891931533813, 'chunk_id': '7122b104-77ce-5b52-9b04-4972137c2ff1#ch0032', 'chunk_text': 'approaches those are prompt tuning prefix tuning and P tuning prefix tuning and P tuning are actually the same approach but with slightly different modeling choices but the idea is that we leave natural language prompting behind the model already embeds our natural language prompts into a high dimensional space so why not optimize our prompts in that space instead of in the natural', 'end_sec': 591, 'seq': 32, 'start_sec': 569, 'talk_id': '7122b104-77ce-5b52-9b04-4972137c2ff1'}, {'_distance': 0.6425793170928955, 'chunk_id': '69b5960c-0196-5f01-ae3d-412ae75be318#ch0046', 'chunk_text': "trigger an update to an existing deployment you can find poths to all the related files and things like that very very easily the way this works is now a data scientist creates the model they have to go and put it into comment they are now officially actually tracking it in our systems they obviously register their features and a feature store because that's a separate", 'end_sec': 865, 'seq': 46, 'start_sec': 845, 'talk_id': '69b5960c-0196-5f01-ae3d-412ae75be318'}, {'_distance': 0.6393619775772095, 'chunk_id': 'd20cff86-35ee-54ac-90a7-d7290704cf41#ch0059', 'chunk_text': "coverage might not be very relevant so how do you go about attaching that to the model in general that's that's your serving so that you can reduce the alerts noise that you have we also deved Tools around feature importance both on a Model level and a global level and creating tools that can do model rollout monitoring ensuring that your metrics are being monitored continuously and any", 'end_sec': 938, 'seq': 59, 'start_sec': 917, 'talk_id': 'd20cff86-35ee-54ac-90a7-d7290704cf41'}, {'_distance': 0.6380589008331299, 'chunk_id': '42849430-6a9e-51cd-8a60-9506b1664a96#ch0088', 'chunk_text': "outs uh updates to models that don't agree with every device for example or have some issue with them need to roll back how do you handle sort of the complexity of that whole process y that's where the model evaluation kind of comes so so the question is like how will you ensure that the model you're deploying is working on the device or second is like if it does not work how", 'end_sec': 1671, 'seq': 88, 'start_sec': 1646, 'talk_id': '42849430-6a9e-51cd-8a60-9506b1664a96'}, {'_distance': 0.6372748613357544, 'chunk_id': 'c71202ff-f4d5-554b-987d-e534a796564f#ch0053', 'chunk_text': "can apply the model effectively and where we cannot um then there's U model interpretation you you can look at what is called Global model interpretation and this is for a crop growth model uh Global interpretation methods are those that seek to understand General aspects about the predictions or operations of model and in feature importance we seek to rank features by", 'end_sec': 1150, 'seq': 53, 'start_sec': 1125, 'talk_id': 'c71202ff-f4d5-554b-987d-e534a796564f'}, {'_distance': 0.63677966594696 ...

# %% [markdown]
# A) Semantic search → talks (dedupe to the source talks)
#
# Goal: Find the top-10 chunks semantically; then get the Talk objects they belong to (one per talk).

# %%
from sentence_transformers import SentenceTransformer
import numpy as np

model = SentenceTransformer("google/embeddinggemma-300m")
qvec = model.encode(["query: tools adoption in genai orgs"], normalize_embeddings=True)[0].astype("<f4")

q = [
  {
    "FindDescriptor": {
      "_ref": 1,
      "set": "ds_transcript_chunks_v1",
      "k_neighbors": 10,
      "results": { "list": ["_distance","chunk_id","talk_id","seq","start_sec","end_sec"] }
    }
  },
  {
    "FindEntity": {
      "with_class": "Talk",
      "is_connected_to": { "ref": 1, "connection_class": "TalkHasTranscriptChunk" },
      "results": { "list": ["talk_title","talk_id","youtube_url","speaker_name"] }
    }
  }
]

resp, _ = con.query(q, blobs=[qvec.tobytes()])  # the vector goes as a blob for the kNN call
print(resp)
# Out:
# [{'FindDescriptor': {'entities': [{'_distance': None, 'chunk_id': 'fc3efe32-e399-5dfc-9cd5-70912f545122#ch0030', 'end_sec': 537, 'seq': 30, 'start_sec': 513, 'talk_id': 'fc3efe32-e399-5dfc-9cd5-70912f545122'}, {'_distance': None, 'chunk_id': '73e19415-188a-5f42-bbbe-21d291723217#ch0036', 'end_sec': 1807, 'seq': 36, 'start_sec': 1807, 'talk_id': '73e19415-188a-5f42-bbbe-21d291723217'}, {'_distance': None, 'chunk_id': '4b5ed1f3-6dc6-5b0f-9dfb-03f9e027f218#ch0005', 'end_sec': 117, 'seq': 5, 'start_sec': 89, 'talk_id': '4b5ed1f3-6dc6-5b0f-9dfb-03f9e027f218'}, {'_distance': None, 'chunk_id': 'f3320a7b-3e1f-5af6-9697-c040e107e22e#ch0042', 'end_sec': 941, 'seq': 42, 'start_sec': 901, 'talk_id': 'f3320a7b-3e1f-5af6-9697-c040e107e22e'}, {'_distance': None, 'chunk_id': 'd717b6a8-bb78-52e0-bbaa-e8b45ca81348#ch0042', 'end_sec': 941, 'seq': 42, 'start_sec': 901, 'talk_id': 'd717b6a8-bb78-52e0-bbaa-e8b45ca81348'}, {'_distance': None, 'chunk_id': 'df52f16e-7e4c-56b8-a5b7-215b1ef25406#ch0037', 'end_sec': 1820, 'seq': 37, 'start_sec': 1820, 'talk_id': 'df52f16e-7e4c-56b8-a5b7-215b1ef25406'}, {'_distance': None, 'chunk_id': '42849430-6a9e-51cd-8a60-9506b1664a96#ch0011', 'end_sec': 211, 'seq': 11, 'start_sec': 189, 'talk_id': '42849430-6a9e-51cd-8a60-9506b1664a96'}, {'_distance': None, 'chunk_id': '78d8d0e6-4617-5f37-b779-28000881fa6d#ch0021', 'end_sec': 453, 'seq': 21, 'start_sec': 429, 'talk_id': '78d8d0e6-4617-5f37-b779-28000881fa6d'}, {'_distance': None, 'chunk_id': '76561ea5-27a5-5934-9a81-26d5fa7666bb#ch0070', 'end_sec': 1509, 'seq': 70, 'start_sec': 1483, 'talk_id': '76561ea5-27a5-5934-9a81-26d5fa7666bb'}, {'_distance': None, 'chunk_id': 'dc2f63ce-931e-59c0-912b-97738a2979ee#ch0012', 'end_sec': 241, 'seq': 12, 'start_sec': 218, 'talk_id': 'dc2f63ce-931e-59c0-912b-97738a2979ee'}], 'returned': 10, 'status': 0}}, {'FindEntity': {'entities': [{'speaker_name': 'Nassim Tayari', 'talk_id': '78d8d0e6-4617-5f37-b779-28000881fa6d', 'talk_title': 'AI Governance: Accelerate Responsible, Transparent, and Explainable AI Workflows', 'youtube_url': 'https://www.youtube.com/watch?v=aQFUaSB5LME'}, {'speaker_name': 'Sri  Raghu Malireddi', 'talk_id': '42849430-6a9e-51cd-8a60-9506b1664a96', 'talk_title': 'On-Device ML for LLMs: Post-training Optimization Techniques with T5 and Beyond', 'youtube_url': 'https://www.youtube.com/watch?v=QRPvr1td4s0'}, {'speaker_name': 'Shelby Heinecke', 'talk_id': 'fc3efe32-e399-5dfc-9cd5-70912f545122', 'talk_title': 'A Practical Guide to Efficient AI', 'youtube_url': 'https://www.youtube.com/watch?v=3HS0Cz_WFHM'}, {'speaker_name': 'Marinela Profi', 'talk_id': 'dc2f63ce-931e-59c0-912b-97738a2979ee', 'talk_title': 'LLMs Alone Do Not Solve Business Problems', 'youtube_url': 'https://www.youtube.com/watch?v=OK-7qZpEADc'}, {'speaker_name': 'Gayathri Srinivasan, Abhimanyu Anand', 'talk_id': '73e19415-188a-5f42-bbbe-21d291723217', 'talk_title': 'Optimizing Recommendations on Wattpad Home', 'youtube_url': 'https://www.youtube.com/watch?v=KckAQQWTMRI'}, {'speaker_name': 'Estefania Barreto', 'talk_id': '76561ea5-27a5-5934-9a81-26d5fa7666bb', 'talk_title': 'Industrializing ML Workflows in Drug Discovery', 'youtube_url': 'https://www.youtube.com/watch?v=Te02lHSsxr4'}, {'speaker_name': 'Fatma Tarlaci', 'talk_id': 'df52f16e-7e4c-56b8-a5b7-215b1ef25406', 'talk_title': 'Agentic AI: Learning Iteratively, Acting Autonomously', 'youtube_url': 'https://www.youtube.com/watch?v=_k8sPizcqUg'}, {'speaker_name': 'Bar Chen', 'talk_id': '4b5ed1f3-6dc6-5b0f-9dfb-03f9e027f218', 'talk_title': 'AI Tools Under Control: Keeping Your Agents Secure and Reliable', 'youtube_url': 'https://www.youtube.com/watch?v=poqhv4hPTpA'}, {'speaker_name': 'Vinit Dhatrak', 'talk_id': 'f3320a7b-3e1f-5af6-9697-c040e107e22e', 'talk_title': 'Revolutionizing Cloud Storage: From Petabytes to Intelligence', 'youtube_url': 'https://www.youtube.com/watch?v=cEcGoJrTptA'}, {'speaker_name': 'Eero Laaksonen', 'talk_id': 'd717b6a8-bb78-52e0-bbaa-e8b45ca81348', 'talk_title': 'MLOps for Agenti ...

# %%
from sentence_transformers import SentenceTransformer
import numpy as np

model = SentenceTransformer("google/embeddinggemma-300m")
qvec = model.encode(["query: which talks discuss using ai agent memory in production?"], normalize_embeddings=True)[0].astype("<f4")

q = [
  {
    "FindDescriptor": {
      "_ref": 1,
      "set": "ds_transcript_chunks_v1",
      "k_neighbors": 10,
      "results": { "list": ["_distance","chunk_id","talk_id","seq","start_sec","end_sec"] }
    }
  },
  {
    "FindEntity": {
      "with_class": "Talk",
      "is_connected_to": { "ref": 1, "connection_class": "TalkHasTranscriptChunk" },
      "results": { "list": ["talk_title","talk_id","youtube_url","speaker_name"] }
    }
  }
]

resp, _ = con.query(q, blobs=[qvec.tobytes()])  # the vector goes as a blob for the kNN call
print(resp)
# Out:
# [{'FindDescriptor': {'entities': [{'_distance': None, 'chunk_id': '14b1947c-c2ac-5777-8a3b-4593460325f7#ch0001', 'end_sec': 38, 'seq': 1, 'start_sec': 0, 'talk_id': '14b1947c-c2ac-5777-8a3b-4593460325f7'}, {'_distance': None, 'chunk_id': 'ae406be8-88aa-584a-adc8-5e46f08655b2#ch0003', 'end_sec': 73, 'seq': 3, 'start_sec': 45, 'talk_id': 'ae406be8-88aa-584a-adc8-5e46f08655b2'}, {'_distance': None, 'chunk_id': '4b5ed1f3-6dc6-5b0f-9dfb-03f9e027f218#ch0015', 'end_sec': 282, 'seq': 15, 'start_sec': 282, 'talk_id': '4b5ed1f3-6dc6-5b0f-9dfb-03f9e027f218'}, {'_distance': None, 'chunk_id': 'a2d77613-e36e-5abd-bce1-89e08c2a075d#ch0001', 'end_sec': 29, 'seq': 1, 'start_sec': 0, 'talk_id': 'a2d77613-e36e-5abd-bce1-89e08c2a075d'}, {'_distance': None, 'chunk_id': '4b5ed1f3-6dc6-5b0f-9dfb-03f9e027f218#ch0013', 'end_sec': 268, 'seq': 13, 'start_sec': 245, 'talk_id': '4b5ed1f3-6dc6-5b0f-9dfb-03f9e027f218'}, {'_distance': None, 'chunk_id': '542c989f-4348-54a3-a1bc-bb7461956ef3#ch0064', 'end_sec': 1504, 'seq': 64, 'start_sec': 1478, 'talk_id': '542c989f-4348-54a3-a1bc-bb7461956ef3'}, {'_distance': None, 'chunk_id': '9d937874-f6f6-520b-ba00-a56e9752eff3#ch0003', 'end_sec': 76, 'seq': 3, 'start_sec': 50, 'talk_id': '9d937874-f6f6-520b-ba00-a56e9752eff3'}, {'_distance': None, 'chunk_id': 'c27e4511-ee11-5dfa-be8a-a2d481a4af17#ch0028', 'end_sec': 520, 'seq': 28, 'start_sec': 520, 'talk_id': 'c27e4511-ee11-5dfa-be8a-a2d481a4af17'}, {'_distance': None, 'chunk_id': '882ea545-d66c-529e-ae9f-5d783d550423#ch0087', 'end_sec': 1580, 'seq': 87, 'start_sec': 1553, 'talk_id': '882ea545-d66c-529e-ae9f-5d783d550423'}, {'_distance': None, 'chunk_id': '2ae81af2-ac61-54d8-b44a-3226ac52013c#ch0052', 'end_sec': 1217, 'seq': 52, 'start_sec': 1184, 'talk_id': '2ae81af2-ac61-54d8-b44a-3226ac52013c'}], 'returned': 10, 'status': 0}}, {'FindEntity': {'entities': [{'speaker_name': 'Richie Frost', 'talk_id': 'ae406be8-88aa-584a-adc8-5e46f08655b2', 'talk_title': 'From Prototype to Product: Rapid iteration and ML model deployment at Dropbox', 'youtube_url': 'https://www.youtube.com/watch?v=nIIBQXOz7dA'}, {'speaker_name': 'Will Jones', 'talk_id': 'c27e4511-ee11-5dfa-be8a-a2d481a4af17', 'talk_title': 'LanceDB: a unified storage layer for vector search, analytics, and model training', 'youtube_url': 'https://www.youtube.com/watch?v=s3L35puUWSA'}, {'speaker_name': 'Keri Olson', 'talk_id': 'a2d77613-e36e-5abd-bce1-89e08c2a075d', 'talk_title': 'Code Smarter, not harder: Generative AI in the Software Development Lifecycle', 'youtube_url': 'https://www.youtube.com/watch?v=MyF2YadiODU'}, {'speaker_name': 'Lee Twito', 'talk_id': '2ae81af2-ac61-54d8-b44a-3226ac52013c', 'talk_title': 'Code Generation Agents: Architecture, Data Modeling Challenges, and Production-Ready Considerations', 'youtube_url': 'https://www.youtube.com/watch?v=68v7rzWpKx4'}, {'speaker_name': 'Rokshana Stephny  Geread', 'talk_id': '9d937874-f6f6-520b-ba00-a56e9752eff3', 'talk_title': 'A machine learning-driven phenotyping platform for rapid in vivo target validation and precision medicine development', 'youtube_url': 'https://www.youtube.com/watch?v=ot3eDZY2X-s'}, {'speaker_name': 'Connor Joyce', 'talk_id': '882ea545-d66c-529e-ae9f-5d783d550423', 'talk_title': 'AI Features Demand Evidence-Based Decisions', 'youtube_url': 'https://www.youtube.com/watch?v=pkkVTqlMQcE'}, {'speaker_name': 'Michael Thriffiley', 'talk_id': '14b1947c-c2ac-5777-8a3b-4593460325f7', 'talk_title': 'Multimodal Agents You Can Deploy Anywhere', 'youtube_url': 'https://www.youtube.com/watch?v=hU2mQTKYA80'}, {'speaker_name': 'Bar Chen', 'talk_id': '4b5ed1f3-6dc6-5b0f-9dfb-03f9e027f218', 'talk_title': 'AI Tools Under Control: Keeping Your Agents Secure and Reliable', 'youtube_url': 'https://www.youtube.com/watch?v=poqhv4hPTpA'}, {'speaker_name': 'Qingyun Wu', 'talk_id': '542c989f-4348-54a3-a1bc-bb7461956ef3', 'talk_title': 'AutoGen: Enabling Next-Gen AI Applications via Multi-Agent Conversation', 'youtube_url': 'https://www.youtube.com/watch?v=WLKStss2W ...

# %% [markdown]
# B) Semantic search → best talk → show that talk’s top 3 earliest chunks
#
# Goal: Hit kNN, pick the most similar chunk, hop to its talk, then list the first 3 chunks of that talk (by seq) to inspect context.

# %%
model = SentenceTransformer("google/embeddinggemma-300m")
qvec = model.encode(["query: ai agents with memory"], normalize_embeddings=True)[0].astype("<f4")

q = [
  { "FindDescriptor": {
      "_ref": 1,
      "set": "ds_transcript_chunks_v1",
      "k_neighbors": 1,
      "results": { "list": ["chunk_id","talk_id","seq"] }
  }},
  { "FindEntity": {
      "_ref": 2,
      "with_class": "Talk",
      "unique": True,
      "is_connected_to": { "ref": 1, "connection_class": "TalkHasTranscriptChunk" },
      "results": { "list": ["talk_title","talk_id","speaker_name"] }
  }},
  { "FindDescriptor": {
      "set": "ds_transcript_chunks_v1",
      "is_connected_to": { "ref": 2, "connection_class": "TalkHasTranscriptChunk" },
      "sort": { "key": "seq", "order": "ascending" },
      "limit": 3,
      "results": { "list": ["seq","start_sec","end_sec","chunk_id","chunk_text"] }
  }}
]

resp, _ = con.query(q, blobs=[qvec.tobytes()])
print(resp)
# Out:
# [{'FindDescriptor': {'entities': [{'chunk_id': '14b1947c-c2ac-5777-8a3b-4593460325f7#ch0001', 'seq': 1, 'talk_id': '14b1947c-c2ac-5777-8a3b-4593460325f7'}], 'returned': 1, 'status': 0}}, {'FindEntity': {'entities': [{'speaker_name': 'Michael Thriffiley', 'talk_id': '14b1947c-c2ac-5777-8a3b-4593460325f7', 'talk_title': 'Multimodal Agents You Can Deploy Anywhere'}], 'returned': 1, 'status': 0}}, {'FindDescriptor': {'entities': [{'chunk_id': '14b1947c-c2ac-5777-8a3b-4593460325f7#ch0001', 'chunk_text': "[Applause] [Music] yep thanks everyone so nice to meet you Michael triffle here with Rea AI um so to rea the future of AI is multimodal so our mission is to develop Next Generation AI to empower the most capable agents that can see hear as well as speak we'll play a little", 'end_sec': 38, 'seq': 1, 'start_sec': 0}, {'chunk_id': '14b1947c-c2ac-5777-8a3b-4593460325f7#ch0002', 'chunk_text': "as speak we'll play a little video at Rea we recognize that most data extends Beyond text it also contains images audio and even videos we made our AI models multimodal so you can better understand and interact with the world they can read see hear speak learn and think just like we do pleasure to meet you Rua multimodal models understand", 'end_sec': 63, 'seq': 2, 'start_sec': 29}, {'chunk_id': '14b1947c-c2ac-5777-8a3b-4593460325f7#ch0003', 'chunk_text': 'think just like we do pleasure to meet you Rua multimodal models understand complex inputs and can make sense of vast amounts of data we support a large context window of up to 128,000 tokens by default with an option to extend to 400,000 context length this means our models can analyze and extract information from unstructured data with great accuracy can you show me the price', 'end_sec': 86, 'seq': 3, 'start_sec': 57}], 'returned': 3, 'status': 0}}]

# %% [markdown]
# C) Talk → semantic search confined to that talk only
#
# Goal: Start from a specific talk, then restrict kNN to only its chunks.

# %%
model = SentenceTransformer("google/embeddinggemma-300m")
qvec = model.encode(["query: ai agents with memory"], normalize_embeddings=True)[0].astype("<f4")

q = [
  { "FindEntity": {
      "_ref": 1,
      "with_class": "Talk",
      "unique": True,
      "constraints": { "talk_title": ["==", "Multimodal Agents You Can Deploy Anywhere"] },
      "results": { "list": ["talk_id","talk_title"] }
  }},
  { "FindDescriptor": {
      "set": "ds_transcript_chunks_v1",
      "is_connected_to": { "ref": 1, "connection_class": "TalkHasTranscriptChunk" },
      "k_neighbors": 5,
      "results": { "list": ["_distance","seq","start_sec","end_sec","chunk_id","chunk_text"] }
  }}
]

resp, _ = con.query(q, blobs=[qvec.tobytes()])
print(resp)
# Out:
# [{'FindEntity': {'entities': [{'talk_id': '14b1947c-c2ac-5777-8a3b-4593460325f7', 'talk_title': 'Multimodal Agents You Can Deploy Anywhere'}], 'returned': 1, 'status': 0}}, {'FindDescriptor': {'entities': [{'_distance': None, 'chunk_id': '14b1947c-c2ac-5777-8a3b-4593460325f7#ch0001', 'chunk_text': "[Applause] [Music] yep thanks everyone so nice to meet you Michael triffle here with Rea AI um so to rea the future of AI is multimodal so our mission is to develop Next Generation AI to empower the most capable agents that can see hear as well as speak we'll play a little", 'end_sec': 38, 'seq': 1, 'start_sec': 0}], 'returned': 1, 'status': 0}}]

# %% [markdown]
# D) Multiple talks → grouped semantic search (see which talk matches best)
#
# Goal: Pick a few talks of interest, then run kNN only within those talks, and group results by talk.

# %%
model = SentenceTransformer("google/embeddinggemma-300m")
qvec = model.encode(["query: what are ai agents?"], normalize_embeddings=True)[0].astype("<f4")

q = [
  { "FindEntity": {
      "_ref": 1,
      "with_class": "Talk",
      "constraints": { "talk_title": ["in", ["Multimodal Agents You Can Deploy Anywhere","Demystifying Large Language Models: ChatGPT, GPT-4, and the Future of AI Communication","Panel: How companies can navigate and approach the new advancements in generative AI"]] },
      "results": { "list": ["talk_title","talk_id"] }
  }},
  { "FindDescriptor": {
      "set": "ds_transcript_chunks_v1",
      "is_connected_to": { "ref": 1, "connection_class": "TalkHasTranscriptChunk" },
      "k_neighbors": 8,
      "group_by_source": True,
      "results": { "list": ["_distance","seq","chunk_id","chunk_text"] }
  }}
]

resp, _ = con.query(q, blobs=[qvec.tobytes()])
print(resp)
# Out:
# [{'FindEntity': {'entities': [{'talk_id': 'ce87713c-db71-561a-8ec9-c840306348ca', 'talk_title': 'Demystifying Large Language Models: ChatGPT, GPT-4, and the Future of AI Communication'}, {'talk_id': '7255dc0f-0f29-5aad-9a95-a7956c44673a', 'talk_title': 'Panel: How companies can navigate and approach the new advancements in generative AI'}, {'talk_id': '14b1947c-c2ac-5777-8a3b-4593460325f7', 'talk_title': 'Multimodal Agents You Can Deploy Anywhere'}], 'returned': 3, 'status': 0}}, {'FindDescriptor': {'entities': {'7.141.262': [], '7.19.260': [], '7.241.262': [{'_distance': None, 'chunk_id': '14b1947c-c2ac-5777-8a3b-4593460325f7#ch0001', 'chunk_text': "[Applause] [Music] yep thanks everyone so nice to meet you Michael triffle here with Rea AI um so to rea the future of AI is multimodal so our mission is to develop Next Generation AI to empower the most capable agents that can see hear as well as speak we'll play a little", 'seq': 1}]}, 'group_by_source': True, 'returned': 1, 'status': 0}}]

# %% [markdown]
# ### Creating Remaining DescriptorSets

# %%
SET_META = "ds_talk_meta_v1"
SET_BIO  = "ds_speaker_bio_v1"

utils.add_descriptorset(SET_META, EMBED_DIM, metric=["CS"], engine="HNSW")
utils.add_descriptorset(SET_BIO,  EMBED_DIM, metric=["CS"], engine="HNSW")
print("DescriptorSets ready:", SET_META, SET_BIO)
# Out:
# WARNING:aperturedb.CommonLibrary:Partial errors:
# [{"AddDescriptorSet": {"name": "ds_talk_meta_v1", "dimensions": 768, "metric": ["CS"], "engine": "HNSW"}}]
# [{"AddDescriptorSet": {"info": "A descriptor set with this name already exists!", "status": 2}}]
# WARNING:aperturedb.CommonLibrary:Partial errors:
# [{"AddDescriptorSet": {"name": "ds_speaker_bio_v1", "dimensions": 768, "metric": ["CS"], "engine": "HNSW"}}]
# [{"AddDescriptorSet": {"info": "A descriptor set with this name already exists!", "status": 2}}]
# DescriptorSets ready: ds_talk_meta_v1 ds_speaker_bio_v1

# %%
# CSV column names used
ABSTRACT_COL   = "Abstract"
WYL_COL        = "What You'll Learn"
PREREQ_COL     = "Prerequiste Knowledge (if required)"
CAT1_COL       = "Category 1"
KW_COL         = "Top 3 keywords (in order)"
UNIQUE_COL     = "What is Unique about your session"
JOB_COL        = "Job Title"
BIO_COL        = "Bio"

MIN_TEXT_LEN = 30  # skip ultra-short/noisy rows

def _safe(x):
    return str(x).strip() if (isinstance(x, str) and x.strip()) else ""

def meta_text_from_row(r: pd.Series) -> str:
    parts = [
        _safe(r.get(TALK_TITLE_COL)),
        _safe(r.get(ABSTRACT_COL)),
        _safe(r.get(WYL_COL)),
        _safe(r.get(PREREQ_COL)),
        _safe(r.get(CAT1_COL)),
        _safe(r.get(KW_COL)),
        _safe(r.get(UNIQUE_COL)),
    ]
    txt = " | ".join([p for p in parts if p])
    return txt

def bio_text_from_row(r: pd.Series) -> str:
    parts = [_safe(r.get(JOB_COL)), _safe(r.get(BIO_COL))]
    txt = " | ".join([p for p in parts if p])
    return txt

# %%
def build_meta_queries(df: pd.DataFrame):
    queries, skipped = [], 0
    for _, row in df.iterrows():
        title = _safe(row.get(TALK_TITLE_COL))
        if not title:
            continue

        yt_id = _safe(row.get(YOUTUBE_ID_COL)) or extract_youtube_id(_safe(row.get(YOUTUBE_URL_COL)))
        talk_id = make_talk_id(title, yt_id)

        txt = meta_text_from_row(row)
        if len(txt) < MIN_TEXT_LEN:
            skipped += 1
            continue

        vec = model.encode([txt], normalize_embeddings=True, show_progress_bar=False)[0]
        uid = f"{talk_id}::{SET_META}"

        cmd = [
            { "FindEntity": {
                "_ref": 1, "with_class": TALK_CLASS, "unique": True,
                "constraints": {"talk_id": ["==", talk_id]},
                "results": {"count": True}
            }},
            { "AddDescriptor": {                                     # AddDescriptor + connect
                "set": SET_META,
                "properties": {
                    "descriptor_uid": uid,       # set-unique for idempotency across sets
                    "talk_id": talk_id,
                    "meta_text": txt
                },
                "if_not_found": { "descriptor_uid": ["==", uid] },  # safe conditional-add
                "connect": { "class": "TalkHasMeta", "ref": 1, "direction": "in" }
            }}
        ]
        queries.append((cmd, [to_blob(np.asarray(vec, dtype="<f4"))]))
    print(f"[meta] prepared={len(queries)} skipped_short_or_empty={skipped}")
    return queries

def build_bio_queries(df: pd.DataFrame):
    queries, skipped = [], 0
    for _, row in df.iterrows():
        title = _safe(row.get(TALK_TITLE_COL))
        if not title:
            continue

        yt_id = _safe(row.get(YOUTUBE_ID_COL)) or extract_youtube_id(_safe(row.get(YOUTUBE_URL_COL)))
        talk_id = make_talk_id(title, yt_id)

        txt = bio_text_from_row(row)
        if len(txt) < MIN_TEXT_LEN:
            skipped += 1
            continue

        vec = model.encode([txt], normalize_embeddings=True, show_progress_bar=False)[0]
        uid = f"{talk_id}::{SET_BIO}"

        cmd = [
            { "FindEntity": {
                "_ref": 1, "with_class": TALK_CLASS, "unique": True,
                "constraints": {"talk_id": ["==", talk_id]},
                "results": {"count": True}
            }},
            { "AddDescriptor": {
                "set": SET_BIO,
                "properties": {
                    "descriptor_uid": uid,
                    "talk_id": talk_id,
                    "bio_text": txt
                },
                "if_not_found": { "descriptor_uid": ["==", uid] },
                "connect": { "class": "TalkHasSpeakerBio", "ref": 1, "direction": "in" }
            }}
        ]
        queries.append((cmd, [to_blob(np.asarray(vec, dtype="<f4"))]))
    print(f"[bio] prepared={len(queries)} skipped_short_or_empty={skipped}")
    return queries

# %%
df = pd.read_csv(CSV_PATH)
print("rows read:", len(df))

meta_queries = build_meta_queries(df)
bio_queries  = build_bio_queries(df)

loader = ParallelLoader(con)

if meta_queries:
    loader.ingest(meta_queries, batchsize=DB_BATCHSIZE, numthreads=DB_THREADS, stats=True)   #
if bio_queries:
    loader.ingest(bio_queries,  batchsize=DB_BATCHSIZE, numthreads=DB_THREADS, stats=True)

print("Done.")
# Out:
# rows read: 278
# [meta] prepared=278 skipped_short_or_empty=0
# [bio] prepared=269 skipped_short_or_empty=9
# Progress: 100%|██████████| 278/278 [00:08<00:00, 34.7items/s]
# ============ ApertureDB Loader Stats ============
# Total time (s): 8.00862741470337
# Total queries executed: 20
# Avg Query time (s): 1.5235175132751464
# Query time std: 0.6177937849136516
# Avg Query Throughput (q/s): 2.6255031301879117
# Overall insertion throughput (element/s): 34.71256503824967
# Total inserted elements: 278
# Total successful commands: 556
# =================================================
# Progress: 100%|██████████| 269/269 [00:08<00:00, 33.6items/s]
# ============ ApertureDB Loader Stats ============
# Total time (s): 8.008178949356079
# Total queries executed: 20
# Avg Query time (s): 1.4736083269119262
# Query time std: 0.5892354024135589
# Avg Query Throughput (q/s): 2.7144254867114834
# Overall insertion throughput (element/s): 33.59065796370968
# Total inserted elements: 269
# Total successful commands: 538
# =================================================
# Done.

# %% [markdown]
# ### sanity check queries

# %% [markdown]
# 1) Counts per set

# %%
for s in [SET_META, SET_BIO]:
    q = [{"FindDescriptor": {"set": s, "results": {"count": True}}}]
    print(s, con.query(q)[0])
# Out:
# ds_talk_meta_v1 [{'FindDescriptor': {'count': 278, 'returned': 0, 'status': 0}}]
# ds_speaker_bio_v1 [{'FindDescriptor': {'count': 269, 'returned': 0, 'status': 0}}]

# %% [markdown]
# 2) Hop from one talk to each set

# %%
title = "Panel: How companies can navigate and approach the new advancements in generative AI"
q = [
  {"FindEntity": {"_ref": 1, "with_class": "Talk", "unique": True,
                  "constraints": {"talk_title": ["==", title]}, "results": {"list": ["talk_id"]}}},
  {"FindDescriptor": {"set": SET_META, "is_connected_to": {"ref": 1, "connection_class": "TalkHasMeta"},
                      "results": {"list": ["descriptor_uid","meta_text"]}}},
  {"FindDescriptor": {"set": SET_BIO,  "is_connected_to": {"ref": 1, "connection_class": "TalkHasSpeakerBio"},
                      "results": {"list": ["descriptor_uid","bio_text"]}}}
]
print(con.query(q))
# Out:
# ([{'FindEntity': {'entities': [{'talk_id': '7255dc0f-0f29-5aad-9a95-a7956c44673a'}], 'returned': 1, 'status': 0}}, {'FindDescriptor': {'entities': [{'descriptor_uid': '7255dc0f-0f29-5aad-9a95-a7956c44673a::ds_talk_meta_v1', 'meta_text': 'Panel: How companies can navigate and approach the new advancements in generative AI | Business and stakeholder alignment | Generative AI, Business Strategy, Panel Discussion'}], 'returned': 1, 'status': 0}}, {'FindDescriptor': {'entities': [{'bio_text': "Principal Director, Experimental Development, Chief Commercialization Officer & VP, Industry Innovation, Chief Operating Officer, Interim Head, Sara - Head of Cohere for AI | Michel - As Director, AI Activation at Mila, the Quebec Artificial Intelligence Institute, Michel Dubois actively participates in the development of AI for the benefit of all. He holds a master's degree in mathematics and is currently a PhD candidate in engineering (machine learning). He is also the author of a patent on the mathematical optimization of high-bandwidth signal switching. Over the past 28 years, Michel Dubois has consolidated his experience in several aspects of machine learning and artificial intelligence. Before joining Mila, Michel Dubois held the role of Associate Partner at IBM, and, in his previous role, he was Vice President of Artificial Intelligence at Newtrax, a Montreal start-up that quickly experienced international success, reaching an average annual revenue growth of 80% and opening offices in Santiago, Perth, Moscow and London.\n\nCameron - Cameron Schuler is the Chief Commercialization Officer & Vice President, Industry Innovation at the Vector Institute. He is the former Executive Director of Amii, where, for 8 years, he led one of the top-ranked Machine Learning and AI groups in the world. Cameron’s multifaceted career has covered finance, business & product development, consumer products, IT and general management from start-ups to mature companies. His industry experience includes Alternative Energy, Banking, Consumer Products, Information Technology (Consumer and Enterprise), Investment Sales and Trading, Life Sciences, Manufacturing, Medical Devices, Oil & Gas, and Oil & Gas Services. Roles have included COO, CFO, President and CEO and he was COO & CFO of a food manufacturer whose products lead to sales of over 250 million units.\n\nKirk - Kirk Rockwell is a project and operations manager with more than 20 years of experience managing technology and innovation initiatives, across a broad range of sectors in partnership with academia, all levels of government, and some of Canada’s largest companies.\n\nWithin an arm's length government agency, he had responsibility for investment of public funds into research and innovation projects across multiple sectors including energy, clean tech, agriculture and health, utilizing technologies like AI and Machine Learning, Nanotechnology and Genomics. \n\nHe has experience with numerous public/private partnerships (P3s) including membership on advisory and governance boards where the stakeholders include large multinational corporations, the governments of Alberta and Canada, universities, and other small or medium-sized companies.\n\nHe has a Diploma in Environmental Technologies, a Bachelor of Science Degree in Environmental Sciences, and a Master’s of Business Administration Degree with a specialization in Innovation and Entrepreneurship.\n\nKirk is currently the VP, Public Strategy and Gants at the Alberta Machine Intelligence Institute (Amii) in Edmonton, Alberta, Canada. He resides in Edmonton with his wife and two daughters.\n\nAlex - Alex LaPlante is currently the interim Head of Borealis AI, RBC's R&D lab for artificial intelligence, where she and her team build and deploy leading-edge AI solutions to complex business problems found across the enterprise. Previously, Alex led Borealis' business development and product management teams, which saw her design the company's long-term product v ...

# %% [markdown]
# 3) kNN on meta set → back to talks

# %%
qvec = model.encode(["query: evaluation pipelines and deployment"], normalize_embeddings=True)[0].astype("<f4")
q = [
  {"FindDescriptor": {"_ref": 1, "set": SET_META, "k_neighbors": 5,
                      "results": {"list": ["_distance","descriptor_uid","talk_id","meta_text"]}}},
  {"FindEntity": {"with_class": "Talk", "is_connected_to": {"ref": 1, "connection_class": "TalkHasMeta"},
                  "results": {"list": ["talk_title","speaker_name","youtube_url"]}}}
]
print(con.query(q, blobs=[qvec.tobytes()]))
# Out:
# ([{'FindDescriptor': {'entities': [{'_distance': None, 'descriptor_uid': '6b8d79ff-1417-57e1-9263-12d335800919::ds_talk_meta_v1', 'meta_text': 'Optimized AI Deployment Platform | Showcasing CentMLs ability to streamline the process of deploying and optimizing LLMs in production. | Deployment and integration | CentML, LLM deployment, Optimization', 'talk_id': '6b8d79ff-1417-57e1-9263-12d335800919'}, {'_distance': None, 'descriptor_uid': '0c7e727c-214e-5fc1-954e-3aa19bd8a513::ds_talk_meta_v1', 'meta_text': 'Deploying and Evaluating RAG pipelines with Lightning Studios | Learn how to use Lightning Studios to quickly deploy AI agents and accelerate your evaluation of RAG pipelines. | Learn how to use Lightning Studios to quickly deploy AI agents and accelerate your evaluation of RAG pipelines. | Deployment and integration | Lightning Studios, RAG Pipelines, AI Agents', 'talk_id': '0c7e727c-214e-5fc1-954e-3aa19bd8a513'}, {'_distance': None, 'descriptor_uid': '4e0c7f79-d08a-5eed-8500-eda5faa5ec2f::ds_talk_meta_v1', 'meta_text': 'Panel: The Current Investment Landscape. Opportunities & Challenges in ML/Gen AI | Business and stakeholder alignment | Investment landscape, Opportunities, ML/GenAI', 'talk_id': '4e0c7f79-d08a-5eed-8500-eda5faa5ec2f'}, {'_distance': None, 'descriptor_uid': '7255dc0f-0f29-5aad-9a95-a7956c44673a::ds_talk_meta_v1', 'meta_text': 'Panel: How companies can navigate and approach the new advancements in generative AI | Business and stakeholder alignment | Generative AI, Business Strategy, Panel Discussion', 'talk_id': '7255dc0f-0f29-5aad-9a95-a7956c44673a'}, {'_distance': None, 'descriptor_uid': 'df7ba3f6-88d0-5225-96e9-4d66d969b090::ds_talk_meta_v1', 'meta_text': 'Panel: Achieving Long-Term AI Growth: Real Problem Solving vs. Trend-Based Solutions | Future trends | Long-term growth, AI problem-solving, Trend-based solutions', 'talk_id': 'df7ba3f6-88d0-5225-96e9-4d66d969b090'}], 'returned': 5, 'status': 0}}, {'FindEntity': {'entities': [{'speaker_name': 'Vasilis Vagias', 'talk_title': 'Optimized AI Deployment Platform', 'youtube_url': 'https://www.youtube.com/watch?v=pNgwVCrpUJU'}, {'speaker_name': 'George Matthew, Prerna Sharma, Mark Weber', 'talk_title': 'Panel: The Current Investment Landscape. Opportunities & Challenges in ML/Gen AI', 'youtube_url': 'https://www.youtube.com/watch?v=V5k4Mpbd0h4'}, {'speaker_name': 'Joe Reis, Jepson Taylor, Hugo Bowne-Anderson', 'talk_title': 'Panel: Achieving Long-Term AI Growth: Real Problem Solving vs. Trend-Based Solutions', 'youtube_url': 'https://www.youtube.com/watch?v=Swof2q5zTyI'}, {'speaker_name': 'Michel Dubois, Cameron Schuler, Alex LaPlante, Sara Hooker', 'talk_title': 'Panel: How companies can navigate and approach the new advancements in generative AI', 'youtube_url': 'https://www.youtube.com/watch?v=BzS74tByHpw'}, {'speaker_name': 'Rob Levy', 'talk_title': 'Deploying and Evaluating RAG pipelines with Lightning Studios', 'youtube_url': 'https://www.youtube.com/watch?v=JO2mJ00rCkU'}], 'returned': 5, 'status': 0}}], [])

# %%
run([
  { "GetSchema": { } }
]
)
# Out:
# [
#     {
#         "GetSchema": {
#             "connections": {
#                 "classes": {
#                     "TalkHasMeta": {
#                         "dst": "_Descriptor",
#                         "matched": 278,
#                         "properties": null,
#                         "src": "Talk"
#                     },
#                     "TalkHasSpeaker": {
#                         "dst": "Person",
#                         "matched": 373,
#                         "properties": null,
#                         "src": "Talk"
#                     },
#                     "TalkHasSpeakerBio": {
#                         "dst": "_Descriptor",
#                         "matched": 269,
#                         "properties": null,
#                         "src": "Talk"
#                     },
#                     "TalkHasTranscriptChunk": {
#                         "dst": "_Descriptor",
#                         "matched": 16770,
#                         "properties": null,
#                         "src": "Talk"
#                     },
#                     "_DescriptorSetToDescriptor": {
#                         "dst": "_Descriptor",
#                         "matched": 17317,
#                         "properties": null,
#                         "src": "_DescriptorSet"
#                     }
#                 },
#                 "returned": 5
#             },
#             "entities": {
#                 "classes": {
#                     "Person": {
#                         "matched": 338,
#                         "properties": {
#                             "name": [
#                                 338,
#                                 true,
#                                 "String"
#                             ]
#                         }
#                     },
#                     "Talk": {
#                         "matched": 278,
#                         "properties": {
#                             "abstract": [
#                                 274,
#                                 false,
#                                 "String"
#                             ],
#                             "bio": [
#                                 269,
#                                 false,
#                                 "String"
#                             ],
#                             "category_primary": [
#                                 277,
#                                 false,
#                                 "String"
#                             ],
#                             "company_name": [
#                                 278,
#                                 false,
#                                 "String"
#                             ],
#                             "event_name": [
#                                 242,
#                                 false,
#                                 "String"
#                             ],
#                             "industries": [
#                                 157,
#                                 false,
#                                 "String"
#                             ],
#                             "job_title": [
#                                 278,
#                                 false,
#                                 "String"
#                             ],
#                             "keywords_csv": [
#                                 232,
#                                 false,
#                                 "String"
#                             ],
#                             "prereq_knowledge": [
#                                 46,
#                                 false,
#                                 "String"
#                             ],
#                             "speaker_name": [
#                                 278,
#                                 false,
#                                 "String"
#                             ],
#                             "talk_id": [
#                                 278,
#                                 true,
#                                 "String"
#                             ],
#                             "talk_title": [
#                                 278,
#                                 true,
#                                 "String"
#                             ],
#                             "tech_level": [
#                                 238,
#                                 false,
#                                 "Number"
#                             ],
#                             "track": [
#                                 261,
#                                 false,
#                                 "String"
#                             ],
#                             "unique_session_note": [
#                                 108,
#                                 false,
#                                 "String"
#                             ],
#                             "what_youll_learn": [
#                                 218,
#                                 false,
#                                 "String"
#                             ],
#                             "youtube_id": [
#                                 278,
#                                 false,
#                                 "String"
#                             ],
#                             "youtube_url": [
#                                 278,
#                                 false,
#                                 "String"
#                             ],
#                             "yt_published_at": [
#                                 274,
#                                 false,
#                                 "Datetime"
#                             ],
#                             "yt_views": [
#                                 278,
#                                 false,
#                                 "Number"
#                             ]
#                         }
#                     },
#                     "_Descriptor": {
#                         "matched": 17317,
#                         "properties": {
#                             "_label": [
#                                 17317,
#                                 false,
#                                 "String"
#                             ],
#                             "bio_text": [
#                                 269,
#                                 false,
#                                 "String"
#                             ],
#                             "chunk_id": [
#                                 16770,
#                                 false,
#                                 "String"
#                             ],
#                             "chunk_text": [
#                                 16770,
#                                 false,
#                                 "String"
#                             ],
#                             "descriptor_uid": [
#                                 547,
#                                 false,
#                                 "String"
#                             ],
#                             "end_sec": [
#                                 16770,
#                                 false,
#                                 "Number"
#                             ],
#                             "meta_text": [
#                                 278,
#                                 false,
#                                 "String"
#                             ],
#                             "seq": [
#                                 16770,
#                                 false,
#                                 "Number"
#                             ],
#                             "start_sec": [
#                                 16770,
#                                 false,
#                                 "Number"
#                             ],
#                             "talk_id": [
#                                 17317,
#                                 false,
#                                 "String"
#                             ]
#                         }
#                     },
#                     "_DescriptorSet": {
#                         "matched": 3,
#                         "properties": {
#                             "_dimensions": [
#                                 3,
#                                 false,
#                                 "Number"
#                             ],
#                             "_name": [
#                                 3,
#                                 false,
#                                 "String"
#                             ]
#                         }
#                     }
#                 },
#                 "returned": 4
#             },
#             "refreshed": "2025-09-28T16:44:44.492628Z",
#             "status": 0
#         }
#     }
# ]
# [{'GetSchema': {'connections': {'classes': {'TalkHasMeta': {'dst': '_Descriptor',
#       'matched': 278,
#       'properties': None,
#       'src': 'Talk'},
#      'TalkHasSpeaker': {'dst': 'Person',
#       'matched': 373,
#       'properties': None,
#       'src': 'Talk'},
#      'TalkHasSpeakerBio': {'dst': '_Descriptor',
#       'matched': 269,
#       'properties': None,
#       'src': 'Talk'},
#      'TalkHasTranscriptChunk': {'dst': '_Descriptor',
#       'matched': 16770,
#       'properties': None,
#       'src': 'Talk'},
#      '_DescriptorSetToDescriptor': {'dst': '_Descriptor',
#       'matched': 17317,
#       'properties': None,
#       'src': '_DescriptorSet'}},
#     'returned': 5},
#    'entities': {'classes': {'Person': {'matched': 338,
#       'properties': {'name': [338, True, 'String']}},
#      'Talk': {'matched': 278,
#       'properties': {'abstract': [274, False, 'String'],
#        'bio': [269, False, 'String'],
#        'category_primary': [277, False, 'String'],
#        'company_name': [278, False, 'String'],
#        'event_name': [242, False, 'String'],
#        'industries': [157, False, 'String'],
#        'job_title': [278, False, 'String'],
#        'keywords_csv': [232, False, 'String'],
#        'prereq_knowledge': [46, False, 'String'],
#        'speaker_name': [278, False, 'String'],
#        'talk_id': [278, True, 'String'],
#        'talk_title': [278, True, 'String'],
#        'tech_level': [238, False, 'Number'],
#        'track': [261, False, 'String'],
#        'unique_session_note': [108, False, 'String'],
#        'what_youll_learn': [218, False, 'String'],
#        'youtube_id': [278, False, 'String'],
#        'youtube_url': [278, False, 'String'],
#        'yt_published_at': [274, False, 'Datetime'],
#        'yt_views': [278, False, 'Number']}},
#      '_Descriptor': {'matched': 17317,
#       'properties': {'_label': [17317, False, 'String'],
#        'bio_text': [269, False, 'String'],
#        'chunk_id': [16770, False, 'String'],
#        'chunk_text': [16770, False, 'String'],
#        'descriptor_uid': [547, False, 'String'],
#        'end_sec': [16770, False, 'Number'],
#        'meta_text': [278, False, 'String'],
#        'seq': [16770, False, 'Number'],
#        'start_sec': [16770, False, 'Number'],
#        'talk_id': [17317, False, 'String']}},
#      '_DescriptorSet': {'matched': 3,
#       'properties': {'_dimensions': [3, False, 'Number'],
#        '_name': [3, False, 'String']}}},
#     'returned': 4},
#    'refreshed': '2025-09-28T16:44:44.492628Z',
#    'status': 0}}]
